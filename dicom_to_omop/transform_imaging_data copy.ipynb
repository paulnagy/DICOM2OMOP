# %% [markdown]
# # Part II: Transform Imaging Data into OMOP CDM
#
# ### Prerequisites
# * Download ODBC Driver 18 from web <https://learn.microsoft.com/en-us/sql/connect/odbc/linux-mac/install-microsoft-odbc-driver-sql-server-macos?view=sql-server-ver16>
# * OMOP CDM instance with the connection string and authentication information. If your database access limits IP addresses, make sure to add your IP address before running the connection strings.
# * Install SQL processing package, i.e., pyodbc.
# * Files or database that non-image data is stored: demographic, clinical assessments, labs, visits, etc.
# * Locate your imaging files: local paths, cloud storage services (e.g., Microsoft Azure)

# %%
import requests
import pandas as pd
import pydicom
from pathlib import Path
from urllib3.filepost import encode_multipart_formdata, choose_boundary
from azure.identity import DefaultAzureCredential
# Out:
# /Users/wooyeonpark/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# !pip install azure-cli

# %%
# !az login

# %%
# Run the az command and capture its output
captured_output = !az account get-access-token --resource https://dicom.healthcareapis.azure.com --query accessToken --output tsv

# The output is a special IPython.utils.text.SList object which behaves like a list.
# If the command outputs a single line (like an access token), it will be the first element.
bearer_token = captured_output[2].strip()

# %%
# check connection
base_dicomweb_url = 'https://imgextpoc-adnidicom.dicom.azurehealthcareapis.com/v2'

headers = {
    'Accept': "application/json",
    'Authorization': 'Bearer ' + bearer_token
    }
dicomweb_study_query_url =  base_dicomweb_url + '/studies/'
response = requests.request("GET", dicomweb_study_query_url, data="", headers=headers)
response
# Out:
# <Response [200]>

# %%
# Extract all metadata from DICOM server
# To avoid repetitive information, we filter extracting one instance metadata per series
import requests
import pandas as pd

# Function to fetch metadata for the first instance in a given series
def fetch_series_metadata(base_url, study_uid, series_uid, headers):
    # Endpoint to fetch instances within the series
    instances_url = f"{base_url}/studies/{study_uid}/series/{series_uid}/instances"
    instances_response = requests.get(instances_url, headers=headers)
    if instances_response.status_code != 200:
        print(f"Error fetching instances for series {series_uid}: {instances_response.status_code}")
        return {}

    instances = instances_response.json()
    if not instances:
        print(f"No instances found for series {series_uid}")
        return {}

    # Fetch metadata for the first instance
    instance_uid = instances[0]['00080018']['Value'][0]
    instance_metadata_url = f"{base_url}/studies/{study_uid}/series/{series_uid}/instances/{instance_uid}/metadata"
    instance_metadata_response = requests.get(instance_metadata_url, headers=headers)
    if instance_metadata_response.status_code == 200:
        return instance_metadata_response.json()
    else:
        print(f"Error fetching metadata for instance {instance_uid}: {instance_metadata_response.status_code}")
        return {}

# Function to extract all metadata
def extract_all_metadata(base_url, headers):
    all_metadata = []
    limit = 200
    offset = 0

    while True:
        # Fetch the list of studies with pagination
        studies_url = f"{base_url}/studies"
        studies_response = requests.get(studies_url, params={"limit": limit, "offset": offset}, headers=headers)
        if studies_response.status_code == 204:
            break
        if studies_response.status_code != 200:
            print(f"Error fetching studies: {studies_response.status_code}")
            break
        studies = studies_response.json()

        # Loop through each study and fetch series within it
        for study in studies:
            study_uid = study['0020000D']['Value'][0]

            # Endpoint for fetching series within a study; adjust as needed
            series_url = f"{base_url}/studies/{study_uid}/series"
            
            # Fetch the list of series in the current study
            series_response = requests.get(series_url, headers=headers)
            if series_response.status_code == 200:
                series_list = series_response.json()

                # Extract metadata for each series and add to the list
                for series in series_list:
                    series_uid = series['0020000E']['Value'][0]  # Adjust based on actual response format
                    series_metadata = fetch_series_metadata(base_url, study_uid, series_uid, headers)
                    if series_metadata:
                        metadata_record = {"StudyUID": study_uid, "SeriesUID": series_uid, "Metadata": series_metadata}
                        all_metadata.append(metadata_record)

        # Update offset for next batch of studies
        offset += limit

    # Convert the list of records to a DataFrame
    return pd.DataFrame(all_metadata)

# %%
headers = {
    'Authorization': 'Bearer ' + bearer_token,
    'Accept': 'application/dicom+json'
}
base_dicomweb_url = 'https://imgextpoc-adnidicom.dicom.azurehealthcareapis.com/v2'

metadata_df = extract_all_metadata(base_dicomweb_url, headers)
metadata_df.shape
# Out:
# (4756, 3)

# %%
metadata_df['Metadata'].iloc[0]
# Out:
# [{'00080005': {'vr': 'CS', 'Value': ['ISO_IR 100']},
#   '00080008': {'vr': 'CS',
#    'Value': ['ORIGINAL', 'PRIMARY', 'M', 'NORM', 'DIS3D', 'DIS2D']},
#   '00080013': {'vr': 'TM', 'Value': ['132059.900000']},
#   '00080016': {'vr': 'UI', 'Value': ['1.2.840.10008.5.1.4.1.1.4']},
#   '00080018': {'vr': 'UI',
#    'Value': ['2.16.124.113543.6006.99.02372564384492529391']},
#   '00080020': {'vr': 'DA', 'Value': ['20171204']},
#   '00080021': {'vr': 'DA', 'Value': ['20171204']},
#   '00080022': {'vr': 'DA', 'Value': ['20171204']},
#   '00080023': {'vr': 'DA', 'Value': ['20171204']},
#   '00080030': {'vr': 'TM', 'Value': ['131221.208000']},
#   '00080031': {'vr': 'TM', 'Value': ['132059.809000']},
#   '00080032': {'vr': 'TM', 'Value': ['131544.167500']},
#   '00080033': {'vr': 'TM', 'Value': ['132059.900000']},
#   '00080060': {'vr': 'CS', 'Value': ['MR']},
#   '00080070': {'vr': 'LO', 'Value': ['SIEMENS']},
#   '00080080': {'vr': 'LO', 'Value': ['UK_MRISC']},
#   '00080090': {'vr': 'PN'},
#   '00081030': {'vr': 'LO',
#    'Value': ['ADNI3 Advanced Prisma_20171012^ADNI3 Advanced']},
#   '0008103E': {'vr': 'LO', 'Value': ['Accelerated Sagittal MPRAGE']},
#   '00081060': {'vr': 'PN'},
#   '00081070': {'vr': 'PN'},
#   '00081090': {'vr': 'LO', 'Value': ['Prisma_fit']},
#   '00081140': {'vr': 'SQ',
#    'Value': [{'00081150': {'vr': 'UI',
#       'Value': ['2.16.124.113543.6006.99.4332567756067262732']},
#      '00081155': {'vr': 'UI',
#       'Value': ['2.16.124.113543.6006.99.02829738204357452305']}},
#     {'00081150': {'vr': 'UI',
#       'Value': ['2.16.124.113543.6006.99.4332567756067262732']},
#      '00081155': {'vr': 'UI',
#       'Value': ['2.16.124.113543.6006.99.06419417214655249292']}},
#     {'00081150': {'vr': 'UI',
#       'Value': ['2.16.124.113543.6006.99.4332567756067262732']},
#      '00081155': {'vr': 'UI',
#       'Value': ['2.16.124.113543.6006.99.6070339646949409874']}}]},
#   '00100010': {'vr': 'PN', 'Value': [{'Alphabetic': '023_S_4448'}]},
#   '00100020': {'vr': 'LO', 'Value': ['023_S_4448']},
#   '00100040': {'vr': 'CS', 'Value': ['F']},
#   '00101010': {'vr': 'AS', 'Value': ['069Y']},
#   '00101020': {'vr': 'DS', 'Value': [1.6256032533333]},
#   '00101030': {'vr': 'DS', 'Value': [86.6361536907]},
#   '00180015': {'vr': 'CS', 'Value': ['BRAIN']},
#   '00180020': {'vr': 'CS', 'Value': ['GR', 'IR']},
#   '00180021': {'vr': 'CS', 'Value': ['SK', 'SP', 'MP']},
#   '00180022': {'vr': 'CS', 'Value': ['IR']},
#   '00180023': {'vr': 'CS', 'Value': ['3D']},
#   '00180024': {'vr': 'SH', 'Value': ['*tfl3d1_16ns']},
#   '00180025': {'vr': 'CS', 'Value': ['N']},
#   '00180050': {'vr': 'DS', 'Value': [1]},
#   '00180080': {'vr': 'DS', 'Value': [2300]},
#   '00180081': {'vr': 'DS', 'Value': [2.98]},
#   '00180082': {'vr': 'DS', 'Value': [900]},
#   '00180083': {'vr': 'DS', 'Value': [1]},
#   '00180084': {'vr': 'DS', 'Value': [123.233299]},
#   '00180085': {'vr': 'SH', 'Value': ['1H']},
#   '00180086': {'vr': 'IS', 'Value': [1]},
#   '00180087': {'vr': 'DS', 'Value': [3]},
#   '00180089': {'vr': 'IS', 'Value': [239]},
#   '00180091': {'vr': 'IS', 'Value': [1]},
#   '00180093': {'vr': 'DS', 'Value': [100]},
#   '00180094': {'vr': 'DS', 'Value': [93.75]},
#   '00180095': {'vr': 'DS', 'Value': [240]},
#   '00181000': {'vr': 'LO', 'Value': ['4fSEItLMt9_o']},
#   '00181020': {'vr': 'LO', 'Value': ['syngo MR E11']},
#   '00181030': {'vr': 'LO', 'Value': ['Accelerated Sagittal MPRAGE']},
#   '00181251': {'vr': 'SH', 'Value': ['Body']},
#   '00181310': {'vr': 'US', 'Value': [0, 256, 240, 0]},
#   '00181312': {'vr': 'CS', 'Value': ['ROW']},
#   '00181314': {'vr': 'DS', 'Value': [9]},
#   '00181315': {'vr': 'CS', 'Value': ['N']},
#   '00181316': {'vr': 'DS', 'Value': [0.07163282872198]},
#   '00181318': {'vr': 'DS', 'Value': [0]},
#   '00185100': {'vr': 'CS', 'Value': ['HFS']},
#   '00190010': {'vr': 'LO', 'Value': ['SIEMENS MR HEADER']},
#   '00191008': {'vr': 'CS', 'Value': ['IMAGE NUM 4']},
#   '0019100B': {'vr': 'DS', 'Value': [309680]},
#   '00191012': {'vr': 'SL', 'Value': [0, 0, -1275]},
#   '00191013': {'vr': 'SL', 'Value': [0, 0, -1289]},
#   '00191014': {'vr': 'IS', 'Value': [0, 0, -14]},
#   '00191015': {'vr': 'FD', 'Value': [-61.5, -138, 128]},
#   '00191017': {'vr': 'DS', 'Value': [1]},
#   '00191018': {'vr': 'IS', 'Value': [8200]},
#   '0020000D': {'vr': 'UI',
#    'Value': ['2.16.124.113543.6006.99.01060096421826160662']},
#   '0020000E': {'vr': 'UI',
#    'Value': ['2.16.124.113543.6006.99.06083117774660962009']},
#   '00200010': {'vr': 'SH', 'Value': ['1']},
#   '00200011': {'vr': 'IS', 'Value': [2]},
#   '00200012': {'vr': 'IS', 'Value': [1]},
#   '00200013': {'vr': 'IS', 'Value': [43]},
#   '00200032': {'vr': 'DS', 'Value': [-61.5, -138, 114]},
#   '00200037': {'vr': 'DS', 'Value': [0, 1, 0, 0, 0, -1]},
#   '00200052': {'vr': 'UI',
#    'Value': ['2.16.124.113543.6006.99.7046172613500226468']},
#   '00201040': {'vr': 'LO'},
#   '00201041': {'vr': 'DS', 'Value': [-61.5]},
#   '00280002': {'vr': 'US', 'Value': [1]},
#   '00280004': {'vr': 'CS', 'Value': ['MONOCHROME2']},
#   '00280010': {'vr': 'US', 'Value': [256]},
#   '00280011': {'vr': 'US', 'Value': [240]},
#   '00280030': {'vr': 'DS', 'Value': [1, 1]},
#   '00280100': {'vr': 'US', 'Value': [16]},
#   '00280101': {'vr': 'US', 'Value': [12]},
#   '00280102': {'vr': 'US', 'Value': [11]},
#   '00280103': {'vr': 'US', 'Value': [0]},
#   '00280106': {'vr': 'US', 'Value': [0]},
#   '00280107': {'vr': 'US', 'Value': [620]},
#   '00281050': {'vr': 'DS', 'Value': [380]},
#   '00281051': {'vr': 'DS', 'Value': [810]},
#   '00291008': {'vr': 'CS', 'Value': ['IMAGE NUM 4']},
#   '00291018': {'vr': 'CS', 'Value': ['MR']},
#   '00400245': {'vr': 'TM', 'Value': ['131221.296000']},
#   '00511008': {'vr': 'CS', 'Value': ['IMAGE NUM 4']},
#   '00511016': {'vr': 'LO', 'Value': ['p2 M/NORM/DIS3D']}}]

# %%
# metadata_df.to_pickle('./files/all_metadata.pkl')
# metadata_df = pd.read_pickle('./files/all_metadata.pkl')

# %%
metadata_df.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                       SeriesUID  \
# 0  2.16.124.113543.6006.99.06083117774660962009
# 1  2.16.124.113543.6006.99.06263494736769400825
# 2  2.16.124.113543.6006.99.06964874624365474765
# 3  2.16.124.113543.6006.99.07300304364963768908
# 4  2.16.124.113543.6006.99.08097639857522452001
#
#                                             Metadata
# 0  [{'00080005': {'vr': 'CS', 'Value': ['ISO_IR 1...
# 1  [{'00080005': {'vr': 'CS', 'Value': ['ISO_IR 1...
# 2  [{'00080005': {'vr': 'CS', 'Value': ['ISO_IR 1...
# 3  [{'00080005': {'vr': 'CS', 'Value': ['ISO_IR 1...
# 4  [{'00080005': {'vr': 'CS', 'Value': ['ISO_IR 1...

# %%
metadata_df.shape
# Out:
# (4756, 3)

# %%
# Function to flatten the nested dictionary of metadata
def flatten_metadata(row):
    flat_metadata = []
    for metadata_dict in row['Metadata']:
        for tag, attributes in metadata_dict.items():
            value = attributes.get('Value', None)
            if isinstance(value, list):
                value = ', '.join(str(v) for v in value)
            flat_metadata.append({
                'StudyUID': row['StudyUID'],
                'SeriesUID': row['SeriesUID'],
                'Tag': tag,
                'vr': attributes.get('vr', None),
                'Value': value
            })
    return flat_metadata

# Flatten the metadata DataFrame
flat_metadata_list = []
for index, row in metadata_df.iterrows():
    flat_metadata_list.extend(flatten_metadata(row))

flat_metadata_df = pd.DataFrame(flat_metadata_list)
flat_metadata_df.shape
# Out:
# (691224, 5)

# %%
flat_metadata_df.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                       SeriesUID       Tag  vr  \
# 0  2.16.124.113543.6006.99.06083117774660962009  00080005  CS
# 1  2.16.124.113543.6006.99.06083117774660962009  00080008  CS
# 2  2.16.124.113543.6006.99.06083117774660962009  00080013  TM
# 3  2.16.124.113543.6006.99.06083117774660962009  00080016  UI
# 4  2.16.124.113543.6006.99.06083117774660962009  00080018  UI
#
#                                           Value
# 0                                    ISO_IR 100
# 1      ORIGINAL, PRIMARY, M, NORM, DIS3D, DIS2D
# 2                                 132059.900000
# 3                     1.2.840.10008.5.1.4.1.1.4
# 4  2.16.124.113543.6006.99.02372564384492529391

# %%
# flat_metadata_df.to_pickle('./files/ADNI/all_metadata_long.pkl')

# %%
# import pandas as pd
# flat_metadata_df = pd.read_pickle('./files/ADNI/all_metadata_long.pkl')

# %%
print(flat_metadata_df.shape)
flat_metadata_df.head()
# Out:
# (691224, 5)
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                       SeriesUID       Tag  vr  \
# 0  2.16.124.113543.6006.99.06083117774660962009  00080005  CS
# 1  2.16.124.113543.6006.99.06083117774660962009  00080008  CS
# 2  2.16.124.113543.6006.99.06083117774660962009  00080013  TM
# 3  2.16.124.113543.6006.99.06083117774660962009  00080016  UI
# 4  2.16.124.113543.6006.99.06083117774660962009  00080018  UI
#
#                                           Value
# 0                                    ISO_IR 100
# 1      ORIGINAL, PRIMARY, M, NORM, DIS3D, DIS2D
# 2                                 132059.900000
# 3                     1.2.840.10008.5.1.4.1.1.4
# 4  2.16.124.113543.6006.99.02372564384492529391

# %%
flat_metadata_df['SeriesUID'].nunique()
# Out:
# 4756

# %%
sql = 'select * from dbo.image_occurrence'
image_occurrence = pd.read_sql_query(sql, conn)
image_occurrence.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_56590/3004886460.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   image_occurrence = pd.read_sql_query(sql, conn)
#    image_occurrence_id  person_id  procedure_occurrence_id  \
# 0                    1       2161                        1
# 1                    2       2161                        1
# 2                    3       2161                        1
# 3                    4       2161                        1
# 4                    5       2161                        1
#
#    visit_occurrence_id  anatomic_site_concept_id  \
# 0                   26                   4119359
# 1                   26                   4119359
# 2                   26                   4119359
# 3                   26                   4119359
# 4                   26                   4119359
#
#                                           wadors_uri local_path  \
# 0  https://imgextpoc-adnidicom.dicom.azurehealthc...       None
# 1  https://imgextpoc-adnidicom.dicom.azurehealthc...       None
# 2  https://imgextpoc-adnidicom.dicom.azurehealthc...       None
# 3  https://imgextpoc-adnidicom.dicom.azurehealthc...       None
# 4  https://imgextpoc-adnidicom.dicom.azurehealthc...       None
#
#   image_occurrence_date                               image_study_uid  \
# 0            2017-12-04  2.16.124.113543.6006.99.01060096421826160662
# 1            2017-12-04  2.16.124.113543.6006.99.01060096421826160662
# 2            2017-12-04  2.16.124.113543.6006.99.01060096421826160662
# 3            2017-12-04  2.16.124.113543.6006.99.01060096421826160662
# 4            2017-12-04  2.16.124.113543.6006.99.01060096421826160662
#
#                                image_series_uid  modality_concept_id
# 0  2.16.124.113543.6006.99.06083117774660962009              4013636
# 1  2.16.124.113543.6006.99.06263494736769400825              4013636
# 2  2.16.124.113543.6006.99.06964874624365474765              4013636
# 3  2.16.124.113543.6006.99.07300304364963768908              4013636
# 4  2.16.124.113543.6006.99.08097639857522452001              4013636

# %%
image_occurrence.shape
# Out:
# (4756, 11)

# %%
sql_query = "SELECT * FROM dbo.concept"
concept_df = pd.read_sql_query(sql_query, conn)
concept_df.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_56590/959860308.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   concept_df = pd.read_sql_query(sql_query, conn)
#    concept_id   concept_name  domain_id vocabulary_id concept_class_id  \
# 0    41886036         Kyogle  Geography           OSM       10th level
# 1    41886037       Kyvalley  Geography           OSM       10th level
# 2    41886038          Laang  Geography           OSM       10th level
# 3    41886039     Lake Bolac  Geography           OSM       10th level
# 4    41886040  Lake Brewster  Geography           OSM       10th level
#
#   standard_concept concept_code valid_start_date valid_end_date invalid_reason
# 0                S      6069960       1970-01-01     2099-12-31
# 1                S      2504902       1970-01-01     2099-12-31
# 2                S      3155973       1970-01-01     2099-12-31
# 3                S      3153764       1970-01-01     2099-12-31
# 4                S      5816798       1970-01-01     2099-12-31

# %%
metadata_omop = flat_metadata_df.merge(concept_df[concept_df['vocabulary_id']=="DICOM"][['concept_id', 'concept_code', 'concept_name']], how = 'left', left_on = 'Tag', right_on = 'concept_code')
print(metadata_omop.shape)
metadata_omop.head()
# Out:
# (691224, 8)
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                       SeriesUID       Tag  vr  \
# 0  2.16.124.113543.6006.99.06083117774660962009  00080005  CS
# 1  2.16.124.113543.6006.99.06083117774660962009  00080008  CS
# 2  2.16.124.113543.6006.99.06083117774660962009  00080013  TM
# 3  2.16.124.113543.6006.99.06083117774660962009  00080016  UI
# 4  2.16.124.113543.6006.99.06083117774660962009  00080018  UI
#
#                                           Value    concept_id concept_code  \
# 0                                    ISO_IR 100  2.128000e+09     00080005
# 1      ORIGINAL, PRIMARY, M, NORM, DIS3D, DIS2D  2.128000e+09     00080008
# 2                                 132059.900000  2.128000e+09     00080013
# 3                     1.2.840.10008.5.1.4.1.1.4           NaN          NaN
# 4  2.16.124.113543.6006.99.02372564384492529391           NaN          NaN
#
#              concept_name
# 0  Specific Character Set
# 1              Image Type
# 2  Instance Creation Time
# 3                     NaN
# 4                     NaN

# %%
metadata_omop['concept_id'] = metadata_omop['concept_id'].astype('Int64')

# %%
tags_for_columns = ["00080020", "0020000D", "0020000E", "0008060", "00180015"]
metadata_omop[metadata_omop['Tag'].isin(tags_for_columns)].groupby('concept_name')['SeriesUID'].nunique()
# Out:
# concept_name
# Body Part Examined    3987
# Study Date            4756
# Name: SeriesUID, dtype: int64

# %%
metadata_omop[~metadata_omop['concept_id'].isna()].shape #296396 ~43%
# Out:
# (296396, 8)

# %%
metadata_omop_tag_counts = metadata_omop[~metadata_omop['concept_id'].isna()][['concept_name', 'vr']].value_counts()
metadata_omop_tag_counts
# Out:
# concept_name                         vr
# Photometric Interpretation           CS    4756
# Bits Stored                          US    4756
# Series Number                        IS    4756
# Series Date                          DA    4756
# Study Date                           DA    4756
#                                            ...
# Partial Fourier Direction            CS      14
# Spatial Pre-saturation               CS      14
# Specific Absorption Rate Definition  CS      14
# Parallel Acquisition Technique       CS      14
# VOI LUT Function                     CS       2
# Name: count, Length: 174, dtype: int64

# %%
import matplotlib.pyplot as plt

# Filter out rows where 'concept_id' is NaN
filtered_metadata = metadata_omop[~metadata_omop['concept_id'].isna()]

# Get the number of concept_ids per SeriesUID
concepts_per_series = filtered_metadata['SeriesUID'].value_counts()

# Plotting the histogram
plt.figure(figsize=(8, 5))
plt.hist(concepts_per_series, bins=20, edgecolor='black', color='grey')
plt.xlabel('# of concept_ids', fontsize=18)
plt.ylabel('# of Imaging Series', fontsize=18)
plt.tight_layout()

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Show the plot
plt.show()

# %%
filtered_metadata_agg = filtered_metadata.groupby(['SeriesUID', 'Tag'])['Value'].count().reset_index()

# %%
filtered_metadata_agg[filtered_metadata_agg['Value']>1] # no duplicated data
# Out:
# Empty DataFrame
# Columns: [SeriesUID, Tag, Value]
# Index: []

# %%
filtered_metadata.shape
# Out:
# (296396, 8)

# %%
filtered_metadata.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 5  2.16.124.113543.6006.99.01060096421826160662
# 6  2.16.124.113543.6006.99.01060096421826160662
#
#                                       SeriesUID       Tag  vr  \
# 0  2.16.124.113543.6006.99.06083117774660962009  00080005  CS
# 1  2.16.124.113543.6006.99.06083117774660962009  00080008  CS
# 2  2.16.124.113543.6006.99.06083117774660962009  00080013  TM
# 5  2.16.124.113543.6006.99.06083117774660962009  00080020  DA
# 6  2.16.124.113543.6006.99.06083117774660962009  00080021  DA
#
#                                       Value  concept_id concept_code  \
# 0                                ISO_IR 100  2128000011     00080005
# 1  ORIGINAL, PRIMARY, M, NORM, DIS3D, DIS2D  2128000012     00080008
# 2                             132059.900000  2128000014     00080013
# 5                                  20171204  2128000017     00080020
# 6                                  20171204  2128000018     00080021
#
#              concept_name
# 0  Specific Character Set
# 1              Image Type
# 2  Instance Creation Time
# 5              Study Date
# 6             Series Date

# %%
print(filtered_metadata[~filtered_metadata['vr'].isin(['CS', 'SQ'])].shape)
filtered_metadata[~filtered_metadata['vr'].isin(['CS', 'SQ'])]['vr'].unique()
# Out:
# (220851, 8)
# array(['TM', 'DA', 'DS', 'IS', 'US', 'UL', 'FL', 'FD'], dtype=object)

# %%
filtered_metadata[filtered_metadata['vr'].isin(['CS'])].shape
# Out:
# (70312, 8)

# %%
filtered_metadata[filtered_metadata['vr'].isin(['SQ'])].shape
# Out:
# (5233, 8)

# %%
filtered_metadata_value_concepts = filtered_metadata[filtered_metadata['vr'].isin(['SQ', 'CS'])].merge(concept_df[concept_df['vocabulary_id']=="DICOM"][['concept_id','concept_name', 'concept_class_id', 'concept_code']],
                                                                    how = 'inner', left_on = 'Value', right_on = 'concept_code')

# %%
print(filtered_metadata_value_concepts.shape)
filtered_metadata_value_concepts.head()
# Out:
# (23628, 12)
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                       SeriesUID       Tag  vr  Value  \
# 0  2.16.124.113543.6006.99.06083117774660962009  00080060  CS     MR
# 1  2.16.124.113543.6006.99.06083117774660962009  00080060  CS     MR
# 2  2.16.124.113543.6006.99.06083117774660962009  00100040  CS      F
# 3  2.16.124.113543.6006.99.06083117774660962009  00180015  CS  BRAIN
# 4  2.16.124.113543.6006.99.06083117774660962009  00185100  CS    HFS
#
#    concept_id_x concept_code_x      concept_name_x  concept_id_y  \
# 0    2128000035       00080060            Modality    2128007813
# 1    2128000035       00080060            Modality    2128015329
# 2    2128000110       00100040       Patient's Sex    2128008067
# 3    2128000419       00180015  Body Part Examined    2128021455
# 4    2128000656       00185100    Patient Position    2128015375
#
#        concept_name_y  concept_class_id concept_code_y
# 0  Magnetic Resonance  DICOM Value Sets             MR
# 1  Magnetic Resonance  DICOM Value Sets             MR
# 2              Female  DICOM Value Sets              F
# 3               Brain  DICOM Value Sets          BRAIN
# 4   Head First-Supine  DICOM Value Sets            HFS

# %%
filtered_metadata_value_concepts['vr'].unique()
# Out:
# array(['CS'], dtype=object)

# %%
filtered_metadata_value_concepts['Value'].unique()
# Out:
# array(['MR', 'F', 'BRAIN', 'HFS', 'M', 'YES', '00', 'IDENTITY', 'FC',
#        'MP', 'NO', 'HEAD', 'U', 'RF'], dtype=object)

# %%
filtered_metadata_value_concepts_2 = filtered_metadata[filtered_metadata['vr'].isin(['SQ', 'CS'])].merge(concept_df[concept_df['vocabulary_id']=="DICOM"][['concept_id','concept_name', 'concept_class_id', 'concept_code']],
                                                                    how = 'inner', left_on = 'Value', right_on = 'concept_name')

# %%
filtered_metadata_value_concepts_2['vr'].unique()
# Out:
# array(['CS'], dtype=object)

# %%
filtered_metadata_value_concepts_2['Value'].unique()
# Out:
# array(['YES', 'NO', 'T2', 'T1'], dtype=object)

# %%
print(filtered_metadata_value_concepts_2[filtered_metadata_value_concepts_2['Value'].isin(['T1', 'T2'])].shape)
filtered_metadata_value_concepts_2[filtered_metadata_value_concepts_2['Value'].isin(['T1', 'T2'])]
# Out:
# (10, 12)
#                                         StudyUID  \
# 757  2.16.124.113543.6006.99.3039848631234787108
# 798  2.16.124.113543.6006.99.3039848631234787108
# 813  2.16.124.113543.6006.99.3039848631234787108
# 827  2.16.124.113543.6006.99.3039848631234787108
# 841  2.16.124.113543.6006.99.3039848631234787108
# 855  2.16.124.113543.6006.99.5698286738096659481
# 883  2.16.124.113543.6006.99.5698286738096659481
# 897  2.16.124.113543.6006.99.5698286738096659481
# 925  2.16.124.113543.6006.99.5698286738096659481
# 939  2.16.124.113543.6006.99.5698286738096659481
#
#                                         SeriesUID       Tag  vr Value  \
# 757  2.16.124.113543.6006.99.05215371343327173270  00089209  CS    T2
# 798    2.16.124.113543.6006.99.258040664557153924  00089209  CS    T2
# 813   2.16.124.113543.6006.99.4533573098452166998  00089209  CS    T1
# 827   2.16.124.113543.6006.99.4727363446261692447  00089209  CS    T1
# 841   2.16.124.113543.6006.99.5096538296447717059  00089209  CS    T1
# 855  2.16.124.113543.6006.99.01094226193701545372  00089209  CS    T2
# 883   2.16.124.113543.6006.99.4681696419934256382  00089209  CS    T1
# 897   2.16.124.113543.6006.99.5886840576788364063  00089209  CS    T2
# 925   2.16.124.113543.6006.99.6449055810808824420  00089209  CS    T1
# 939   2.16.124.113543.6006.99.8814379233236481704  00089209  CS    T1
#
#      concept_id_x concept_code_x        concept_name_x  concept_id_y  \
# 757    2128000101       00089209  Acquisition Contrast    2128007656
# 798    2128000101       00089209  Acquisition Contrast    2128007656
# 813    2128000101       00089209  Acquisition Contrast    2128007654
# 827    2128000101       00089209  Acquisition Contrast    2128007654
# 841    2128000101       00089209  Acquisition Contrast    2128007654
# 855    2128000101       00089209  Acquisition Contrast    2128007656
# 883    2128000101       00089209  Acquisition Contrast    2128007654
# 897    2128000101       00089209  Acquisition Contrast    2128007656
# 925    2128000101       00089209  Acquisition Contrast    2128007654
# 939    2128000101       00089209  Acquisition Contrast    2128007654
#
#     concept_name_y  concept_class_id concept_code_y
# 757             T2  DICOM Value Sets         113065
# 798             T2  DICOM Value Sets         113065
# 813             T1  DICOM Value Sets         113063
# 827             T1  DICOM Value Sets         113063
# 841             T1  DICOM Value Sets         113063
# 855             T2  DICOM Value Sets         113065
# 883             T1  DICOM Value Sets         113063
# 897             T2  DICOM Value Sets         113065
# 925             T1  DICOM Value Sets         113063
# 939             T1  DICOM Value Sets         113063

# %%
omop_value_not_found_cs = filtered_metadata[(filtered_metadata['vr']=='CS') & 
                                            (~filtered_metadata['Value'].isin(['MR', 'F', 'BRAIN', 'HFS', 'M', 'YES', '00', 'IDENTITY', 'FC','MP', 'NO', 'HEAD', 'U', 'RF', 'T2', 'T1']))
                                            ][['Tag', 'concept_name', 'Value']].drop_duplicates().reset_index(drop=True)
print(omop_value_not_found_cs.shape)
omop_value_not_found_cs.head()
# Out:
# (173, 3)
#         Tag            concept_name                                     Value
# 0  00080005  Specific Character Set                                ISO_IR 100
# 1  00080008              Image Type  ORIGINAL, PRIMARY, M, NORM, DIS3D, DIS2D
# 2  00180020       Scanning Sequence                                    GR, IR
# 3  00180021        Sequence Variant                                SK, SP, MP
# 4  00180022            Scan Options                                        IR

# %%
omop_value_not_found_cs['Tag'].nunique()
# Out:
# 57

# %%
# none, missing
# multiple values
# missing single values
print("Value missing:", omop_value_not_found_cs[(omop_value_not_found_cs['Value'].isna()) | (omop_value_not_found_cs['Value']=="NONE")].shape)
print("Multiple values:",omop_value_not_found_cs[(~omop_value_not_found_cs['Value'].isna()) & (omop_value_not_found_cs['Value'].str.contains(','))].shape)
# 173-28-82=63 missing single values
# Out:
# Value missing: (28, 3)
# Multiple values: (82, 3)

# %%
filtered_metadata_SQ = filtered_metadata[filtered_metadata['vr']=='SQ'].groupby(['Tag', 'concept_name', 'Value']).agg(counts=('Value', len)).reset_index()
filtered_metadata_SQ
# Out:
#           Tag                            concept_name  \
# 0    00081032                 Procedure Code Sequence
# 1    00081032                 Procedure Code Sequence
# 2    00082218                Anatomic Region Sequence
# 3    00082218                Anatomic Region Sequence
# 4    00120064  De-identification Method Code Sequence
# ..        ...                                     ...
# 375  00409096       Real World Value Mapping Sequence
# 376  00409096       Real World Value Mapping Sequence
# 377  00409096       Real World Value Mapping Sequence
# 378  00409096       Real World Value Mapping Sequence
# 379  00409096       Real World Value Mapping Sequence
#
#                                                  Value  counts
# 0           {'0008010B': {'vr': 'CS', 'Value': ['N']}}     406
# 1                                                   {}    1362
# 2    {'00080100': {'vr': 'SH', 'Value': ['T-A0100']...     282
# 3    {'00080100': {'vr': 'SH', 'Value': ['T-D1100']...      17
# 4                           {}, {}, {}, {}, {}, {}, {}      70
# ..                                                 ...     ...
# 375  {'00409224': {'vr': 'FD', 'Value': [0]}, '0040...       1
# 376  {'00409224': {'vr': 'FD', 'Value': [0]}, '0040...       1
# 377  {'00409224': {'vr': 'FD', 'Value': [0]}, '0040...       1
# 378  {'00409224': {'vr': 'FD', 'Value': [0]}, '0040...       1
# 379  {'00409224': {'vr': 'FD', 'Value': [0]}, '0040...       1
#
# [380 rows x 4 columns]

# %%
filtered_metadata[filtered_metadata['vr']=='SQ']['Tag'].unique()
# Out:
# array(['00081032', '00400275', '00409096', '00120064', '00082218',
#        '00400260'], dtype=object)

# %%
filtered_metadata[filtered_metadata['vr'].isin(['CS'])].shape
# Out:
# (70312, 8)

# %%
# after the investigation, we decide to add only CS codes that matched using Value and Concept_code
new_image_features = filtered_metadata[filtered_metadata['vr'].isin(['CS'])].merge(concept_df[concept_df['vocabulary_id']=="DICOM"][['concept_id','concept_name', 'concept_class_id', 'concept_code']],
                                                                    how = 'left', left_on = 'Value', right_on = 'concept_code')

# %%
new_image_features.shape
# Out:
# (70312, 12)

# %%
new_image_features_non_cs = filtered_metadata[~filtered_metadata['vr'].isin(['CS', 'SQ'])]
new_image_features_non_cs = new_image_features_non_cs.rename(columns={'concept_id': 'concept_id_x',
                                                                      'concept_name': 'concept_name_x',
                                                                      'concept_code': 'concept_code_x'})
print(new_image_features_non_cs.shape)
new_image_features_non_cs.head()
# Out:
# (220851, 8)
#                                        StudyUID  \
# 2  2.16.124.113543.6006.99.01060096421826160662
# 5  2.16.124.113543.6006.99.01060096421826160662
# 6  2.16.124.113543.6006.99.01060096421826160662
# 7  2.16.124.113543.6006.99.01060096421826160662
# 8  2.16.124.113543.6006.99.01060096421826160662
#
#                                       SeriesUID       Tag  vr          Value  \
# 2  2.16.124.113543.6006.99.06083117774660962009  00080013  TM  132059.900000
# 5  2.16.124.113543.6006.99.06083117774660962009  00080020  DA       20171204
# 6  2.16.124.113543.6006.99.06083117774660962009  00080021  DA       20171204
# 7  2.16.124.113543.6006.99.06083117774660962009  00080022  DA       20171204
# 8  2.16.124.113543.6006.99.06083117774660962009  00080023  DA       20171204
#
#    concept_id_x concept_code_x          concept_name_x
# 2    2128000014       00080013  Instance Creation Time
# 5    2128000017       00080020              Study Date
# 6    2128000018       00080021             Series Date
# 7    2128000019       00080022        Acquisition Date
# 8    2128000020       00080023            Content Date

# %%
new_image_features = pd.concat([new_image_features, new_image_features_non_cs])
new_image_features['concept_id_y'] = new_image_features['concept_id_y'].astype('Int64')
new_image_features
# Out:
#                                             StudyUID  \
# 0       2.16.124.113543.6006.99.01060096421826160662
# 1       2.16.124.113543.6006.99.01060096421826160662
# 2       2.16.124.113543.6006.99.01060096421826160662
# 3       2.16.124.113543.6006.99.01060096421826160662
# 4       2.16.124.113543.6006.99.01060096421826160662
# ...                                              ...
# 691213   2.16.124.113543.6006.99.9223169425485824208
# 691214   2.16.124.113543.6006.99.9223169425485824208
# 691215   2.16.124.113543.6006.99.9223169425485824208
# 691216   2.16.124.113543.6006.99.9223169425485824208
# 691222   2.16.124.113543.6006.99.9223169425485824208
#
#                                            SeriesUID       Tag  vr  \
# 0       2.16.124.113543.6006.99.06083117774660962009  00080005  CS
# 1       2.16.124.113543.6006.99.06083117774660962009  00080008  CS
# 2       2.16.124.113543.6006.99.06083117774660962009  00080060  CS
# 3       2.16.124.113543.6006.99.06083117774660962009  00100040  CS
# 4       2.16.124.113543.6006.99.06083117774660962009  00180015  CS
# ...                                              ...       ...  ..
# 691213    2.16.124.113543.6006.99.640768751323050122  00281050  DS
# 691214    2.16.124.113543.6006.99.640768751323050122  00281051  DS
# 691215    2.16.124.113543.6006.99.640768751323050122  00281052  DS
# 691216    2.16.124.113543.6006.99.640768751323050122  00281053  DS
# 691222    2.16.124.113543.6006.99.640768751323050122  00400245  TM
#
#                                            Value  concept_id_x concept_code_x  \
# 0                                     ISO_IR 100    2128000011       00080005
# 1       ORIGINAL, PRIMARY, M, NORM, DIS3D, DIS2D    2128000012       00080008
# 2                                             MR    2128000035       00080060
# 3                                              F    2128000110       00100040
# 4                                          BRAIN    2128000419       00180015
# ...                                          ...           ...            ...
# 691213                                      -126    2128001392       00281050
# 691214                                      5311    2128001393       00281051
# 691215                                     -4096    2128001394       00281052
# 691216                            2.000244140625    2128001395       00281053
# 691222                             133022.131000    2128001544       00400245
#
#                              concept_name_x  concept_id_y      concept_name_y  \
# 0                    Specific Character Set          <NA>                 NaN
# 1                                Image Type          <NA>                 NaN
# 2                                  Modality    2128007813  Magnetic Resonance
# 3                             Patient's Sex    2128008067              Female
# 4                        Body Part Examined    2128021455               Brain
# ...                                     ...           ...                 ...
# 691213                        Window Center          <NA>                 NaN
# 691214                         Window Width          <NA>                 NaN
# 691215                    Rescale Intercept          <NA>                 NaN
# 691216                        Rescale Slope          <NA>                 NaN
# 691222  Performed Procedure Step Start Time          <NA>                 NaN
#
#         concept_class_id concept_code_y
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2       DICOM Value Sets             MR
# 3       DICOM Value Sets              F
# 4       DICOM Value Sets          BRAIN
# ...                  ...            ...
# 691213               NaN            NaN
# 691214               NaN            NaN
# 691215               NaN            NaN
# 691216               NaN            NaN
# 691222               NaN            NaN
#
# [291163 rows x 12 columns]

# %%
new_image_features = new_image_features.merge(image_occurrence[['image_occurrence_id', 'person_id', 'image_series_uid', 'image_occurrence_date', 'anatomic_site_concept_id']], 
                         how = 'left', left_on = 'SeriesUID', right_on = 'image_series_uid')

# %%
# delete image_feature and measurement rows where image_feature_concept_id = concept_id and vocabulary_id = 'DICOM' and concept_class_id = 'DICOM Attributes'

# image_feature_event_field_id = 1147330
# image_feature_event_id = measurement_id
# image_feature_event_type_id = 32817

new_image_features['image_feature_event_field_id'] = 1147330
new_image_features['image_feature_event_type_id'] = 32817
new_image_features['image_feature_event_id'] = range(1, len(new_image_features)+1)
new_image_features.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                       SeriesUID       Tag  vr  \
# 0  2.16.124.113543.6006.99.06083117774660962009  00080005  CS
# 1  2.16.124.113543.6006.99.06083117774660962009  00080008  CS
# 2  2.16.124.113543.6006.99.06083117774660962009  00080060  CS
# 3  2.16.124.113543.6006.99.06083117774660962009  00100040  CS
# 4  2.16.124.113543.6006.99.06083117774660962009  00180015  CS
#
#                                       Value  concept_id_x concept_code_x  \
# 0                                ISO_IR 100    2128000011       00080005
# 1  ORIGINAL, PRIMARY, M, NORM, DIS3D, DIS2D    2128000012       00080008
# 2                                        MR    2128000035       00080060
# 3                                         F    2128000110       00100040
# 4                                     BRAIN    2128000419       00180015
#
#            concept_name_x  concept_id_y      concept_name_y  concept_class_id  \
# 0  Specific Character Set          <NA>                 NaN               NaN
# 1              Image Type          <NA>                 NaN               NaN
# 2                Modality    2128007813  Magnetic Resonance  DICOM Value Sets
# 3           Patient's Sex    2128008067              Female  DICOM Value Sets
# 4      Body Part Examined    2128021455               Brain  DICOM Value Sets
#
#   concept_code_y  image_occurrence_id  person_id  \
# 0            NaN                    1       2161
# 1            NaN                    1       2161
# 2             MR                    1       2161
# 3              F                    1       2161
# 4          BRAIN                    1       2161
#
#                                image_series_uid image_occurrence_date  \
# 0  2.16.124.113543.6006.99.06083117774660962009            2017-12-04
# 1  2.16.124.113543.6006.99.06083117774660962009            2017-12-04
# 2  2.16.124.113543.6006.99.06083117774660962009            2017-12-04
# 3  2.16.124.113543.6006.99.06083117774660962009            2017-12-04
# 4  2.16.124.113543.6006.99.06083117774660962009            2017-12-04
#
#    image_feature_event_field_id  image_feature_event_type_id  \
# 0                       1147330                        32817
# 1                       1147330                        32817
# 2                       1147330                        32817
# 3                       1147330                        32817
# 4                       1147330                        32817
#
#    anatomic_site_concept_id  image_feature_event_id
# 0                   4119359                       1
# 1                   4119359                       2
# 2                   4119359                       3
# 3                   4119359                       4
# 4                   4119359                       5

# %%
new_image_features['value_as_number'] = new_image_features.apply(lambda row: row['Value'] if row['vr'] != 'CS' else None, axis=1)
new_image_features['measurement_source_value'] = new_image_features['Value'].astype(str).str[:50]

# %%
new_image_features = new_image_features.where(pd.notnull(new_image_features), None)

# %%
new_image_features.columns
# Out:
# Index(['StudyUID', 'SeriesUID', 'Tag', 'vr', 'Value', 'concept_id_x',
#        'concept_code_x', 'concept_name_x', 'concept_id_y', 'concept_name_y',
#        'concept_class_id', 'concept_code_y', 'image_occurrence_id',
#        'person_id', 'image_series_uid', 'image_occurrence_date',
#        'image_feature_event_field_id', 'image_feature_event_type_id',
#        'anatomic_site_concept_id', 'image_feature_event_id',
#        'measurement_source_value'],
#       dtype='object')

# %%
new_image_features['value_as_number'] = pd.to_numeric(new_image_features['Value'], errors='coerce')
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#               ...
# 291158      -126.000000
# 291159      5311.000000
# 291160     -4096.000000
# 291161         2.000244
# 291162    133022.131000
# Name: value_as_number, Length: 291163, dtype: float64

# %%
new_image_features = new_image_features.where((pd.notnull(new_image_features)), None)
new_image_features.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                       SeriesUID       Tag  vr  \
# 0  2.16.124.113543.6006.99.06083117774660962009  00080005  CS
# 1  2.16.124.113543.6006.99.06083117774660962009  00080008  CS
# 2  2.16.124.113543.6006.99.06083117774660962009  00080060  CS
# 3  2.16.124.113543.6006.99.06083117774660962009  00100040  CS
# 4  2.16.124.113543.6006.99.06083117774660962009  00180015  CS
#
#                                       Value  concept_id_x concept_code_x  \
# 0                                ISO_IR 100    2128000011       00080005
# 1  ORIGINAL, PRIMARY, M, NORM, DIS3D, DIS2D    2128000012       00080008
# 2                                        MR    2128000035       00080060
# 3                                         F    2128000110       00100040
# 4                                     BRAIN    2128000419       00180015
#
#            concept_name_x  concept_id_y      concept_name_y  ...  \
# 0  Specific Character Set             0                None  ...
# 1              Image Type             0                None  ...
# 2                Modality    2128007813  Magnetic Resonance  ...
# 3           Patient's Sex    2128008067              Female  ...
# 4      Body Part Examined    2128021455               Brain  ...
#
#   image_occurrence_id person_id                              image_series_uid  \
# 0                   1      2161  2.16.124.113543.6006.99.06083117774660962009
# 1                   1      2161  2.16.124.113543.6006.99.06083117774660962009
# 2                   1      2161  2.16.124.113543.6006.99.06083117774660962009
# 3                   1      2161  2.16.124.113543.6006.99.06083117774660962009
# 4                   1      2161  2.16.124.113543.6006.99.06083117774660962009
#
#    image_occurrence_date image_feature_event_field_id  \
# 0             2017-12-04                      1147330
# 1             2017-12-04                      1147330
# 2             2017-12-04                      1147330
# 3             2017-12-04                      1147330
# 4             2017-12-04                      1147330
#
#   image_feature_event_type_id  anatomic_site_concept_id  \
# 0                       32817                   4119359
# 1                       32817                   4119359
# 2                       32817                   4119359
# 3                       32817                   4119359
# 4                       32817                   4119359
#
#    image_feature_event_id                  measurement_source_value  \
# 0                       1                                ISO_IR 100
# 1                       2  ORIGINAL, PRIMARY, M, NORM, DIS3D, DIS2D
# 2                       3                                        MR
# 3                       4                                         F
# 4                       5                                     BRAIN
#
#    value_as_number
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 22 columns]

# %%
new_image_features.to_pickle('./files/ADNI/image_series_metadata_v2.pkl')

# %%
# Update MEASUREMENT
sql = '''
    INSERT INTO dbo.measurement (measurement_id, person_id, measurement_concept_id, measurement_date, measurement_type_concept_id, value_as_number, value_as_concept_id, measurement_source_value, measurement_source_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
'''

# Define batch size
batch_size = 20000
batch = []

# Iterate through the DataFrame
for index, row in new_image_features.iterrows():
    # Append row data to the batch
    batch.append((
        row['image_feature_event_id'], 
        row['person_id'], 
        row['concept_id_x'], 
        row['image_occurrence_date'], 
        row['image_feature_event_type_id'], 
        row['value_as_number'], 
        row['concept_id_y'], 
        row['measurement_source_value'], 
        row['concept_id_x']
    ))

    # Check if batch size is reached or if it's the last row
    if len(batch) == batch_size or (index == len(new_image_features) - 1):
        # Execute the batch
        cursor.executemany(sql, batch)
        conn.commit()  # Commit after each batch
        batch = []  # Clear the batch for the next set of rows

cursor.close()
conn.close()

# %%
# Update IMAGE_FEATURE
sql = '''
    INSERT INTO dbo.image_feature (image_feature_id, person_id, image_occurrence_id, image_feature_event_id,
      image_feature_event_field_concept_id, image_feature_concept_id, image_feature_type_concept_id, anatomic_site_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
'''

# Define batch size
batch_size = 20000
batch = []

# Iterate through the DataFrame
for index, row in new_image_features.iterrows():
    # Append row data to the batch
    batch.append((row['image_feature_event_id'], row['person_id'], row['image_occurrence_id'], row['image_feature_event_id'], 
                  row['image_feature_event_field_id'], row['concept_id_x'], row['image_feature_event_type_id'],
                  row['anatomic_site_concept_id']))

    # Check if batch size is reached or if it's the last row
    if len(batch) == batch_size or (index == len(new_image_features) - 1):
        # Execute the batch
        cursor.executemany(sql, batch)
        conn.commit()  # Commit after each batch
        batch = []  # Clear the batch for the next set of rows

# Close the cursor and connection
cursor.close()
conn.close()

# %% [markdown]
# ## existing codes

# %%
# Pivot the DataFrame
df_wide = subset.pivot_table(
    index=['StudyUID', 'SeriesUID'],
    columns='concept_id',
    values='Value',
    aggfunc='first'
).reset_index()

# Flatten the columns
df_wide.columns.name = None
df_wide.columns = [str(col) for col in df_wide.columns]

df_wide.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01047543405701085685
# 1  2.16.124.113543.6006.99.01047543405701085685
# 2  2.16.124.113543.6006.99.01047543405701085685
# 3  2.16.124.113543.6006.99.01047543405701085685
# 4  2.16.124.113543.6006.99.01047543405701085685
#
#                                       SeriesUID 2128000366 2128000367  \
# 0  2.16.124.113543.6006.99.01296719744744407133        571       4.92
# 1  2.16.124.113543.6006.99.02054130675780820610        650         20
# 2  2.16.124.113543.6006.99.04611770930445736334        571       7.38
# 3   2.16.124.113543.6006.99.0701056875880124301       8020         50
# 4   2.16.124.113543.6006.99.1284958151862260961         20          5
#
#   2128000368
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df_wide['2128000366'] = df_wide['2128000366'].astype(float)
df_wide['2128000367'] = df_wide['2128000367'].astype(float)
df_wide['2128000368'] = df_wide['2128000368'].astype(float)

# %%
df_wide_subset = df_wide[(((df_wide['2128000368']>=800) & (df_wide['2128000368'] <=1100)) |(df_wide['2128000368']<500)) & 
(df_wide['2128000367'] < 10) & (((df_wide['2128000366'] >= 1500) & (df_wide['2128000366'] <= 2500)) | (df_wide['2128000366'] <10))]

# %%
df_wide_subset.to_csv('./files/rest_of_series_07252024.csv')

# %% [markdown]
# #### Gather DICOM attributes for Image Extension tables

# %%
# PTID 00100020
# StudyDate (00080020) v
# Acquisition Date (00080022) v
# Study Description (00081030) 
# Series Description (0008103E) 
# Modality (00080060)
# Body Part Examined (00180015)
# SOP Class UID (00080016) v
df_subset = flat_metadata_df[flat_metadata_df['Tag'].isin(['00100020', '00080020', '00080022', '00081030', '0008103E', '00080060', '00180015', '00080016'])]
df_subset = df_subset.pivot(index=['StudyUID', 'SeriesUID'], columns='Tag', values='Value').reset_index()
df_subset.columns.name = None
df_subset.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01047543405701085685
# 1  2.16.124.113543.6006.99.01047543405701085685
# 2  2.16.124.113543.6006.99.01047543405701085685
# 3  2.16.124.113543.6006.99.01047543405701085685
# 4  2.16.124.113543.6006.99.01047543405701085685
#
#                                       SeriesUID                   00080016  \
# 0  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
# 1  2.16.124.113543.6006.99.02054130675780820610  1.2.840.10008.5.1.4.1.1.4
# 2  2.16.124.113543.6006.99.04611770930445736334  1.2.840.10008.5.1.4.1.1.4
# 3   2.16.124.113543.6006.99.0701056875880124301  1.2.840.10008.5.1.4.1.1.4
# 4   2.16.124.113543.6006.99.1284958151862260961  1.2.840.10008.5.1.4.1.1.4
#
#    00080020  00080022 00080060                                 00081030  \
# 0  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 1  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 2  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 3  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 4  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
#
#              0008103E    00100020 00180015
# 0       Field Mapping  003_S_6260    BRAIN
# 1       Axial T2 STAR  003_S_6260    BRAIN
# 2       Field Mapping  003_S_6260    BRAIN
# 3  HighResHippocampus  003_S_6260    BRAIN
# 4   3 Plane Localizer  003_S_6260    BRAIN

# %%
df_subset.shape
# Out:
# (4756, 10)

# %%
df_id = pd.read_csv('./files/registry_idmap.csv')
df_id
# Out:
#         source_id  person_id source_name
# 0      011_S_0002          1        ADNI
# 1      022_S_0001          2        ADNI
# 2      011_S_0003          3        ADNI
# 3      022_S_0004          4        ADNI
# 4      011_S_0005          5        ADNI
# ...           ...        ...         ...
# 4147  037_S_10063       4148        ADNI
# 4148  941_S_10085       4149        ADNI
# 4149  037_S_10062       4150        ADNI
# 4150  007_S_10075       4151        ADNI
# 4151  033_S_10083       4152        ADNI
#
# [4152 rows x 3 columns]

# %%
df_subset = df_subset.merge(df_id[['source_id', 'person_id']], how = 'left', left_on = '00100020', right_on = 'source_id')

# %% [markdown]
# #### Inspect Body Part Examined

# %%
df_subset.groupby('00180015')['SeriesUID'].nunique().sort_values(ascending=False)
# Out:
# 00180015
# BRAIN        3484
# HEAD          403
# HEAD_NECK     100
# Name: SeriesUID, dtype: int64

# %%
part16 = pd.read_csv('./files/part16_fhir_valuesets.csv')

# %%
df_subset['00180015'] = df_subset['00180015'].str.lower()
part16['display'] = part16['display'].str.lower()

# %%
part16[part16['display'].isin(['brain', 'head_neck', 'head'])]['id'].unique()
# Out:
# array(['dicom-cid-4030-CTMRandPETAnatomyImaged',
#        'dicom-cid-4028-CraniofacialAnatomicRegion',
#        'dicom-cid-645-ExogenousSubstanceOriginTissue',
#        'dicom-cid-4042-XAXRFAnatomyImaged',
#        'dicom-cid-9514-AnatomicalStructureForRadiotherapy',
#        'dicom-cid-4031-CommonAnatomicRegion',
#        'dicom-cid-4-AnatomicRegion',
#        'dicom-cid-10044-RadiosensitiveOrgan',
#        'dicom-cid-7153-CNSSegmentationType',
#        'dicom-cid-7151-SegmentationPropertyType',
#        'dicom-cid-8134-AnatomicStructure',
#        'dicom-cid-4009-DXAnatomyImaged',
#        'dicom-cid-644-ExogenousSubstanceAdministrationSite',
#        'dicom-cid-10060-OrganForRadiationDoseEstimate',
#        'dicom-cid-7192-AnatomicalStructureSegmentationPropertyType'],
#       dtype=object)

# %%
part16[part16['display']=='head_neck']['id'].unique()
# Out:
# array([], dtype=object)

# %%
df_subset.merge(part16[['code', 'system', 'display']], how ='left', left_on = '00180015', right_on = 'display').head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01047543405701085685
# 1  2.16.124.113543.6006.99.01047543405701085685
# 2  2.16.124.113543.6006.99.01047543405701085685
# 3  2.16.124.113543.6006.99.01047543405701085685
# 4  2.16.124.113543.6006.99.01047543405701085685
#
#                                       SeriesUID                   00080016  \
# 0  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
# 1  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
# 2  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
# 3  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
# 4  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
#
#    00080020  00080022 00080060                                 00081030  \
# 0  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 1  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 2  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 3  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 4  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
#
#         0008103E    00100020 00180015   source_id  person_id      code  \
# 0  Field Mapping  003_S_6260    brain  003_S_6260       3339  12738006
# 1  Field Mapping  003_S_6260    brain  003_S_6260       3339  12738006
# 2  Field Mapping  003_S_6260    brain  003_S_6260       3339  12738006
# 3  Field Mapping  003_S_6260    brain  003_S_6260       3339  12738006
# 4  Field Mapping  003_S_6260    brain  003_S_6260       3339  12738006
#
#                    system display
# 0  http://snomed.info/sct   brain
# 1  http://snomed.info/sct   brain
# 2  http://snomed.info/sct   brain
# 3  http://snomed.info/sct   brain
# 4  http://snomed.info/sct   brain

# %% [markdown]
# #### Too variable. We will use brain 4119359 for all series.

# %%
df_subset['anatomic_site_concept_id'] = 4119359
df_subset['modality_concept_id'] = 4013636

# %%
df_subset.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01047543405701085685
# 1  2.16.124.113543.6006.99.01047543405701085685
# 2  2.16.124.113543.6006.99.01047543405701085685
# 3  2.16.124.113543.6006.99.01047543405701085685
# 4  2.16.124.113543.6006.99.01047543405701085685
#
#                                       SeriesUID                   00080016  \
# 0  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
# 1  2.16.124.113543.6006.99.02054130675780820610  1.2.840.10008.5.1.4.1.1.4
# 2  2.16.124.113543.6006.99.04611770930445736334  1.2.840.10008.5.1.4.1.1.4
# 3   2.16.124.113543.6006.99.0701056875880124301  1.2.840.10008.5.1.4.1.1.4
# 4   2.16.124.113543.6006.99.1284958151862260961  1.2.840.10008.5.1.4.1.1.4
#
#    00080020  00080022 00080060                                 00081030  \
# 0  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 1  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 2  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 3  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 4  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
#
#              0008103E    00100020 00180015   source_id  person_id  \
# 0       Field Mapping  003_S_6260    BRAIN  003_S_6260       3339
# 1       Axial T2 STAR  003_S_6260    BRAIN  003_S_6260       3339
# 2       Field Mapping  003_S_6260    BRAIN  003_S_6260       3339
# 3  HighResHippocampus  003_S_6260    BRAIN  003_S_6260       3339
# 4   3 Plane Localizer  003_S_6260    BRAIN  003_S_6260       3339
#
#    anatomic_site_concept_id  modality_concept_id
# 0                   4119359              4013636
# 1                   4119359              4013636
# 2                   4119359              4013636
# 3                   4119359              4013636
# 4                   4119359              4013636

# %%
print(df_subset[(df_subset['00080020'].isna()) & (df_subset['00080022'].isna())].shape) #missing both dates = 0
print(df_subset[(df_subset['00080020'].isna())].shape) #missing study date = 0
print(df_subset[(df_subset['00080022'].isna())].shape) #missing acquisition date = 106
# Out:
# (0, 14)
# (0, 14)
# (106, 14)

# %%
df_subset['image_occurrence_date'] = pd.to_datetime(df_subset['00080020'])
df_subset.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01047543405701085685
# 1  2.16.124.113543.6006.99.01047543405701085685
# 2  2.16.124.113543.6006.99.01047543405701085685
# 3  2.16.124.113543.6006.99.01047543405701085685
# 4  2.16.124.113543.6006.99.01047543405701085685
#
#                                       SeriesUID                   00080016  \
# 0  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
# 1  2.16.124.113543.6006.99.02054130675780820610  1.2.840.10008.5.1.4.1.1.4
# 2  2.16.124.113543.6006.99.04611770930445736334  1.2.840.10008.5.1.4.1.1.4
# 3   2.16.124.113543.6006.99.0701056875880124301  1.2.840.10008.5.1.4.1.1.4
# 4   2.16.124.113543.6006.99.1284958151862260961  1.2.840.10008.5.1.4.1.1.4
#
#    00080020  00080022 00080060                                 00081030  \
# 0  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 1  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 2  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 3  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 4  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
#
#              0008103E    00100020 00180015   source_id  person_id  \
# 0       Field Mapping  003_S_6260    BRAIN  003_S_6260       3339
# 1       Axial T2 STAR  003_S_6260    BRAIN  003_S_6260       3339
# 2       Field Mapping  003_S_6260    BRAIN  003_S_6260       3339
# 3  HighResHippocampus  003_S_6260    BRAIN  003_S_6260       3339
# 4   3 Plane Localizer  003_S_6260    BRAIN  003_S_6260       3339
#
#    anatomic_site_concept_id  modality_concept_id image_occurrence_date
# 0                   4119359              4013636            2019-07-09
# 1                   4119359              4013636            2019-07-09
# 2                   4119359              4013636            2019-07-09
# 3                   4119359              4013636            2019-07-09
# 4                   4119359              4013636            2019-07-09

# %%
df_subset['wadors_uri'] = 'https://imgextpoc-adnidicom.dicom.azurehealthcareapis.com/v2/studies/' + df_subset['StudyUID'] + '/series/' + df_subset['SeriesUID']
df_subset.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01047543405701085685
# 1  2.16.124.113543.6006.99.01047543405701085685
# 2  2.16.124.113543.6006.99.01047543405701085685
# 3  2.16.124.113543.6006.99.01047543405701085685
# 4  2.16.124.113543.6006.99.01047543405701085685
#
#                                       SeriesUID                   00080016  \
# 0  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
# 1  2.16.124.113543.6006.99.02054130675780820610  1.2.840.10008.5.1.4.1.1.4
# 2  2.16.124.113543.6006.99.04611770930445736334  1.2.840.10008.5.1.4.1.1.4
# 3   2.16.124.113543.6006.99.0701056875880124301  1.2.840.10008.5.1.4.1.1.4
# 4   2.16.124.113543.6006.99.1284958151862260961  1.2.840.10008.5.1.4.1.1.4
#
#    00080020  00080022 00080060                                 00081030  \
# 0  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 1  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 2  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 3  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 4  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
#
#              0008103E    00100020 00180015   source_id  person_id  \
# 0       Field Mapping  003_S_6260    BRAIN  003_S_6260       3339
# 1       Axial T2 STAR  003_S_6260    BRAIN  003_S_6260       3339
# 2       Field Mapping  003_S_6260    BRAIN  003_S_6260       3339
# 3  HighResHippocampus  003_S_6260    BRAIN  003_S_6260       3339
# 4   3 Plane Localizer  003_S_6260    BRAIN  003_S_6260       3339
#
#    anatomic_site_concept_id  modality_concept_id image_occurrence_date  \
# 0                   4119359              4013636            2019-07-09
# 1                   4119359              4013636            2019-07-09
# 2                   4119359              4013636            2019-07-09
# 3                   4119359              4013636            2019-07-09
# 4                   4119359              4013636            2019-07-09
#
#                                           wadors_uri
# 0  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 1  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 2  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 3  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 4  https://imgextpoc-adnidicom.dicom.azurehealthc...

# %%
df_subset.shape #(4756, 16)
# Out:
# (4756, 16)

# %%
image_occurrence_staging = pd.read_pickle('./files/image_occurrence_staging.pkl')
image_occurrence_staging.head()
# Out:
#                                       study_uid  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                      series_uid  person_id procedure_date  \
# 0  2.16.124.113543.6006.99.06083117774660962009       2161     2017-12-04
# 1  2.16.124.113543.6006.99.06263494736769400825       2161     2017-12-04
# 2  2.16.124.113543.6006.99.06964874624365474765       2161     2017-12-04
# 3  2.16.124.113543.6006.99.07300304364963768908       2161     2017-12-04
# 4  2.16.124.113543.6006.99.08097639857522452001       2161     2017-12-04
#
#    procedure_occurrence_id  image_occurrence_id  \
# 0                        1                    1
# 1                        1                    2
# 2                        1                    3
# 3                        1                    4
# 4                        1                    5
#
#                                           wadors_uri  \
# 0  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 1  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 2  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 3  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 4  https://imgextpoc-adnidicom.dicom.azurehealthc...
#
#    anatomic_site_concept_id  modality_concept_id  visit_occurrence_id  \
# 0                   4119359              4013636                   26
# 1                   4119359              4013636                   26
# 2                   4119359              4013636                   26
# 3                   4119359              4013636                   26
# 4                   4119359              4013636                   26
#
#    visit_concept_id visit_start_date visit_end_date  visit_type_concept_id
# 0              9202       2017-12-04     2017-12-04                  32817
# 1              9202       2017-12-04     2017-12-04                  32817
# 2              9202       2017-12-04     2017-12-04                  32817
# 3              9202       2017-12-04     2017-12-04                  32817
# 4              9202       2017-12-04     2017-12-04                  32817

# %%
image_occurrence_staging = image_occurrence_staging[['series_uid', 'procedure_date', 'procedure_occurrence_id','image_occurrence_id', 'visit_occurrence_id', 'visit_concept_id', 'visit_type_concept_id']].copy()

# %%
df_subset = df_subset.merge(image_occurrence_staging, how = 'left', left_on = 'SeriesUID', right_on = 'series_uid')

# %%
df_subset.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01047543405701085685
# 1  2.16.124.113543.6006.99.01047543405701085685
# 2  2.16.124.113543.6006.99.01047543405701085685
# 3  2.16.124.113543.6006.99.01047543405701085685
# 4  2.16.124.113543.6006.99.01047543405701085685
#
#                                       SeriesUID                   00080016  \
# 0  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
# 1  2.16.124.113543.6006.99.02054130675780820610  1.2.840.10008.5.1.4.1.1.4
# 2  2.16.124.113543.6006.99.04611770930445736334  1.2.840.10008.5.1.4.1.1.4
# 3   2.16.124.113543.6006.99.0701056875880124301  1.2.840.10008.5.1.4.1.1.4
# 4   2.16.124.113543.6006.99.1284958151862260961  1.2.840.10008.5.1.4.1.1.4
#
#    00080020  00080022 00080060                                 00081030  \
# 0  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 1  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 2  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 3  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 4  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
#
#              0008103E    00100020 00180015  ... modality_concept_id  \
# 0       Field Mapping  003_S_6260    BRAIN  ...             4013636
# 1       Axial T2 STAR  003_S_6260    BRAIN  ...             4013636
# 2       Field Mapping  003_S_6260    BRAIN  ...             4013636
# 3  HighResHippocampus  003_S_6260    BRAIN  ...             4013636
# 4   3 Plane Localizer  003_S_6260    BRAIN  ...             4013636
#
#    image_occurrence_date                                         wadors_uri  \
# 0             2019-07-09  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 1             2019-07-09  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 2             2019-07-09  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 3             2019-07-09  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 4             2019-07-09  https://imgextpoc-adnidicom.dicom.azurehealthc...
#
#    series_uid procedure_date procedure_occurrence_id image_occurrence_id  \
# 0         NaN            NaT                     NaN                 NaN
# 1         NaN            NaT                     NaN                 NaN
# 2         NaN            NaT                     NaN                 NaN
# 3         NaN            NaT                     NaN                 NaN
# 4         NaN            NaT                     NaN                 NaN
#
#   visit_occurrence_id  visit_concept_id  visit_type_concept_id
# 0                 NaN               NaN                    NaN
# 1                 NaN               NaN                    NaN
# 2                 NaN               NaN                    NaN
# 3                 NaN               NaN                    NaN
# 4                 NaN               NaN                    NaN
#
# [5 rows x 23 columns]

# %%
new_ids_start = df_subset['image_occurrence_id'].max() +1
new_ids_start = int(new_ids_start)

# %%
4756 -889
# Out:
# 3867

# %%
num_missing_ids = df_subset['image_occurrence_id'].isnull().sum()

# %%
# Create a series with new unique IDs
new_ids = pd.Series(range(new_ids_start, new_ids_start + num_missing_ids), index=df_subset[df_subset['image_occurrence_id'].isnull()].index)

# Fill NaN values with new unique IDs
df_subset.loc[df_subset['image_occurrence_id'].isnull(), 'image_occurrence_id'] = new_ids

# %%
df_subset['image_occurrence_id'].max()
# Out:
# 4756.0

# %%
df_subset.shape
# Out:
# (4756, 23)

# %%
print(df_subset['procedure_occurrence_id'].max())
print(df_subset['visit_occurrence_id'].max())
# Out:
# 94.0
# 93.0

# %%
df_subset.groupby('person_id')['00080020'].nunique().reset_index().sort_values('00080020', ascending=False)
# Out:
#      person_id  00080020
# 83        2593         6
# 25        1594         6
# 87        2666         5
# 36        1858         5
# 80        2556         5
# ..         ...       ...
# 157       3309         1
# 159       3316         1
# 160       3319         1
# 167       3349         1
# 288       4017         1
#
# [289 rows x 2 columns]

# %%
new_id_df = df_subset[df_subset['procedure_occurrence_id']==0].groupby(['person_id', '00080020', 'StudyUID'])['SeriesUID'].nunique().reset_index().sort_values('SeriesUID', ascending=False)

# %%
new_id_df.shape
# Out:
# (454, 4)

# %%
df_subset[df_subset['visit_occurrence_id'].isna()].groupby(['person_id', '00080020'])['StudyUID'].nunique().reset_index().sort_values('StudyUID', ascending=False)
# Out:
#      person_id  00080020  StudyUID
# 0           23  20180125         1
# 284       3280  20180417         1
# 310       3376  20180815         1
# 309       3371  20190627         1
# 308       3371  20180605         1
# ..         ...       ...       ...
# 147       2475  20170522         1
# 146       2433  20180731         1
# 145       2433  20170713         1
# 144       2401  20210819         1
# 453       4017  20220329         1
#
# [454 rows x 3 columns]

# %%
new_id_df['id'] = pd.Series(range(95, 95 + len(new_id_df)))

# %%
new_id_df.head()
# Out:
#      person_id  00080020                                      StudyUID   id
# 47        1601  20210409  2.16.124.113543.6006.99.06933582152185294823  142
# 402       3757  20190821   2.16.124.113543.6006.99.0655856398358543536  497
# 165       2666  20210406  2.16.124.113543.6006.99.03291382713950193458  260
# 440       3925  20210618  2.16.124.113543.6006.99.04845780431783970806  535
# 430       3895  20210405  2.16.124.113543.6006.99.08442790786534162058  525

# %%
new_id_df = new_id_df.drop('SeriesUID', axis =1)

# %%
df_subset = df_subset.merge(new_id_df, how = 'left', on = ['person_id', '00080020', 'StudyUID'])

# %%
df_subset['procedure_occurrence_id'] = np.where(df_subset['procedure_occurrence_id'] ==0, df_subset['id'], df_subset['procedure_occurrence_id'])
df_subset['visit_occurrence_id'] = np.where(df_subset['visit_occurrence_id'].isna(), df_subset['id'], df_subset['visit_occurrence_id'])

# %%
df_subset.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01047543405701085685
# 1  2.16.124.113543.6006.99.01047543405701085685
# 2  2.16.124.113543.6006.99.01047543405701085685
# 3  2.16.124.113543.6006.99.01047543405701085685
# 4  2.16.124.113543.6006.99.01047543405701085685
#
#                                       SeriesUID                   00080016  \
# 0  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
# 1  2.16.124.113543.6006.99.02054130675780820610  1.2.840.10008.5.1.4.1.1.4
# 2  2.16.124.113543.6006.99.04611770930445736334  1.2.840.10008.5.1.4.1.1.4
# 3   2.16.124.113543.6006.99.0701056875880124301  1.2.840.10008.5.1.4.1.1.4
# 4   2.16.124.113543.6006.99.1284958151862260961  1.2.840.10008.5.1.4.1.1.4
#
#    00080020  00080022 00080060                                 00081030  \
# 0  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 1  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 2  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 3  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 4  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
#
#              0008103E    00100020 00180015  ... image_occurrence_date  \
# 0       Field Mapping  003_S_6260    BRAIN  ...            2019-07-09
# 1       Axial T2 STAR  003_S_6260    BRAIN  ...            2019-07-09
# 2       Field Mapping  003_S_6260    BRAIN  ...            2019-07-09
# 3  HighResHippocampus  003_S_6260    BRAIN  ...            2019-07-09
# 4   3 Plane Localizer  003_S_6260    BRAIN  ...            2019-07-09
#
#                                           wadors_uri  series_uid  \
# 0  https://imgextpoc-adnidicom.dicom.azurehealthc...         NaN
# 1  https://imgextpoc-adnidicom.dicom.azurehealthc...         NaN
# 2  https://imgextpoc-adnidicom.dicom.azurehealthc...         NaN
# 3  https://imgextpoc-adnidicom.dicom.azurehealthc...         NaN
# 4  https://imgextpoc-adnidicom.dicom.azurehealthc...         NaN
#
#    procedure_date procedure_occurrence_id image_occurrence_id  \
# 0             NaT                   394.0               890.0
# 1             NaT                   394.0               891.0
# 2             NaT                   394.0               892.0
# 3             NaT                   394.0               893.0
# 4             NaT                   394.0               894.0
#
#   visit_occurrence_id visit_concept_id  visit_type_concept_id     id
# 0               394.0              NaN                    NaN  394.0
# 1               394.0              NaN                    NaN  394.0
# 2               394.0              NaN                    NaN  394.0
# 3               394.0              NaN                    NaN  394.0
# 4               394.0              NaN                    NaN  394.0
#
# [5 rows x 24 columns]

# %%
df_subset['visit_concept_id'] = 9202 #outpatient visit
df_subset['visit_type_concept_id'] = 32817 #EHR
df_subset['procedure_concept_id'] = 36713262 #MRI without contrast

# %%
df_subset_subset = df_subset[df_subset['series_uid'].isna()]

# %%
# df_subset.to_csv('temp_07_25.csv')

# %%
df_subset_subset.columns
# Out:
# Index(['StudyUID', 'SeriesUID', '00080016', '00080020', '00080022', '00080060',
#        '00081030', '0008103E', '00100020', '00180015', 'source_id',
#        'person_id', 'anatomic_site_concept_id', 'modality_concept_id',
#        'image_occurrence_date', 'wadors_uri', 'series_uid', 'procedure_date',
#        'procedure_occurrence_id', 'image_occurrence_id', 'visit_occurrence_id',
#        'visit_concept_id', 'visit_type_concept_id', 'id',
#        'procedure_concept_id'],
#       dtype='object')

# %%
# Update PROCERURE_OCCURRENCE
sql = '''
    INSERT INTO dbo.procedure_occurrence (procedure_occurrence_id, person_id, procedure_concept_id, procedure_date, procedure_type_concept_id) 
    VALUES (%s,%s,%s,%s,%s)
    '''
for index, row in df_subset_subset.iterrows():
    cursor.execute(sql, (row['procedure_occurrence_id'], row['person_id'], row['procedure_concept_id'], row['image_occurrence_date'], row['visit_type_concept_id']))

conn.commit()

# %%
# Update Visit_OCCURRENCE
sql = '''
    INSERT INTO dbo.visit_occurrence (visit_occurrence_id, person_id, visit_concept_id, visit_start_date, visit_end_date, visit_type_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s)
    '''
for index, row in df_subset_subset.iterrows():
    cursor.execute(sql, (row['visit_occurrence_id'], row['person_id'], row['visit_concept_id'], row['image_occurrence_date'], row['image_occurrence_date'], row['visit_type_concept_id']))

conn.commit()

# %%
# Update IMAGE_OCCURRENCE
sql = '''
    INSERT INTO dbo.image_occurrence (image_occurrence_id, person_id, procedure_occurrence_id, anatomic_site_concept_id, wadors_uri, image_occurrence_date, image_study_uid, image_series_uid, modality_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in df_subset_subset.iterrows():
    cursor.execute(sql, (row['image_occurrence_id'], row['person_id'], row['procedure_occurrence_id'],  row['anatomic_site_concept_id'], row['wadors_uri'], row['image_occurrence_date'],
                    row['StudyUID'], row['SeriesUID'], row['modality_concept_id']))

conn.commit()

# %% [markdown]
# ### Measurement and Image Feature tables

# %%
df_subset_subset.head() #image_occurrence_id, image_occurrence_date, anatomic_site_concept_id, person_id, SeriesUID
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01047543405701085685
# 1  2.16.124.113543.6006.99.01047543405701085685
# 2  2.16.124.113543.6006.99.01047543405701085685
# 3  2.16.124.113543.6006.99.01047543405701085685
# 4  2.16.124.113543.6006.99.01047543405701085685
#
#                                       SeriesUID                   00080016  \
# 0  2.16.124.113543.6006.99.01296719744744407133  1.2.840.10008.5.1.4.1.1.4
# 1  2.16.124.113543.6006.99.02054130675780820610  1.2.840.10008.5.1.4.1.1.4
# 2  2.16.124.113543.6006.99.04611770930445736334  1.2.840.10008.5.1.4.1.1.4
# 3   2.16.124.113543.6006.99.0701056875880124301  1.2.840.10008.5.1.4.1.1.4
# 4   2.16.124.113543.6006.99.1284958151862260961  1.2.840.10008.5.1.4.1.1.4
#
#    00080020  00080022 00080060                                 00081030  \
# 0  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 1  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 2  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 3  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
# 4  20190709  20190709       MR  ADNI3 Basic Prisma_20170209^ADNI3 Basic
#
#              0008103E    00100020 00180015  ...  \
# 0       Field Mapping  003_S_6260    BRAIN  ...
# 1       Axial T2 STAR  003_S_6260    BRAIN  ...
# 2       Field Mapping  003_S_6260    BRAIN  ...
# 3  HighResHippocampus  003_S_6260    BRAIN  ...
# 4   3 Plane Localizer  003_S_6260    BRAIN  ...
#
#                                           wadors_uri  series_uid  \
# 0  https://imgextpoc-adnidicom.dicom.azurehealthc...         NaN
# 1  https://imgextpoc-adnidicom.dicom.azurehealthc...         NaN
# 2  https://imgextpoc-adnidicom.dicom.azurehealthc...         NaN
# 3  https://imgextpoc-adnidicom.dicom.azurehealthc...         NaN
# 4  https://imgextpoc-adnidicom.dicom.azurehealthc...         NaN
#
#    procedure_date  procedure_occurrence_id image_occurrence_id  \
# 0             NaT                    394.0               890.0
# 1             NaT                    394.0               891.0
# 2             NaT                    394.0               892.0
# 3             NaT                    394.0               893.0
# 4             NaT                    394.0               894.0
#
#   visit_occurrence_id visit_concept_id visit_type_concept_id     id  \
# 0               394.0             9202                 32817  394.0
# 1               394.0             9202                 32817  394.0
# 2               394.0             9202                 32817  394.0
# 3               394.0             9202                 32817  394.0
# 4               394.0             9202                 32817  394.0
#
#    procedure_concept_id
# 0              36713262
# 1              36713262
# 2              36713262
# 3              36713262
# 4              36713262
#
# [5 rows x 25 columns]

# %%
series_to_upload = series_to_upload.drop('concept_code', axis =1)

# %%
series_to_upload.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01374093887421385650
# 1  2.16.124.113543.6006.99.01374093887421385650
# 2  2.16.124.113543.6006.99.01374093887421385650
# 3  2.16.124.113543.6006.99.01374093887421385650
# 4  2.16.124.113543.6006.99.01374093887421385650
#
#                                       SeriesUID       Tag  vr  \
# 0  2.16.124.113543.6006.99.02724440683260009463  00080005  CS
# 1  2.16.124.113543.6006.99.02724440683260009463  00080008  CS
# 2  2.16.124.113543.6006.99.02724440683260009463  00080013  TM
# 3  2.16.124.113543.6006.99.02724440683260009463  00080020  DA
# 4  2.16.124.113543.6006.99.02724440683260009463  00080021  DA
#
#                                                Value  concept_id  \
# 0                                         ISO_IR 100  2128000011
# 1  ORIGINAL, PRIMARY, PERFUSION, NONE, ND, NORM, ...  2128000012
# 2                                      132514.750000  2128000014
# 3                                           20180314  2128000016
# 4                                           20180314  2128000017
#
#              concept_name
# 0  Specific Character Set
# 1              Image Type
# 2  Instance Creation Time
# 3              Study Date
# 4             Series Date

# %%
series_to_upload = series_to_upload.merge(df_subset_subset[['image_occurrence_id', 'image_occurrence_date', 'anatomic_site_concept_id', 'person_id', 'SeriesUID']], how = 'left', on = 'SeriesUID')

# %%
series_to_upload.head()
# Out:
#                                        StudyUID  \
# 0  2.16.124.113543.6006.99.01374093887421385650
# 1  2.16.124.113543.6006.99.01374093887421385650
# 2  2.16.124.113543.6006.99.01374093887421385650
# 3  2.16.124.113543.6006.99.01374093887421385650
# 4  2.16.124.113543.6006.99.01374093887421385650
#
#                                       SeriesUID       Tag  vr  \
# 0  2.16.124.113543.6006.99.02724440683260009463  00080005  CS
# 1  2.16.124.113543.6006.99.02724440683260009463  00080008  CS
# 2  2.16.124.113543.6006.99.02724440683260009463  00080013  TM
# 3  2.16.124.113543.6006.99.02724440683260009463  00080020  DA
# 4  2.16.124.113543.6006.99.02724440683260009463  00080021  DA
#
#                                                Value  concept_id  \
# 0                                         ISO_IR 100  2128000011
# 1  ORIGINAL, PRIMARY, PERFUSION, NONE, ND, NORM, ...  2128000012
# 2                                      132514.750000  2128000014
# 3                                           20180314  2128000016
# 4                                           20180314  2128000017
#
#              concept_name  image_occurrence_id image_occurrence_date  \
# 0  Specific Character Set                957.0            2018-03-14
# 1              Image Type                957.0            2018-03-14
# 2  Instance Creation Time                957.0            2018-03-14
# 3              Study Date                957.0            2018-03-14
# 4             Series Date                957.0            2018-03-14
#
#    anatomic_site_concept_id  person_id  image_feature_event_field_concept_id  \
# 0                   4119359       2666                               1147330
# 1                   4119359       2666                               1147330
# 2                   4119359       2666                               1147330
# 3                   4119359       2666                               1147330
# 4                   4119359       2666                               1147330
#
#    image_feature_type_concept_id  measurement_id  image_feature_id
# 0                          32817          673718            510616
# 1                          32817          673719            510617
# 2                          32817          673720            510618
# 3                          32817          673721            510619
# 4                          32817          673722            510620

# %%
series_to_upload['image_feature_event_field_concept_id'] = 1147330
series_to_upload['image_feature_type_concept_id'] = 32817

# %%
# max measurement_id = 673717
# max image feature id = 510615
series_to_upload['measurement_id'] = range(673718, 673718 + len(series_to_upload), 1)
series_to_upload['image_feature_id'] = range(510616, 510616 + len(series_to_upload), 1)

# %%
series_to_upload['value_as_number'] = pd.to_numeric(series_to_upload['Value'], errors='coerce')

# %%
# Tags with values > 50 characters -> exclude them for now
series_to_upload[series_to_upload['Value'].str.len()>50][['concept_name', 'Tag']].drop_duplicates()
# Out:
#                         concept_name       Tag
# 1                         Image Type  00080008
# 45          Image Position (Patient)  00200032
# 410      Image Orientation (Patient)  00200037
# 3413  Diffusion Gradient Orientation  00189089
# 6065                    Scan Options  00180022

# %%
series_to_upload = series_to_upload[~series_to_upload['Tag'].isin(['00080008', '00200032', '00200037', '00189089', '00180022'])]
series_to_upload.shape
# Out:
# (218482, 16)

# %%
# Update MEASUREMENT
sql = '''
    INSERT INTO dbo.measurement (measurement_id, person_id, measurement_concept_id, measurement_date, measurement_type_concept_id, value_as_number, measurement_source_value, measurement_source_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
'''

# Define batch size
batch_size = 20000
batch = []

# Iterate through the DataFrame
for index, row in series_to_upload.iterrows():
    # Append row data to the batch
    batch.append((row['measurement_id'], row['person_id'], row['concept_id'], row['image_occurrence_date'], row['image_feature_type_concept_id'], row['value_as_number'], row['Value'], row['concept_id']))

    # Check if batch size is reached or if it's the last row
    if len(batch) == batch_size or (index == len(series_to_upload) - 1):
        # Execute the batch
        cursor.executemany(sql, batch)
        conn.commit()  # Commit after each batch
        batch = []  # Clear the batch for the next set of rows

# %%
# Update IMAGE_FEATURE
# numeric data
sql = '''
    INSERT INTO dbo.image_feature (image_feature_id, person_id, image_occurrence_id, image_feature_event_id,
      image_feature_event_field_concept_id, image_feature_concept_id, image_feature_type_concept_id, anatomic_site_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
'''

# Define batch size
batch_size = 20000
batch = []

# Iterate through the DataFrame
for index, row in series_to_upload.iterrows():
    # Append row data to the batch
    batch.append((row['image_feature_id'], row['person_id'], row['image_occurrence_id'], row['measurement_id'], 
                  row['image_feature_event_field_concept_id'], row['concept_id'], row['image_feature_type_concept_id'],
                  row['anatomic_site_concept_id']))

    # Check if batch size is reached or if it's the last row
    if len(batch) == batch_size or (index == len(series_to_upload) - 1):
        # Execute the batch
        cursor.executemany(sql, batch)
        conn.commit()  # Commit after each batch
        batch = []  # Clear the batch for the next set of rows

# Close the cursor and connection
cursor.close()
conn.close()

# %%
new_vol = pd.read_csv('./files/cohort1_volumes_0726.csv')
new_vol.head()
# Out:
#                                        study_id  \
# 0  2.16.124.113543.6006.99.06773755737597518352
# 1    2.16.124.113543.6006.99.887626465205241637
# 2  2.16.124.113543.6006.99.03291382713950193458
# 3    2.16.124.113543.6006.99.137757906306121194
# 4   2.16.124.113543.6006.99.1658690444528783610
#
#                                       series_id  SFG_L  SFG_R  SFG_PFC_L  \
# 0  2.16.124.113543.6006.99.06776275394214813350  15875  11854      12077
# 1   2.16.124.113543.6006.99.1980347023974417782  14588  13050      11414
# 2  2.16.124.113543.6006.99.03389417910192018890  17044  17261      10971
# 3   2.16.124.113543.6006.99.2570101154935452557  12593  10746       9826
# 4    2.16.124.113543.6006.99.118959375462130461  14834  12599      10418
#
#    SFG_PFC_R  SFG_pole_L  SFG_pole_R  MFG_L  MFG_R  ...  Fimbria_R  \
# 0      11869        2798        4962   7705   9626  ...          0
# 1      11896        2129        4577   9942   8574  ...          0
# 2      11980        1959        3981   8017   8610  ...          0
# 3      10113        2075        3803   8463   8925  ...          0
# 4      10719        2406        4322   8621   8615  ...          0
#
#    Chroid_LVetc_L  Chroid_LVetc_R  IV_ventricle  ECCL_L  ECCL_R  \
# 0             635             473          1940     362     419
# 1             346             296          2990     404     683
# 2             288             308          2206     429     510
# 3             291             202          2307     367     450
# 4             325             253          2328     346     433
#
#    ECSAnterior_L  ECSAnterior_R  ECSPosterior_L  ECSPosterior_R
# 0           4420           4458            3957            3737
# 1           2126           1921            2156            1687
# 2           8954           7719            8977            6600
# 3           5281           6945            5247            5121
# 4           5060           4825            8792            7406
#
# [5 rows x 282 columns]

# %%
new_vol.shape
# Out:
# (550, 282)

# %%
vol_concept = pd.read_csv('./files/concept_vol_brain.csv')
vol_concept.head()
# Out:
#    vol_concept_id  brain_part
# 0      2129001000       SFG_L
# 1      2129001001       SFG_R
# 2      2129001002   SFG_PFC_L
# 3      2129001003   SFG_PFC_R
# 4      2129001004  SFG_pole_L

# %%
series_uploaded = series_to_upload['SeriesUID'].unique()

# %%
new_vol_long = new_vol[new_vol['series_id'].isin(series_uploaded)].melt(id_vars = ['study_id', 'series_id'],var_name = 'brain_vol_name', value_name = 'value')
new_vol_long.head()
# Out:
#                                        study_id  \
# 0  2.16.124.113543.6006.99.06773755737597518352
# 1    2.16.124.113543.6006.99.887626465205241637
# 2  2.16.124.113543.6006.99.03291382713950193458
# 3    2.16.124.113543.6006.99.137757906306121194
# 4  2.16.124.113543.6006.99.02456403398253415947
#
#                                       series_id brain_vol_name  value
# 0  2.16.124.113543.6006.99.06776275394214813350          SFG_L  15875
# 1   2.16.124.113543.6006.99.1980347023974417782          SFG_L  14588
# 2  2.16.124.113543.6006.99.03389417910192018890          SFG_L  17044
# 3   2.16.124.113543.6006.99.2570101154935452557          SFG_L  12593
# 4  2.16.124.113543.6006.99.01497921111528676920          SFG_L  13789

# %%
new_vol_long['series_id'].nunique()
# Out:
# 462

# %%
new_vol_long = new_vol_long.merge(vol_concept, how = 'left', left_on = 'brain_vol_name', right_on = 'brain_part')

# %%
new_vol_long.head()
# Out:
#                                        study_id  \
# 0  2.16.124.113543.6006.99.06773755737597518352
# 1    2.16.124.113543.6006.99.887626465205241637
# 2  2.16.124.113543.6006.99.03291382713950193458
# 3    2.16.124.113543.6006.99.137757906306121194
# 4  2.16.124.113543.6006.99.02456403398253415947
#
#                                       series_id brain_vol_name  value  \
# 0  2.16.124.113543.6006.99.06776275394214813350          SFG_L  15875
# 1   2.16.124.113543.6006.99.1980347023974417782          SFG_L  14588
# 2  2.16.124.113543.6006.99.03389417910192018890          SFG_L  17044
# 3   2.16.124.113543.6006.99.2570101154935452557          SFG_L  12593
# 4  2.16.124.113543.6006.99.01497921111528676920          SFG_L  13789
#
#    vol_concept_id brain_part
# 0      2129001000      SFG_L
# 1      2129001000      SFG_L
# 2      2129001000      SFG_L
# 3      2129001000      SFG_L
# 4      2129001000      SFG_L

# %%
new_vol_long.shape
# Out:
# (129360, 6)

# %%
df_subset_subset.columns
# Out:
# Index(['StudyUID', 'SeriesUID', '00080016', '00080020', '00080022', '00080060',
#        '00081030', '0008103E', '00100020', '00180015', 'source_id',
#        'person_id', 'anatomic_site_concept_id', 'modality_concept_id',
#        'image_occurrence_date', 'wadors_uri', 'series_uid', 'procedure_date',
#        'procedure_occurrence_id', 'image_occurrence_id', 'visit_occurrence_id',
#        'visit_concept_id', 'visit_type_concept_id', 'id',
#        'procedure_concept_id'],
#       dtype='object')

# %%
# image_feature_id, person_id, image_occurrence_id, image_feature_event_field_id (1147330), image_feature_event_id(measurement_id)
# , image_feature_type_concept_id (32880), anatomic_site_concept_id, measurement_date,
new_vol_long = new_vol_long.merge(df_subset[['SeriesUID', 'image_occurrence_id', 'image_occurrence_date', 'person_id']], how ='left', left_on = 'series_id', right_on = 'SeriesUID')
new_vol_long.head()
# Out:
#                                        study_id  \
# 0  2.16.124.113543.6006.99.06773755737597518352
# 1    2.16.124.113543.6006.99.887626465205241637
# 2  2.16.124.113543.6006.99.03291382713950193458
# 3    2.16.124.113543.6006.99.137757906306121194
# 4  2.16.124.113543.6006.99.02456403398253415947
#
#                                       series_id brain_vol_name  value  \
# 0  2.16.124.113543.6006.99.06776275394214813350          SFG_L  15875
# 1   2.16.124.113543.6006.99.1980347023974417782          SFG_L  14588
# 2  2.16.124.113543.6006.99.03389417910192018890          SFG_L  17044
# 3   2.16.124.113543.6006.99.2570101154935452557          SFG_L  12593
# 4  2.16.124.113543.6006.99.01497921111528676920          SFG_L  13789
#
#    vol_concept_id brain_part                                     SeriesUID  \
# 0      2129001000      SFG_L  2.16.124.113543.6006.99.06776275394214813350
# 1      2129001000      SFG_L   2.16.124.113543.6006.99.1980347023974417782
# 2      2129001000      SFG_L  2.16.124.113543.6006.99.03389417910192018890
# 3      2129001000      SFG_L   2.16.124.113543.6006.99.2570101154935452557
# 4      2129001000      SFG_L  2.16.124.113543.6006.99.01497921111528676920
#
#    image_occurrence_id image_occurrence_date  person_id
# 0               2324.0            2018-02-21       3167
# 1               4606.0            2021-03-16       3876
# 2               1385.0            2021-04-06       2666
# 3               2960.0            2019-07-23       2871
# 4               1225.0            2018-03-15       3221

# %%
new_vol_long['image_feature_event_field_concept_id'] = 1147330
new_vol_long['image_feature_type_concept_id'] = 32880
new_vol_long['anatomic_site_concept_id'] = new_vol_long['vol_concept_id'] - 1000

# %%
# max measurement_id = 892199
# max image feature id = 729097
new_vol_long['measurement_id'] = range(892200, 892200 + len(new_vol_long), 1)
new_vol_long['image_feature_id'] = range(729098, 729098 + len(new_vol_long), 1)

# %%
new_vol_long.head()
# Out:
#                                        study_id  \
# 0  2.16.124.113543.6006.99.06773755737597518352
# 1    2.16.124.113543.6006.99.887626465205241637
# 2  2.16.124.113543.6006.99.03291382713950193458
# 3    2.16.124.113543.6006.99.137757906306121194
# 4  2.16.124.113543.6006.99.02456403398253415947
#
#                                       series_id brain_vol_name  value  \
# 0  2.16.124.113543.6006.99.06776275394214813350          SFG_L  15875
# 1   2.16.124.113543.6006.99.1980347023974417782          SFG_L  14588
# 2  2.16.124.113543.6006.99.03389417910192018890          SFG_L  17044
# 3   2.16.124.113543.6006.99.2570101154935452557          SFG_L  12593
# 4  2.16.124.113543.6006.99.01497921111528676920          SFG_L  13789
#
#    vol_concept_id brain_part                                     SeriesUID  \
# 0      2129001000      SFG_L  2.16.124.113543.6006.99.06776275394214813350
# 1      2129001000      SFG_L   2.16.124.113543.6006.99.1980347023974417782
# 2      2129001000      SFG_L  2.16.124.113543.6006.99.03389417910192018890
# 3      2129001000      SFG_L   2.16.124.113543.6006.99.2570101154935452557
# 4      2129001000      SFG_L  2.16.124.113543.6006.99.01497921111528676920
#
#    image_occurrence_id image_occurrence_date  person_id  \
# 0               2324.0            2018-02-21       3167
# 1               4606.0            2021-03-16       3876
# 2               1385.0            2021-04-06       2666
# 3               2960.0            2019-07-23       2871
# 4               1225.0            2018-03-15       3221
#
#    image_feature_event_field_concept_id  image_feature_type_concept_id  \
# 0                               1147330                          32880
# 1                               1147330                          32880
# 2                               1147330                          32880
# 3                               1147330                          32880
# 4                               1147330                          32880
#
#    anatomic_site_concept_id  measurement_id  image_feature_id
# 0                2129000000          892200            729098
# 1                2129000000          892201            729099
# 2                2129000000          892202            729100
# 3                2129000000          892203            729101
# 4                2129000000          892204            729102

# %%
new_vol_long['series_id'].nunique()
# Out:
# 462

# %%
import psycopg2

conn = psycopg2.connect(
    database="adni",
    user="",
    password="",
    host="",
    port="5432",
    connect_timeout = 6000
)

cursor = conn.cursor()

# %%
# Update MEASUREMENT
sql = '''
    INSERT INTO dbo.measurement (measurement_id, person_id, measurement_concept_id, measurement_date, measurement_type_concept_id, value_as_number, measurement_source_value, measurement_source_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
'''

# Define batch size
batch_size = 20000
batch = []

# Iterate through the DataFrame
for index, row in new_vol_long.iterrows():
    # Append row data to the batch
    batch.append((row['measurement_id'], row['person_id'], row['vol_concept_id'], row['image_occurrence_date'], row['image_feature_type_concept_id'], row['value'], row['value'], row['vol_concept_id']))

    # Check if batch size is reached or if it's the last row
    if len(batch) == batch_size or (index == len(new_vol_long) - 1):
        # Execute the batch
        cursor.executemany(sql, batch)
        conn.commit()  # Commit after each batch
        batch = []  # Clear the batch for the next set of rows

# %%
# Update IMAGE_FEATURE
# numeric data
sql = '''
    INSERT INTO dbo.image_feature (image_feature_id, person_id, image_occurrence_id, image_feature_event_id,
      image_feature_event_field_concept_id, image_feature_concept_id, image_feature_type_concept_id, anatomic_site_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
'''

# Define batch size
batch_size = 20000
batch = []

# Iterate through the DataFrame
for index, row in new_vol_long.iterrows():
    # Append row data to the batch
    batch.append((row['image_feature_id'], row['person_id'], row['image_occurrence_id'], row['measurement_id'], 
                  row['image_feature_event_field_concept_id'], row['vol_concept_id'], row['image_feature_type_concept_id'],
                  row['anatomic_site_concept_id']))

    # Check if batch size is reached or if it's the last row
    if len(batch) == batch_size or (index == len(new_vol_long) - 1):
        # Execute the batch
        cursor.executemany(sql, batch)
        conn.commit()  # Commit after each batch
        batch = []  # Clear the batch for the next set of rows

# Close the cursor and connection
cursor.close()
conn.close()

# %% [markdown]
# ## Initial transformation code

# %%
df_metadata.head()
# Out:
#                                       study_uid  \
# 0  2.16.124.113543.6006.99.06519376916392844499
# 1  2.16.124.113543.6006.99.06519376916392844499
# 2  2.16.124.113543.6006.99.06519376916392844499
# 3  2.16.124.113543.6006.99.06519376916392844499
# 4  2.16.124.113543.6006.99.06519376916392844499
#
#                                     series_uid  \
# 0  2.16.124.113543.6006.99.0762513022255586274
# 1  2.16.124.113543.6006.99.0762513022255586274
# 2  2.16.124.113543.6006.99.0762513022255586274
# 3  2.16.124.113543.6006.99.0762513022255586274
# 4  2.16.124.113543.6006.99.0762513022255586274
#
#                                    instance_uid  patient_id  \
# 0  2.16.124.113543.6006.99.02345206785977573755  003_S_6268
# 1  2.16.124.113543.6006.99.02345206785977573755  003_S_6268
# 2  2.16.124.113543.6006.99.02345206785977573755  003_S_6268
# 3  2.16.124.113543.6006.99.02345206785977573755  003_S_6268
# 4  2.16.124.113543.6006.99.02345206785977573755  003_S_6268
#
#                          study_description  series_description  \
# 0  ADNI3 Basic Prisma_20170209^ADNI3 Basic  Perfusion_Weighted
# 1  ADNI3 Basic Prisma_20170209^ADNI3 Basic  Perfusion_Weighted
# 2  ADNI3 Basic Prisma_20170209^ADNI3 Basic  Perfusion_Weighted
# 3  ADNI3 Basic Prisma_20170209^ADNI3 Basic  Perfusion_Weighted
# 4  ADNI3 Basic Prisma_20170209^ADNI3 Basic  Perfusion_Weighted
#
#                sop_class_uid attribute_tag          value
# 0  1.2.840.10008.5.1.4.1.1.4      00080005     ISO_IR 100
# 1  1.2.840.10008.5.1.4.1.1.4      00080008        DERIVED
# 2  1.2.840.10008.5.1.4.1.1.4      00080013  134748.218000
# 3  1.2.840.10008.5.1.4.1.1.4      00080020       20190806
# 4  1.2.840.10008.5.1.4.1.1.4      00080021       20190806

# %%
instance_counts = df_metadata.groupby(['study_uid', 'series_uid'])['instance_uid'].nunique().reset_index().sort_values('instance_uid', ascending=False)

# %%
instance_counts['instance_uid'].hist()
# Out:
# <Axes: >

# %%
df_metadata_dedup = df_metadata[['study_uid', 'series_uid', 'attribute_tag','value']].drop_duplicates()

# %%
df_metadata['study_description'].unique()
# Out:
# array(['ADNI3 Basic Prisma_20170209^ADNI3 Basic',
#        'ADNI3 Basic Prisma^ADNI3 Basic', 'ADNI3 Basic Prisma^20181129',
#        'SCREENING', 'MR BRAIN RESEARCH',
#        'ADNI3 Basic Prisma^ADNI_MostRecent', 'YEAR 4', 'Yassine^DHA',
#        'screening', 'e+1 MRI BRAIN W/O CONTRAST',
#        'ADNI3 Advanced Prisma_20171012^ADNI3 Advanced', 'e+2 ADNI 3',
#        'e+1 ADNI3', 'Year_1_Visit', 'ADNI3 Year2', 'year 2', 'YEAR_2'],
#       dtype=object)

# %%
df_metadata['series_description'].unique()
# Out:
# array(['Perfusion_Weighted', 'Axial T2 STAR', 'Field Mapping',
#        '3 Plane Localizer', 'Sagittal 3D FLAIR',
#        'Axial 3D PASL (Eyes Open)', 'Accelerated Sagittal MPRAGE',
#        'HighResHippocampus', 'Field Mapping_AP_Phase',
#        'Axial 3TE T2 STAR',
#        'HighResHippo Scan (Oblique - perpendicular to hippocampal tail',
#        'Axial T2 Star', 'Axial Field Mapping', 'Axial 2D PASL',
#        'Sagittal 3D Accelerated MPRAGE',
#        'HighResHippocampus_AA prescan Normalize', 'tgse_pcasl_PLD2000',
#        'Field Mapping_2.5mm', 'Calibration Scan', 'HighResHippo',
#        'Accelerated Sagittal IR-FSPGR', 'Axial 3D pCASL (Eyes Open)',
#        'Repeat_Accelerated Sagittal MPRAGE', 't1_fl2d_sag',
#        'Repeat_Axial T2 STAR', '<MPR Collection>', 'cor mpr'],
#       dtype=object)

# %%
df_metadata_dedup # 400,385
# Out:
#                                             study_uid  \
# 0        2.16.124.113543.6006.99.06519376916392844499
# 1        2.16.124.113543.6006.99.06519376916392844499
# 2        2.16.124.113543.6006.99.06519376916392844499
# 3        2.16.124.113543.6006.99.06519376916392844499
# 4        2.16.124.113543.6006.99.06519376916392844499
# ...                                               ...
# 3966618   2.16.124.113543.6006.99.9223169425485824208
# 3966619   2.16.124.113543.6006.99.9223169425485824208
# 3966620   2.16.124.113543.6006.99.9223169425485824208
# 3966621   2.16.124.113543.6006.99.9223169425485824208
# 3966622   2.16.124.113543.6006.99.9223169425485824208
#
#                                           series_uid attribute_tag  \
# 0        2.16.124.113543.6006.99.0762513022255586274      00080005
# 1        2.16.124.113543.6006.99.0762513022255586274      00080008
# 2        2.16.124.113543.6006.99.0762513022255586274      00080013
# 3        2.16.124.113543.6006.99.0762513022255586274      00080020
# 4        2.16.124.113543.6006.99.0762513022255586274      00080021
# ...                                              ...           ...
# 3966618   2.16.124.113543.6006.99.640768751323050122      00281051
# 3966619   2.16.124.113543.6006.99.640768751323050122      00281052
# 3966620   2.16.124.113543.6006.99.640768751323050122      00281053
# 3966621   2.16.124.113543.6006.99.640768751323050122      0032000A
# 3966622   2.16.124.113543.6006.99.640768751323050122      00400245
#
#                  value
# 0           ISO_IR 100
# 1              DERIVED
# 2        134748.218000
# 3             20190806
# 4             20190806
# ...                ...
# 3966618           5311
# 3966619          -4096
# 3966620       2.000244
# 3966621      COMPLETED
# 3966622  133022.131000
#
# [400385 rows x 4 columns]

# %%
df_metadata_dedup.groupby('attribute_tag')['value'].nunique().sort_values(ascending=False)[:20]
# Out:
# attribute_tag
# 00080013    59662
# 00080033    47257
# 00201041    34311
# 00200032    23377
# 00080032    15954
# 00281051    13235
# 00281050    10367
# 00080031      808
# 00181316      523
# 00180084      506
# 00200013      231
# 00209057      198
# 00080030       95
# 00400245       94
# 00080023       85
# 00080021       85
# 00080020       85
# 00080022       84
# 00101030       69
# 00180081       52
# Name: value, dtype: int64

# %%
df_metadata_dedup[df_metadata_dedup['attribute_tag']=='00200013']['value'].hist()
# Out:
# <Axes: >

# %%
df_metadata_dedup.to_pickle('./files/df_metadata_dedup_8.pkl')

# %%
import pandas as pd
df_metadata_dedup = pd.read_pickle('./files/df_metadata_dedup_6.pkl')

# %%
df_metadata_dedup.head()
# Out:
#                                      study_uid  \
# 0  2.16.124.113543.6006.99.3727626124013327188
# 1  2.16.124.113543.6006.99.3727626124013327188
# 2  2.16.124.113543.6006.99.3727626124013327188
# 3  2.16.124.113543.6006.99.3727626124013327188
# 4  2.16.124.113543.6006.99.3727626124013327188
#
#                                     series_uid attribute_tag          value
# 0  2.16.124.113543.6006.99.0257367353967101811      00080005     ISO_IR 100
# 1  2.16.124.113543.6006.99.0257367353967101811      00080008       ORIGINAL
# 2  2.16.124.113543.6006.99.0257367353967101811      00080013  132300.791000
# 3  2.16.124.113543.6006.99.0257367353967101811      00080020       20200218
# 4  2.16.124.113543.6006.99.0257367353967101811      00080021       20200218

# %%
df_metadata_dedup.attribute_tag.nunique()
# Out:
# 91

# %%
# PTID 00100020
# StudyDate (00080020)
# Acquisition Date (00080022)
# Study UID (0020000D)
# Series UID (0020000E)
# Series UID (00080018) – to count number of instances
# Study Description (00081030) 
# Series Description (0008103E)
# Modality (00080060)
# Body Part Examined (00180015)
# SOP Class UID (00080016)
df_subset = df_metadata_dedup[df_metadata_dedup['attribute_tag'].isin(['00100020', '00080020', '00080022', '00080018', '00081030', '0008103E', '00080060', '00180015', '00080016'])]
df_subset = df_subset.pivot(index=['study_uid', 'series_uid'], columns='attribute_tag', values='value').reset_index()
df_subset.head()
# Out:
# attribute_tag                                    study_uid  \
# 0              2.16.124.113543.6006.99.3727626124013327188
# 1              2.16.124.113543.6006.99.3727626124013327188
# 2              2.16.124.113543.6006.99.3727626124013327188
# 3              2.16.124.113543.6006.99.3727626124013327188
# 4              2.16.124.113543.6006.99.3727626124013327188
#
# attribute_tag                                    series_uid  00080020  \
# 0               2.16.124.113543.6006.99.0257367353967101811  20200218
# 1              2.16.124.113543.6006.99.02677408316883235540  20200218
# 2              2.16.124.113543.6006.99.06675742049047693160  20200218
# 3              2.16.124.113543.6006.99.08274858919129258141  20200218
# 4               2.16.124.113543.6006.99.1035056743807608511  20200218
#
# attribute_tag  00080022 00080060 00180015
# 0              20200218       MR     HEAD
# 1              20200218       MR     HEAD
# 2              20200218       MR     HEAD
# 3              20200218       MR     HEAD
# 4              20200218       MR     HEAD

# %%
df_subset.columns = ['study_uid', 'series_uid', 'study_date', 'acuisition_date', 'modality', 'body_part_examined']

# %%
df_subset
# Out:
#                                         study_uid  \
# 0    2.16.124.113543.6006.99.06519376916392844499
# 1    2.16.124.113543.6006.99.06519376916392844499
# 2    2.16.124.113543.6006.99.06519376916392844499
# 3    2.16.124.113543.6006.99.06519376916392844499
# 4    2.16.124.113543.6006.99.06706857867504247446
# ..                                            ...
# 803   2.16.124.113543.6006.99.9223169425485824208
# 804   2.16.124.113543.6006.99.9223169425485824208
# 805   2.16.124.113543.6006.99.9223169425485824208
# 806   2.16.124.113543.6006.99.9223169425485824208
# 807   2.16.124.113543.6006.99.9223169425485824208
#
#                                        series_uid study_date acuisition_date  \
# 0     2.16.124.113543.6006.99.0762513022255586274   20190806        20190806
# 1    2.16.124.113543.6006.99.08428228397778749671   20190806        20190806
# 2     2.16.124.113543.6006.99.2054636274198166179   20190806        20190806
# 3     2.16.124.113543.6006.99.7916726722310379853   20190806        20190806
# 4    2.16.124.113543.6006.99.03671086227124482649   20170313        20170313
# ..                                            ...        ...             ...
# 803  2.16.124.113543.6006.99.08750092380025407058   20170615        20170615
# 804   2.16.124.113543.6006.99.3300067167625826404   20170615        20170615
# 805   2.16.124.113543.6006.99.4024297997348294533   20170615        20170615
# 806   2.16.124.113543.6006.99.6295799475157931997   20170615        20170615
# 807    2.16.124.113543.6006.99.640768751323050122   20170615        20170615
#
#     modality body_part_examined
# 0         MR              BRAIN
# 1         MR              BRAIN
# 2         MR              BRAIN
# 3         MR              BRAIN
# 4         MR              BRAIN
# ..       ...                ...
# 803       MR              BRAIN
# 804       MR              BRAIN
# 805       MR              BRAIN
# 806       MR              BRAIN
# 807       MR              BRAIN
#
# [808 rows x 6 columns]

# %% [markdown]
# ## Download the image metadata and transform them

# %%
omop_image_concept[omop_image_concept['concept_id'].isin([2128000367, 2128000366, 2129001004, 2128000493])]
# Out:
#      concept_id     concept_name    domain_id vocabulary_id  concept_class_id  \
# 356  2128000366  Repetition Time  Measurement         DICOM  DICOM Attributes
# 357  2128000367        Echo Time  Measurement         DICOM  DICOM Attributes
# 483  2128000493       Flip Angle  Measurement         DICOM  DICOM Attributes
#
#      standard_concept concept_code  valid_start_date  valid_end_date  \
# 356               NaN     00180080          19930101        20991231
# 357               NaN     00180081          19930101        20991231
# 483               NaN     00181314          19930101        20991231
#
#      invalid_reason
# 356             NaN
# 357             NaN
# 483             NaN

# %%
omop_image_concept[omop_image_concept['concept_code'] == '00870081']
# Out:
# Empty DataFrame
# Columns: [concept_id, concept_name, domain_id, vocabulary_id, concept_class_id, standard_concept, concept_code, valid_start_date, valid_end_date, invalid_reason]
# Index: []

# %%
# 2128000367, 00180081 echo <= 10 
# 2128000366, 00180080 repetition time between 500 and 800
# 2128000493, 00181314 flip angle between 8 and 15
df_metadata_dedup[df_metadata_dedup['attribute_tag'].isin(['00180080', '00180081', '00181314', '00870081'])]
# Out:
#                                             study_uid  \
# 22       2.16.124.113543.6006.99.06519376916392844499
# 23       2.16.124.113543.6006.99.06519376916392844499
# 36       2.16.124.113543.6006.99.06519376916392844499
# 83       2.16.124.113543.6006.99.06519376916392844499
# 84       2.16.124.113543.6006.99.06519376916392844499
# ...                                               ...
# 3966464   2.16.124.113543.6006.99.9223169425485824208
# 3966477   2.16.124.113543.6006.99.9223169425485824208
# 3966583   2.16.124.113543.6006.99.9223169425485824208
# 3966584   2.16.124.113543.6006.99.9223169425485824208
# 3966597   2.16.124.113543.6006.99.9223169425485824208
#
#                                            series_uid attribute_tag  value
# 22        2.16.124.113543.6006.99.0762513022255586274      00180080   4000
# 23        2.16.124.113543.6006.99.0762513022255586274      00180081  20.26
# 36        2.16.124.113543.6006.99.0762513022255586274      00181314    180
# 83       2.16.124.113543.6006.99.08428228397778749671      00180080    650
# 84       2.16.124.113543.6006.99.08428228397778749671      00180081     20
# ...                                               ...           ...    ...
# 3966464   2.16.124.113543.6006.99.6295799475157931997      00180081  16.02
# 3966477   2.16.124.113543.6006.99.6295799475157931997      00181314    180
# 3966583    2.16.124.113543.6006.99.640768751323050122      00180080   5000
# 3966584    2.16.124.113543.6006.99.640768751323050122      00180081  16.02
# 3966597    2.16.124.113543.6006.99.640768751323050122      00181314    180
#
# [2527 rows x 4 columns]

# %% [markdown]
# ## Update Procedure_occurrence table
#
# Required Fields: person_id, procedure_occurrence_id (PK), procedure_date, procedure_concept_id, procedure_type_concept_id
# * Use patient ID (00100020) to get PTID then use registry_idmap to find the matching person_id
# * Convert StudyDate (00080020) to procedure_date
# * Series Description (00081030) to procedure_concept_id through Athena lookup - 36713262 (Brain MR)
# * procedure_type_concept_id = 32817 - EHR
# * Use Series UID to create procedure_occurrence_id

# %%
staging_table = pd.read_pickle('./files/image_occurrence_staging.pkl')
image_series = pd.read_pickle('./files/image_series_metadata.pkl')

# %%
staging_table.head()
# Out:
#                                       study_uid  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                      series_uid  person_id procedure_date  \
# 0  2.16.124.113543.6006.99.06083117774660962009       2161     2017-12-04
# 1  2.16.124.113543.6006.99.06263494736769400825       2161     2017-12-04
# 2  2.16.124.113543.6006.99.06964874624365474765       2161     2017-12-04
# 3  2.16.124.113543.6006.99.07300304364963768908       2161     2017-12-04
# 4  2.16.124.113543.6006.99.08097639857522452001       2161     2017-12-04
#
#    procedure_occurrence_id  image_occurrence_id  \
# 0                        1                    1
# 1                        1                    2
# 2                        1                    3
# 3                        1                    4
# 4                        1                    5
#
#                                           wadors_uri  \
# 0  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 1  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 2  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 3  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 4  https://imgextpoc-adnidicom.dicom.azurehealthc...
#
#    anatomic_site_concept_id  modality_concept_id  visit_occurrence_id  \
# 0                   4119359              4013636                   26
# 1                   4119359              4013636                   26
# 2                   4119359              4013636                   26
# 3                   4119359              4013636                   26
# 4                   4119359              4013636                   26
#
#    visit_concept_id visit_start_date visit_end_date  visit_type_concept_id
# 0              9202       2017-12-04     2017-12-04                  32817
# 1              9202       2017-12-04     2017-12-04                  32817
# 2              9202       2017-12-04     2017-12-04                  32817
# 3              9202       2017-12-04     2017-12-04                  32817
# 4              9202       2017-12-04     2017-12-04                  32817

# %%
staging_table.groupby('person_id')['procedure_date'].nunique().reset_index().sort_values('procedure_date', ascending=False)
# Out:
#     person_id  procedure_date
# 12       2593               6
# 4        1594               6
# 11       2556               5
# 10       2372               4
# 20       3290               4
# 17       3015               4
# 2        1572               4
# 6        1858               3
# 30       3609               3
# 29       3477               3
# 9        2161               3
# 5        1812               3
# 3        1580               3
# 26       3353               3
# 15       2970               3
# 16       2987               3
# 24       3332               3
# 19       3166               3
# 23       3331               3
# 22       3322               2
# 28       3415               2
# 25       3336               2
# 0          75               2
# 21       3304               2
# 18       3148               2
# 7        1885               2
# 34       3805               2
# 1         134               1
# 14       2754               1
# 27       3362               1
# 13       2753               1
# 8        1894               1
# 31       3645               1
# 32       3669               1
# 33       3750               1

# %%
# Create visit_occurrence_id
staging_table['visit_occurrence_id'] = staging_table.groupby(['person_id', 'procedure_date']).ngroup() + 1
staging_table.head()
# Out:
#                                       study_uid  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                      series_uid  \
# 0  2.16.124.113543.6006.99.06083117774660962009
# 1  2.16.124.113543.6006.99.06263494736769400825
# 2  2.16.124.113543.6006.99.06964874624365474765
# 3  2.16.124.113543.6006.99.07300304364963768908
# 4  2.16.124.113543.6006.99.08097639857522452001
#
#                                        StudyUID  person_id procedure_date  \
# 0  2.16.124.113543.6006.99.01060096421826160662       2161     2017-12-04
# 1  2.16.124.113543.6006.99.01060096421826160662       2161     2017-12-04
# 2  2.16.124.113543.6006.99.01060096421826160662       2161     2017-12-04
# 3  2.16.124.113543.6006.99.01060096421826160662       2161     2017-12-04
# 4  2.16.124.113543.6006.99.01060096421826160662       2161     2017-12-04
#
#    procedure_occurrence_id  image_occurrence_id  \
# 0                        1                    1
# 1                        1                    2
# 2                        1                    3
# 3                        1                    4
# 4                        1                    5
#
#                                           wadors_uri  \
# 0  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 1  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 2  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 3  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 4  https://imgextpoc-adnidicom.dicom.azurehealthc...
#
#    anatomic_site_concept_id  modality_concept_id  visit_occurrence_id
# 0                   4119359              4013636                   26
# 1                   4119359              4013636                   26
# 2                   4119359              4013636                   26
# 3                   4119359              4013636                   26
# 4                   4119359              4013636                   26

# %%
staging_table.groupby(['visit_occurrence_id']).nunique().reset_index().sort_values('procedure_date', ascending=False)
# Out:
#     visit_occurrence_id  study_uid  series_uid  StudyUID  person_id  \
# 0                     1          1           9         1          1
# 59                   60          1          10         1          1
# 68                   69          1          10         1          1
# 67                   68          1          10         1          1
# 66                   67          1          10         1          1
# ..                  ...        ...         ...       ...        ...
# 29                   30          1           9         1          1
# 28                   29          1           9         1          1
# 27                   28          1          13         1          1
# 26                   27          1          10         1          1
# 92                   93          1          11         1          1
#
#     procedure_date  procedure_occurrence_id  image_occurrence_id  wadors_uri  \
# 0                1                        1                    9           9
# 59               1                        1                   10          10
# 68               1                        1                   10          10
# 67               1                        1                   10          10
# 66               1                        1                   10          10
# ..             ...                      ...                  ...         ...
# 29               1                        1                    9           9
# 28               1                        1                    9           9
# 27               1                        1                   13          13
# 26               1                        1                   10          10
# 92               1                        1                   11          11
#
#     anatomic_site_concept_id  modality_concept_id
# 0                          1                    1
# 59                         1                    1
# 68                         1                    1
# 67                         1                    1
# 66                         1                    1
# ..                       ...                  ...
# 29                         1                    1
# 28                         1                    1
# 27                         1                    1
# 26                         1                    1
# 92                         1                    1
#
# [93 rows x 11 columns]

# %%
staging_table['visit_concept_id'] = 9202 #outpatient visit
staging_table['visit_start_date'] = staging_table['procedure_date']
staging_table['visit_end_date'] = staging_table['procedure_date']
staging_table['visit_type_concept_id'] = 32817 #EHR

# %%
staging_table.to_pickle('./files/image_occurrence_staging.pkl')

# %%
# PTID 00100020
# StudyDate (00080020)
# Acquisition Date (00080022)
# Study UID (0020000D)
# Series UID (0020000E)
# Study Description (00081030) 
# Modality (00080060)
# Body Part Examined (00180015)
# Series Description (0008103E)
# SOP Class UID (00080016)
# other instance level metadata into measurement and image_feature table
# filter out repetitive values per image series

# %%
# Extract information from metadata
def fetch_patient_details(base_url, headers):
    patient_data = []

    # Endpoint for fetching metadata of a study; adjust as needed
    metadata_url = f"{base_url}/studies/{study_uid}/metadata"

    # Fetch metadata for the current study
    metadata_response = requests.get(metadata_url, headers=headers)

    if metadata_response.status_code == 200:
        metadata = metadata_response.json()

        # Extract Patient ID, Gender, and Birth Date from the study metadata
        patient_id = metadata[0].get('00100020', {}).get('Value', [None])[0]
        study_uid = metadata[0].get("0020000D", {}).get("Value", [None])[0]
        series_uid = metadata[0].get("0020000E", {}).get("Value", [None])[0]
        study_description = metadata[0].get('00081030', {}).get('Value', [None])[0]
        study_date = metadata[0].get('00080020', {}).get('Value', [None])[0]
        acquisition_date = metadata[0].get('00080022', {}).get('Value', [None])[0]
        modality = metadata[0].get('00080060', {}).get('Value', [None])[0]
        body_part_examined = metadata[0].get('00180015', {}).get('Value', [None])[0]
        series_description = metadata[0].get('0008103E', {}).get('Value', [None])[0]
        sop_class_uid = metadata[0].get('00080016', {}).get('Value', [None])[0]

        patient_data.append({
            "StudyUID": study_uid,
            "SeriesUID": series_uid,
            "PatientID": patient_id,
            "Study_Description": study_description,
            "StudyDate": study_date,
            "AcquisitionDate": acquisition_date,
            "Modality": modality,
            "BodyPartExamined": body_part_examined,
            "SeriesDescription": series_description,
            "SOPClassUID": sop_class_uid
        })

    # Convert the list of records to a DataFrame
    return pd.DataFrame(patient_data)

# %%
headers = {
    'Authorization': 'Bearer ' + bearer_token,
    'Accept': 'application/dicom+json'
}
base_dicomweb_url = 'https://imgextpoc-adnidicom.dicom.azurehealthcareapis.com/v2'
patient_data = fetch_patient_details(base_dicomweb_url, headers)

# %%
patient_data.shape
# Out:
# (100, 9)

# %%
patient_data.head()
# Out:
#                                        StudyUID   PatientID  \
# 0  2.16.124.113543.6006.99.01060096421826160662  023_S_4448
# 1  2.16.124.113543.6006.99.01145873998336190369  024_S_6385
# 2  2.16.124.113543.6006.99.01486454390863664241  027_S_2219
# 3   2.16.124.113543.6006.99.0171281600952240178  027_S_2219
# 4   2.16.124.113543.6006.99.0177008878696943993  024_S_6846
#
#                                Study_Description StudyDate AcquisitionDate  \
# 0  ADNI3 Advanced Prisma_20171012^ADNI3 Advanced  20171204        20171204
# 1                                Brain^lop-adni3  20180529        20180529
# 2                   e+1 MR HEAD WITHOUT CONTRAST  20180206        20180206
# 3                   e+1 MR HEAD WITHOUT CONTRAST  20190207        20190207
# 4                                Brain^LOP-ADNI3  20210520        20210520
#
#   Modality BodyPartExamined   SeriesDescription                SOPClassUID
# 0       MR            BRAIN       Field Mapping  1.2.840.10008.5.1.4.1.1.4
# 1       MR            BRAIN  Perfusion_Weighted  1.2.840.10008.5.1.4.1.1.4
# 2       MR             None    Calibration Scan  1.2.840.10008.5.1.4.1.1.4
# 3       MR            BRAIN    Calibration Scan  1.2.840.10008.5.1.4.1.1.4
# 4       MR            BRAIN  Perfusion_Weighted  1.2.840.10008.5.1.4.1.1.4

# %%
import psycopg2

conn = psycopg2.connect(
    database="adni",
    user="",
    password="",
    host="",
    port="5432",
    connect_timeout = 6000
)

cursor = conn.cursor()

# %%
# Update PROCERURE_OCCURRENCE
sql = '''
    INSERT INTO adni.procedure_occurrence (procedure_occurrence_id, person_id, procedure_concept_id, procedure_date, procedure_type_concept_id) 
    VALUES (%s,%s,%s,%s,%s)
    '''
for index, row in patient_details_df.iterrows():
    cursor.execute(sql, (row['procedure_occurrence_id'], row['person_id'], row['procedure_concept_id'], row['procedure_date'], row['procedure_type_concept_id']))

conn.commit()

# %%
sql = '''select * from dbo.procedure_occurrence'''
omop_procedure = pd.read_sql(sql, conn)
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_93686/1896854644.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   omop_procedure = pd.read_sql(sql, conn)

# %%
omop_procedure['visit_occurrence_id'].nunique()
# Out:
# 93

# %%
# subset staging table to have two columns : procedure_occurrence_id, visit_occurrence_id
staging_table[['procedure_occurrence_id', 'visit_occurrence_id']]
# Out:
#      procedure_occurrence_id  visit_occurrence_id
# 0                          1                   26
# 1                          1                   26
# 2                          1                   26
# 3                          1                   26
# 4                          1                   26
# ..                       ...                  ...
# 884                       93                   73
# 885                       94                   64
# 886                       94                   64
# 887                       94                   64
# 888                       94                   64
#
# [889 rows x 2 columns]

# %%
omop_procedure = omop_procedure.merge(staging_table[['procedure_occurrence_id', 'visit_occurrence_id']], on='procedure_occurrence_id') #visit_occurrence_id_y
omop_procedure['visit_occurrence_id'] = omop_procedure['visit_occurrence_id_y']
# Out:
#    procedure_occurrence_id  person_id  procedure_concept_id procedure_date  \
# 0                        1       2161              36713262     2017-12-04
# 1                        1       2161              36713262     2017-12-04
# 2                        1       2161              36713262     2017-12-04
# 3                        1       2161              36713262     2017-12-04
# 4                        1       2161              36713262     2017-12-04
#
#   procedure_datetime procedure_end_date procedure_end_datetime  \
# 0               None               None                   None
# 1               None               None                   None
# 2               None               None                   None
# 3               None               None                   None
# 4               None               None                   None
#
#    procedure_type_concept_id modifier_concept_id quantity provider_id  \
# 0                      32817                None     None        None
# 1                      32817                None     None        None
# 2                      32817                None     None        None
# 3                      32817                None     None        None
# 4                      32817                None     None        None
#
#   visit_occurrence_id_x visit_detail_id procedure_source_value  \
# 0                  None            None                   None
# 1                  None            None                   None
# 2                  None            None                   None
# 3                  None            None                   None
# 4                  None            None                   None
#
#   procedure_source_concept_id modifier_source_value  visit_occurrence_id_y  \
# 0                        None                  None                     26
# 1                        None                  None                     26
# 2                        None                  None                     26
# 3                        None                  None                     26
# 4                        None                  None                     26
#
#    visit_occurrence_id
# 0                   26
# 1                   26
# 2                   26
# 3                   26
# 4                   26

# %%
omop_procedure = omop_procedure.drop(columns=['visit_occurrence_id_x', 'visit_occurrence_id_y'], axis = 1)

# %%
# Update Visit_OCCURRENCE
sql = '''
    INSERT INTO dbo.visit_occurrence (visit_occurrence_id, person_id, visit_concept_id, visit_start_date, visit_end_date, visit_type_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s)
    '''
for index, row in staging_table.iterrows():
    cursor.execute(sql, (row['visit_occurrence_id'], row['person_id'], row['visit_concept_id'], row['visit_start_date'], row['visit_end_date'], row['visit_type_concept_id']))

conn.commit()

# %%
sql = 'DELETE from dbo.procedure_occurrence'
cursor.execute(sql)
conn.commit()

# %%
# Update PROCERURE_OCCURRENCE
sql = '''
    INSERT INTO dbo.procedure_occurrence (procedure_occurrence_id, person_id, procedure_concept_id, procedure_date, procedure_type_concept_id, visit_occurrence_id) 
    VALUES (%s,%s,%s,%s,%s,%s)
    '''
for index, row in omop_procedure.iterrows():
    cursor.execute(sql, (row['procedure_occurrence_id'], row['person_id'], row['procedure_concept_id'], row['procedure_date'], row['procedure_type_concept_id'], row['visit_occurrence_id']))

conn.commit()

# %% [markdown]
# ## Update Image_occurrence table
#
# * PK, FK: image_occurrence_id, person_id, procedure_occurrence_id, visit_occurrence_id,
# * Concept IDs: anatomic_site_concept_id (0018,0015) - snomed, modality_concept_id (0008,0060)
# * wadors_uri, local_path (NA), image_occurrence_date (0008,0022), image_study_UID (0020,000D), series_UID (0020,0010)

# %%
image_occurrence_staging = series_attributes[["Study_UID", "Series_UID"]].drop_duplicates()
image_occurrence_staging

# %%
image_occurrence_staging = image_occurrence_staging.merge(patient_details_df[["StudyUID", "person_id", "procedure_date", "procedure_occurrence_id"]], left_on= "study_uid", right_on = 'StudyUID', how = 'left')

# Image occurrence ID
image_occurrence_staging['image_occurrence_id'], _ = pd.factorize(image_occurrence_staging['series_uid'])
image_occurrence_staging['image_occurrence_id'] = image_occurrence_staging['image_occurrence_id'] + 1 

# WADORS-URI
base_dicom_uri = 'https://imgextpoc-adnidicom.dicom.azurehealthcareapis.com/v2'
image_occurrence_staging['wadors_uri'] = base_dicom_uri + '/studies/' + image_occurrence_staging['study_uid'] + '/series/' + image_occurrence_staging['series_uid']

# Others
image_occurrence_staging['anatomic_site_concept_id'] = 4119359
image_occurrence_staging['modality_concept_id'] = 4013636

image_occurrence_staging

# %%
image_occurrence_staging = pd.read_pickle('./files/image_occurrence_staging.pkl')
image_occurrence_staging.head()
# Out:
#                                       study_uid  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                      series_uid  \
# 0  2.16.124.113543.6006.99.06083117774660962009
# 1  2.16.124.113543.6006.99.06263494736769400825
# 2  2.16.124.113543.6006.99.06964874624365474765
# 3  2.16.124.113543.6006.99.07300304364963768908
# 4  2.16.124.113543.6006.99.08097639857522452001
#
#                                        StudyUID  person_id procedure_date  \
# 0  2.16.124.113543.6006.99.01060096421826160662       2161     2017-12-04
# 1  2.16.124.113543.6006.99.01060096421826160662       2161     2017-12-04
# 2  2.16.124.113543.6006.99.01060096421826160662       2161     2017-12-04
# 3  2.16.124.113543.6006.99.01060096421826160662       2161     2017-12-04
# 4  2.16.124.113543.6006.99.01060096421826160662       2161     2017-12-04
#
#    procedure_occurrence_id  image_occurrence_id  \
# 0                        1                    1
# 1                        1                    2
# 2                        1                    3
# 3                        1                    4
# 4                        1                    5
#
#                                           wadors_uri  \
# 0  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 1  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 2  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 3  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 4  https://imgextpoc-adnidicom.dicom.azurehealthc...
#
#    anatomic_site_concept_id  modality_concept_id
# 0                   4119359              4013636
# 1                   4119359              4013636
# 2                   4119359              4013636
# 3                   4119359              4013636
# 4                   4119359              4013636

# %%
# Update IMAGE_OCCURRENCE
sql = '''
    INSERT INTO adni.image_occurrence (image_occurrence_id, person_id, procedure_occurrence_id, anatomic_site_concept_id, wadors_uri, image_occurrence_date, image_study_uid, image_series_uid, modality_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in image_occurrence_staging.iterrows():
    cursor.execute(sql, (row['image_occurrence_id'], row['person_id'], row['procedure_occurrence_id'],  row['anatomic_site_concept_id'], row['wadors_uri'], row['procedure_date'],
                    row['study_uid'], row['series_uid'], row['modality_concept_id']))

conn.commit()

# %% [markdown]
# ## Update Measurement table
#
# * Numeric and non-numeric values have different fields
# * One Image_feature row has one Measurement row.
# * Create one stage table for Measurement and Image_feature input data.
# * Required fields: measurement_id, person_id, measurement_concept_id, measurement_date, measurement_type_concept_id, value_as_number, measurement_source_value

# %% [markdown]
# ## Update Image_feature table
#
# * PK, FK: image_feature_id, person_id, image_occurrence_id, image_feature_event_id
# * Clinical domain: image_feature_event_field_concept_id (1147330 = measurement table)
# * image_feature_concept_id: matching tags from the staging table
# * image_feature_type_concept_id: acquisition parameter (add a new concept id? can I use the concept class id?)
# * anatomic_site_concept_id: for acquisition parameter, same as (0018,0015) - snomed

# %%
series_attributes = pd.read_pickle('./files/image_series_metadata.pkl')
series_attributes.head()
# Out:
#                                       Study_UID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                      Series_UID Attribute Tag          Value  \
# 0  2.16.124.113543.6006.99.06083117774660962009      00080005     ISO_IR 100
# 1  2.16.124.113543.6006.99.06083117774660962009      00080008       ORIGINAL
# 2  2.16.124.113543.6006.99.06083117774660962009      00080013  132059.935000
# 3  2.16.124.113543.6006.99.06083117774660962009      00080020       20171204
# 4  2.16.124.113543.6006.99.06083117774660962009      00080021       20171204
#
#    concept_id            concept_name value_as_number  image_feature_id  \
# 0  2128000011  Specific Character Set             NaN                 1
# 1  2128000012              Image Type             NaN                 2
# 2  2128000014  Instance Creation Time             NaN                 3
# 3  2128000016              Study Date             NaN                 4
# 4  2128000017             Series Date             NaN                 5
#
#    measurement_id  measurement_type_concept_id image_occurrence_date  \
# 0               1                        32817            2017-12-04
# 1               2                        32817            2017-12-04
# 2               3                        32817            2017-12-04
# 3               4                        32817            2017-12-04
# 4               5                        32817            2017-12-04
#
#    person_id  image_occurrence_id  image_feature_event_field_concept_id  \
# 0       2161                    1                               1147330
# 1       2161                    1                               1147330
# 2       2161                    1                               1147330
# 3       2161                    1                               1147330
# 4       2161                    1                               1147330
#
#    anatomic_site_concept_id
# 0                   4119359
# 1                   4119359
# 2                   4119359
# 3                   4119359
# 4                   4119359

# %%
agg_attr = series_attributes.groupby(['Study_UID', 'Series_UID', 'Attribute Tag']).size().reset_index(name='counts')

# %%
# Echo time 2128000367 (less or equal than 10 )
# Repetition time 2128000366 (values between 500 and 800 )
# Inversion time 2128000368 (values between 900 1100 )
# Flip angle 2128000493 (values between 8 and 15)
# Field of view 2128000378 (values between 220 and 250 )
# max int value = 2,147,483,647
# Number of slices 2128001004 (above 150) -> count the number of slices and put it as 2129001004

attr_list = [2128000367, 2128000366, 2128000368, 2128000493, 2128000378]

# %%
series_attributes[series_attributes['Series_UID'].isin(agg_attr[agg_attr['counts'] > 1]['Series_UID'])]['concept_name'].unique()
# Out:
# array(['Specific Character Set', 'Image Type', 'Instance Creation Time',
#        'Study Date', 'Series Date', 'Acquisition Date', 'Content Date',
#        'Study Time', 'Series Time', 'Acquisition Time', 'Content Time',
#        'Modality', "Patient's Sex", "Patient's Size", "Patient's Weight",
#        'Body Part Examined', 'Scanning Sequence', 'Sequence Variant',
#        'Scan Options', 'MR Acquisition Type', 'Angio Flag',
#        'Slice Thickness', 'Repetition Time', 'Echo Time',
#        'Inversion Time', 'Number of Averages', 'Imaging Frequency',
#        'Echo Number(s)', 'Magnetic Field Strength',
#        'Number of Phase Encoding Steps', 'Echo Train Length',
#        'Percent Sampling', 'Percent Phase Field of View',
#        'Pixel Bandwidth', 'Acquisition Matrix',
#        'In-plane Phase Encoding Direction', 'Flip Angle',
#        'Variable Flip Angle Flag', 'SAR', 'dB/dt', 'Patient Position',
#        'Series Number', 'Acquisition Number', 'Instance Number',
#        'Image Position (Patient)', 'Image Orientation (Patient)',
#        'Slice Location', 'Samples per Pixel',
#        'Photometric Interpretation', 'Rows', 'Columns', 'Pixel Spacing',
#        'Bits Allocated', 'Bits Stored', 'High Bit',
#        'Pixel Representation', 'Window Center', 'Window Width',
#        'Performed Procedure Step Start Time', 'Spacing Between Slices',
#        'Rescale Intercept', 'Rescale Slope', 'Heart Rate',
#        'Cardiac Number of Images', 'Trigger Window',
#        'Reconstruction Diameter', 'Laterality', 'Images in Acquisition',
#        'In-Stack Position Number', 'Instance Creation Date',
#        'Trigger Time', 'Relative Opacity', 'Pixel Presentation',
#        'Volumetric Properties', 'Volume Based Calculation Technique',
#        'Complex Image Component', 'Acquisition Contrast',
#        'Patient Identity Removed', 'B1rms', 'Content Qualification',
#        'Echo Pulse Sequence', 'Multi-planar Excitation', 'Phase Contrast',
#        'Time of Flight Contrast', 'Steady State Pulse Sequence',
#        'Echo Planar Pulse Sequence', 'Saturation Recovery',
#        'Spectrally Selected Suppression', 'Oversampling Phase',
#        'Geometry of k-Space Traversal', 'Segmented k-Space Traversal',
#        'Rectilinear Phase Encode Reordering', 'k-space Filtering',
#        'Acquisition Duration', 'Number of k-Space Trajectories',
#        'Resonant Nucleus', 'Applicable Safety Standard Agency',
#        'Number of Temporal Positions', 'Number of Frames',
#        'Burned In Annotation', 'Lossy Image Compression',
#        'Presentation LUT Shape', 'Coverage of k-Space',
#        'Arterial Spin Labeling Contrast', 'Beat Rejection Flag'],
#       dtype=object)

# %%
series_attr_to_load = series_attributes[series_attributes['Attribute Tag'].isin(agg_attr[agg_attr['counts'] == 1]['Attribute Tag'])]
series_attr_to_load
# Out:
#                                            Study_UID  \
# 0       2.16.124.113543.6006.99.01060096421826160662
# 1       2.16.124.113543.6006.99.01060096421826160662
# 2       2.16.124.113543.6006.99.01060096421826160662
# 3       2.16.124.113543.6006.99.01060096421826160662
# 4       2.16.124.113543.6006.99.01060096421826160662
# ...                                              ...
# 485022   2.16.124.113543.6006.99.9035087760856874683
# 485023   2.16.124.113543.6006.99.9035087760856874683
# 485024   2.16.124.113543.6006.99.9035087760856874683
# 485025   2.16.124.113543.6006.99.9035087760856874683
# 485026   2.16.124.113543.6006.99.9035087760856874683
#
#                                           Series_UID Attribute Tag  \
# 0       2.16.124.113543.6006.99.06083117774660962009      00080005
# 1       2.16.124.113543.6006.99.06083117774660962009      00080008
# 2       2.16.124.113543.6006.99.06083117774660962009      00080013
# 3       2.16.124.113543.6006.99.06083117774660962009      00080020
# 4       2.16.124.113543.6006.99.06083117774660962009      00080021
# ...                                              ...           ...
# 485022   2.16.124.113543.6006.99.8706306584783342182      00281050
# 485023   2.16.124.113543.6006.99.8706306584783342182      00281051
# 485024   2.16.124.113543.6006.99.8706306584783342182      00281052
# 485025   2.16.124.113543.6006.99.8706306584783342182      00281053
# 485026   2.16.124.113543.6006.99.8706306584783342182      00400245
#
#                 Value  concept_id                         concept_name  \
# 0          ISO_IR 100  2128000011               Specific Character Set
# 1            ORIGINAL  2128000012                           Image Type
# 2       132059.935000  2128000014               Instance Creation Time
# 3            20171204  2128000016                           Study Date
# 4            20171204  2128000017                          Series Date
# ...               ...         ...                                  ...
# 485022           -306  2128001273                        Window Center
# 485023           5377  2128001274                         Window Width
# 485024          -4096  2128001275                    Rescale Intercept
# 485025       2.000244  2128001276                        Rescale Slope
# 485026  143901.101000  2128001422  Performed Procedure Step Start Time
#
#        value_as_number  image_feature_id  measurement_id  \
# 0                  NaN                 1               1
# 1                  NaN                 2               2
# 2                  NaN                 3               3
# 3                  NaN                 4               4
# 4                  NaN                 5               5
# ...                ...               ...             ...
# 485022            -306            485023          485023
# 485023            5377            485024          485024
# 485024           -4096            485025          485025
# 485025        2.000244            485026          485026
# 485026             NaN            485027          485027
#
#         measurement_type_concept_id image_occurrence_date  person_id  \
# 0                             32817            2017-12-04       2161
# 1                             32817            2017-12-04       2161
# 2                             32817            2017-12-04       2161
# 3                             32817            2017-12-04       2161
# 4                             32817            2017-12-04       2161
# ...                             ...                   ...        ...
# 485022                        32817            2018-03-16       3223
# 485023                        32817            2018-03-16       3223
# 485024                        32817            2018-03-16       3223
# 485025                        32817            2018-03-16       3223
# 485026                        32817            2018-03-16       3223
#
#         image_occurrence_id  image_feature_event_field_concept_id  \
# 0                         1                               1147330
# 1                         1                               1147330
# 2                         1                               1147330
# 3                         1                               1147330
# 4                         1                               1147330
# ...                     ...                                   ...
# 485022                  948                               1147330
# 485023                  948                               1147330
# 485024                  948                               1147330
# 485025                  948                               1147330
# 485026                  948                               1147330
#
#         anatomic_site_concept_id
# 0                        4119359
# 1                        4119359
# 2                        4119359
# 3                        4119359
# 4                        4119359
# ...                          ...
# 485022                   4119359
# 485023                   4119359
# 485024                   4119359
# 485025                   4119359
# 485026                   4119359
#
# [471285 rows x 15 columns]

# %%
instance_attr_to_load = series_attr_to_load[series_attr_to_load['concept_id'].isin(attr_list)]
instance_attr_to_load.head()
# Out:
#                                        Study_UID  \
# 22  2.16.124.113543.6006.99.01060096421826160662
# 23  2.16.124.113543.6006.99.01060096421826160662
# 24  2.16.124.113543.6006.99.01060096421826160662
# 32  2.16.124.113543.6006.99.01060096421826160662
# 36  2.16.124.113543.6006.99.01060096421826160662
#
#                                       Series_UID Attribute Tag  Value  \
# 22  2.16.124.113543.6006.99.06083117774660962009      00180080   2300
# 23  2.16.124.113543.6006.99.06083117774660962009      00180081   2.98
# 24  2.16.124.113543.6006.99.06083117774660962009      00180082    900
# 32  2.16.124.113543.6006.99.06083117774660962009      00180094  93.75
# 36  2.16.124.113543.6006.99.06083117774660962009      00181314      9
#
#     concept_id                 concept_name value_as_number  image_feature_id  \
# 22  2128000366              Repetition Time            2300                23
# 23  2128000367                    Echo Time            2.98                24
# 24  2128000368               Inversion Time             900                25
# 32  2128000378  Percent Phase Field of View           93.75                33
# 36  2128000493                   Flip Angle               9                37
#
#     measurement_id  measurement_type_concept_id image_occurrence_date  \
# 22              23                        32817            2017-12-04
# 23              24                        32817            2017-12-04
# 24              25                        32817            2017-12-04
# 32              33                        32817            2017-12-04
# 36              37                        32817            2017-12-04
#
#     person_id  image_occurrence_id  image_feature_event_field_concept_id  \
# 22       2161                    1                               1147330
# 23       2161                    1                               1147330
# 24       2161                    1                               1147330
# 32       2161                    1                               1147330
# 36       2161                    1                               1147330
#
#     anatomic_site_concept_id
# 22                   4119359
# 23                   4119359
# 24                   4119359
# 32                   4119359
# 36                   4119359

# %%
series_attr_to_load['value_as_number'] = series_attr_to_load['value_as_number'].fillna(0)
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_95336/2483624578.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   series_attr_to_load['value_as_number'] = series_attr_to_load['value_as_number'].fillna(0)

# %%
series_attr_to_load = series_attr_to_load[series_attr_to_load['value_as_number']!='']

# %%
import psycopg2

conn = psycopg2.connect(
    database="postgres",
    user="postgres",
    password="hopkinsdb",
    host="20.190.196.193",
    port="5432",
    connect_timeout = 6000
)

cursor = conn.cursor()

# %%
# Update MEASUREMENT
sql = '''
    INSERT INTO adni.measurement (measurement_id, person_id, measurement_concept_id, measurement_date, measurement_type_concept_id, value_as_number, measurement_source_value) 
    VALUES (%s,%s,%s,%s,%s,%s,%s)
'''

# Define batch size
batch_size = 20000
batch = []

# Iterate through the DataFrame
for index, row in series_attr_to_load.iterrows():
    # Append row data to the batch
    batch.append((row['measurement_id'], row['person_id'], row['concept_id'], row['image_occurrence_date'], row['measurement_type_concept_id'], row['value_as_number'], row['Value']))

    # Check if batch size is reached or if it's the last row
    if len(batch) == batch_size or (index == len(series_attr_to_load) - 1):
        # Execute the batch
        cursor.executemany(sql, batch)
        conn.commit()  # Commit after each batch
        batch = []  # Clear the batch for the next set of rows

# %%
# Update IMAGE_FEATURE
# numeric data
sql = '''
    INSERT INTO adni.image_feature (image_feature_id, person_id, image_occurrence_id, image_feature_event_id,
      image_feature_event_field_concept_id, image_feature_concept_id, image_feature_type_concept_id, anatomic_site_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
'''

# Define batch size
batch_size = 20000
batch = []

# Iterate through the DataFrame
for index, row in series_attr_to_load.iterrows():
    # Append row data to the batch
    batch.append((row['image_feature_id'], row['person_id'], row['image_occurrence_id'], row['measurement_id'], 
                  row['image_feature_event_field_concept_id'], row['concept_id'], row['measurement_type_concept_id'],
                  row['anatomic_site_concept_id']))

    # Check if batch size is reached or if it's the last row
    if len(batch) == batch_size or (index == len(series_attributes) - 1):
        # Execute the batch
        cursor.executemany(sql, batch)
        conn.commit()  # Commit after each batch
        batch = []  # Clear the batch for the next set of rows

# Close the cursor and connection
cursor.close()
conn.close()

# %% [markdown]
# ### Instance level attributes

# %%
# upload instance level attributes
import psycopg2

conn = psycopg2.connect(
    database="postgres",
    user="postgres",
    password="hopkinsdb",
    host="20.190.196.193",
    port="5432",
    connect_timeout = 6000
)

cursor = conn.cursor()

# %%
# Update MEASUREMENT
sql = '''
    INSERT INTO adni.measurement (measurement_id, person_id, measurement_concept_id, measurement_date, measurement_type_concept_id, value_as_number, measurement_source_value) 
    VALUES (%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in instance_attr_to_load.iterrows():
    cursor.execute(sql, (row['measurement_id'], row['person_id'], row['concept_id'], row['image_occurrence_date'], row['measurement_type_concept_id'], row['value_as_number'], row['Value']))

conn.commit()

# %%
# Update IMAGE_FEATURE
sql = '''
    INSERT INTO adni.image_feature (image_feature_id, person_id, image_occurrence_id, image_feature_event_id,
      image_feature_event_field_concept_id, image_feature_concept_id, image_feature_type_concept_id, anatomic_site_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in instance_attr_to_load.iterrows():
    cursor.execute(sql, (row['image_feature_id'], row['person_id'], row['image_occurrence_id'], row['measurement_id'], 
                  row['image_feature_event_field_concept_id'], row['concept_id'], row['measurement_type_concept_id'],
                  row['anatomic_site_concept_id']))

conn.commit()

# %% [markdown]
# #### Custom concept for instance slices

# %%
# Update CONCEPT with new concept id for number of slices (counted), not from DICOM tag
cursor = conn.cursor()

sql = '''
    INSERT INTO adni.concept (concept_id,concept_name,domain_id,vocabulary_id,concept_class_id,standard_concept,concept_code,valid_start_date,valid_end_date,invalid_reason)
    VALUES (2129001004, 'Number of slices - count', 'Measurement', 'DICOM', 'DICOM Attributes', '', 0, '2099-12-31', '1993-01-01', '')
    '''
cursor.execute(sql)
conn.commit()

# %%
instance_attr_to_load.head()
# Out:
#                                        Study_UID  \
# 22  2.16.124.113543.6006.99.01060096421826160662
# 23  2.16.124.113543.6006.99.01060096421826160662
# 24  2.16.124.113543.6006.99.01060096421826160662
# 32  2.16.124.113543.6006.99.01060096421826160662
# 36  2.16.124.113543.6006.99.01060096421826160662
#
#                                       Series_UID Attribute Tag  Value  \
# 22  2.16.124.113543.6006.99.06083117774660962009      00180080   2300
# 23  2.16.124.113543.6006.99.06083117774660962009      00180081   2.98
# 24  2.16.124.113543.6006.99.06083117774660962009      00180082    900
# 32  2.16.124.113543.6006.99.06083117774660962009      00180094  93.75
# 36  2.16.124.113543.6006.99.06083117774660962009      00181314      9
#
#     concept_id                 concept_name value_as_number  image_feature_id  \
# 22  2128000366              Repetition Time            2300                23
# 23  2128000367                    Echo Time            2.98                24
# 24  2128000368               Inversion Time             900                25
# 32  2128000378  Percent Phase Field of View           93.75                33
# 36  2128000493                   Flip Angle               9                37
#
#     measurement_id  measurement_type_concept_id image_occurrence_date  \
# 22              23                        32817            2017-12-04
# 23              24                        32817            2017-12-04
# 24              25                        32817            2017-12-04
# 32              33                        32817            2017-12-04
# 36              37                        32817            2017-12-04
#
#     person_id  image_occurrence_id  image_feature_event_field_concept_id  \
# 22       2161                    1                               1147330
# 23       2161                    1                               1147330
# 24       2161                    1                               1147330
# 32       2161                    1                               1147330
# 36       2161                    1                               1147330
#
#     anatomic_site_concept_id
# 22                   4119359
# 23                   4119359
# 24                   4119359
# 32                   4119359
# 36                   4119359

# %%
instance_counts = series_attributes.groupby(['Study_UID', 'Series_UID', 'person_id', 'image_occurrence_date', 'image_occurrence_id', 'image_feature_event_field_concept_id', 'anatomic_site_concept_id']).size().reset_index(name='counts')
instance_counts.head()
# Out:
#                                       Study_UID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                      Series_UID  person_id  \
# 0  2.16.124.113543.6006.99.06083117774660962009       2161
# 1  2.16.124.113543.6006.99.06263494736769400825       2161
# 2  2.16.124.113543.6006.99.06964874624365474765       2161
# 3  2.16.124.113543.6006.99.07300304364963768908       2161
# 4  2.16.124.113543.6006.99.08097639857522452001       2161
#
#   image_occurrence_date  image_occurrence_id  \
# 0            2017-12-04                    1
# 1            2017-12-04                    2
# 2            2017-12-04                    3
# 3            2017-12-04                    4
# 4            2017-12-04                    5
#
#    image_feature_event_field_concept_id  anatomic_site_concept_id  counts
# 0                               1147330                   4119359    1294
# 1                               1147330                   4119359      75
# 2                               1147330                   4119359      61
# 3                               1147330                   4119359     678
# 4                               1147330                   4119359     206

# %%
instance_counts = image_series.groupby(['Study_UID', 'Series_UID', 'person_id', 'image_occurrence_date', 'image_occurrence_id', 'image_feature_event_field_concept_id', 'anatomic_site_concept_id']).size().reset_index(name='counts')
instance_counts.head()
# Out:
#                                       Study_UID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                      Series_UID  person_id  \
# 0  2.16.124.113543.6006.99.06083117774660962009       2161
# 1  2.16.124.113543.6006.99.06263494736769400825       2161
# 2  2.16.124.113543.6006.99.06964874624365474765       2161
# 3  2.16.124.113543.6006.99.07300304364963768908       2161
# 4  2.16.124.113543.6006.99.08097639857522452001       2161
#
#   image_occurrence_date  image_occurrence_id  \
# 0            2017-12-04                    1
# 1            2017-12-04                    2
# 2            2017-12-04                    3
# 3            2017-12-04                    4
# 4            2017-12-04                    5
#
#    image_feature_event_field_concept_id  anatomic_site_concept_id  counts
# 0                               1147330                   4119359    1294
# 1                               1147330                   4119359      75
# 2                               1147330                   4119359      61
# 3                               1147330                   4119359     678
# 4                               1147330                   4119359     206

# %%
print(image_series.measurement_id.max())
print(image_series.image_feature_id.max())
# Out:
# 485027
# 485027

# %%
instance_counts['Value'] = instance_counts['counts']
instance_counts['concept_id'] = 2129001004
instance_counts['value_as_number'] = instance_counts['counts']
instance_counts['measurement_id'] = 485028 + instance_counts.index
instance_counts['measurement_type_concept_id'] = 32817

instance_counts.shape
# Out:
# (948, 13)

# %%
instance_counts.head()
# Out:
#                                       Study_UID  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                      Series_UID  person_id  \
# 0  2.16.124.113543.6006.99.06083117774660962009       2161
# 1  2.16.124.113543.6006.99.06263494736769400825       2161
# 2  2.16.124.113543.6006.99.06964874624365474765       2161
# 3  2.16.124.113543.6006.99.07300304364963768908       2161
# 4  2.16.124.113543.6006.99.08097639857522452001       2161
#
#   image_occurrence_date  image_occurrence_id  \
# 0            2017-12-04                    1
# 1            2017-12-04                    2
# 2            2017-12-04                    3
# 3            2017-12-04                    4
# 4            2017-12-04                    5
#
#    image_feature_event_field_concept_id  anatomic_site_concept_id  counts  \
# 0                               1147330                   4119359    1294
# 1                               1147330                   4119359      75
# 2                               1147330                   4119359      61
# 3                               1147330                   4119359     678
# 4                               1147330                   4119359     206
#
#    Value  concept_id  value_as_number  measurement_id  \
# 0   1294  2129001004             1294          485028
# 1     75  2129001004               75          485029
# 2     61  2129001004               61          485030
# 3    678  2129001004              678          485031
# 4    206  2129001004              206          485032
#
#    measurement_type_concept_id
# 0                        32817
# 1                        32817
# 2                        32817
# 3                        32817
# 4                        32817

# %%
# Update MEASUREMENT
sql = '''
    INSERT INTO dbo.measurement (measurement_id, person_id, measurement_concept_id, measurement_date, measurement_type_concept_id, value_as_number, measurement_source_value, measurement_source_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in instance_counts.iterrows():
    cursor.execute(sql, (row['measurement_id'], row['person_id'], row['concept_id'], row['image_occurrence_date'], row['measurement_type_concept_id'], row['value_as_number'], row['Value'], row['concept_id']))

conn.commit()

# %%
# Update IMAGE_FEATURE
sql = '''
    INSERT INTO dbo.image_feature (image_feature_id, person_id, image_occurrence_id, image_feature_event_id,
      image_feature_event_field_concept_id, image_feature_concept_id, image_feature_type_concept_id, anatomic_site_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in instance_counts.iterrows():
    cursor.execute(sql, (row['measurement_id'], row['person_id'], row['image_occurrence_id'], row['measurement_id'], 
                  row['image_feature_event_field_concept_id'], row['concept_id'], row['measurement_type_concept_id'],
                  row['anatomic_site_concept_id']))

conn.commit()

# %%
df = df_measurement_final.merge(df_concept, left_on = 'measurement_source_concept_id', right_on = 'concept_id')

# %%
concepts = df.groupby('concept_name').nunique()

# %%
concepts
# Out:
#                        measurement_id  person_id  measurement_concept_id  \
# concept_name
# Acquisition Contrast               92          7                       1
# Acquisition Date                  833         36                       1
# Acquisition Duration              110          7                       1
# Acquisition Matrix                898         36                       1
# Acquisition Number               8820         36                       1
# ...                               ...        ...                     ...
# Volumetric Properties              92          7                       1
# Window Center                   45194         36                       1
# Window Width                    50597         36                       1
# dB/dt                             624         28                       1
# k-space Filtering                  92          7                       1
#
#                        measurement_date  measurement_datetime  \
# concept_name
# Acquisition Contrast                  6                     0
# Acquisition Date                     84                     0
# Acquisition Duration                  6                     0
# Acquisition Matrix                   84                     0
# Acquisition Number                   90                     0
# ...                                 ...                   ...
# Volumetric Properties                 6                     0
# Window Center                        84                     0
# Window Width                         84                     0
# dB/dt                                59                     0
# k-space Filtering                     6                     0
#
#                        measurement_time  measurement_type_concept_id  \
# concept_name
# Acquisition Contrast                  0                            1
# Acquisition Date                      0                            1
# Acquisition Duration                  0                            1
# Acquisition Matrix                    0                            1
# Acquisition Number                    0                            1
# ...                                 ...                          ...
# Volumetric Properties                 0                            1
# Window Center                         0                            1
# Window Width                          0                            1
# dB/dt                                 0                            1
# k-space Filtering                     0                            1
#
#                        operator_concept_id  value_as_number  \
# concept_name
# Acquisition Contrast                     0                1
# Acquisition Date                         0                1
# Acquisition Duration                     0               15
# Acquisition Matrix                       0                1
# Acquisition Number                       0              976
# ...                                    ...              ...
# Volumetric Properties                    0                1
# Window Center                            0             3951
# Window Width                             0             6445
# dB/dt                                    0                1
# k-space Filtering                        0                1
#
#                        value_as_concept_id  ...  meas_event_field_concept_id  \
# concept_name                                ...
# Acquisition Contrast                     0  ...                            0
# Acquisition Date                         0  ...                            0
# Acquisition Duration                     0  ...                            0
# Acquisition Matrix                       0  ...                            0
# Acquisition Number                       0  ...                            0
# ...                                    ...  ...                          ...
# Volumetric Properties                    0  ...                            0
# Window Center                            0  ...                            0
# Window Width                             0  ...                            0
# dB/dt                                    0  ...                            0
# k-space Filtering                        0  ...                            0
#
#                        concept_id  domain_id  vocabulary_id  concept_class_id  \
# concept_name
# Acquisition Contrast            1          1              1                 1
# Acquisition Date                1          1              1                 1
# Acquisition Duration            1          1              1                 1
# Acquisition Matrix              1          1              1                 1
# Acquisition Number              1          1              1                 1
# ...                           ...        ...            ...               ...
# Volumetric Properties           1          1              1                 1
# Window Center                   1          1              1                 1
# Window Width                    1          1              1                 1
# dB/dt                           1          1              1                 1
# k-space Filtering               1          1              1                 1
#
#                        standard_concept  concept_code  valid_start_date  \
# concept_name
# Acquisition Contrast                  1             1                 1
# Acquisition Date                      1             1                 1
# Acquisition Duration                  1             1                 1
# Acquisition Matrix                    1             1                 1
# Acquisition Number                    1             1                 1
# ...                                 ...           ...               ...
# Volumetric Properties                 1             1                 1
# Window Center                         1             1                 1
# Window Width                          1             1                 1
# dB/dt                                 1             1                 1
# k-space Filtering                     1             1                 1
#
#                        valid_end_date  invalid_reason
# concept_name
# Acquisition Contrast                1               1
# Acquisition Date                    1               1
# Acquisition Duration                1               1
# Acquisition Matrix                  1               1
# Acquisition Number                  1               1
# ...                               ...             ...
# Volumetric Properties               1               1
# Window Center                       1               1
# Window Width                        1               1
# dB/dt                               1               1
# k-space Filtering                   1               1
#
# [104 rows x 32 columns]

# %%
# Echo time 2128000367 (less or equal than 10 )
# Repetition time 2128000366 (values between 500 and 800 )
# Inversion time 2128000368 (values between 900 1100 )
# Flip angle 2128000493 (values between 8 and 15)
# Field of view 2128000378 (values between 220 and 250 )
# max int value = 2,147,483,647
# Number of slices 2128001004 (above 150) -> count the number of slices and put it as 2129001004

# %%
sql = '''select * from dbo.measurement where measurement_concept_id > 2000000000'''
omop_measurement = pd.read_sql(sql, conn)
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_13203/3366930718.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   omop_measurement = pd.read_sql(sql, conn)

# %%
omop_measurement.describe()
# Out:
#        measurement_id      person_id  measurement_concept_id  \
# count   463309.000000  463309.000000            4.633090e+05
# mean    237433.606073    2752.812637            2.128005e+09
# std     136368.030748     807.056356            6.386207e+04
# min          1.000000      75.000000            2.128000e+09
# 25%     120602.000000    2161.000000            2.128000e+09
# 50%     237061.000000    3015.000000            2.128001e+09
# 75%     354042.000000    3336.000000            2.128001e+09
# max     485975.000000    3805.000000            2.129001e+09
#
#        measurement_type_concept_id  value_as_number  \
# count                     463309.0    463309.000000
# mean                       32817.0       365.285973
# std                            0.0      1117.531586
# min                        32817.0     -4096.000000
# 25%                        32817.0         0.000000
# 50%                        32817.0         1.000000
# 75%                        32817.0       114.000000
# max                        32817.0     19541.000000
#
#        measurement_source_concept_id
# count                   4.633090e+05
# mean                    2.128005e+09
# std                     6.386207e+04
# min                     2.128000e+09
# 25%                     2.128000e+09
# 50%                     2.128001e+09
# 75%                     2.128001e+09
# max                     2.129001e+09

# %%
omop_measurement['person_id'].nunique()
# Out:
# 37

# %%
omop_measurement

# %%
omop_measurement[omop_measurement['measurement_source_concept_id']==2129001004]['value_as_number'].hist()
# Out:
# <Axes: >

# %%
omop_measurement[(omop_measurement['measurement_source_concept_id']==2129001004) & (omop_measurement['value_as_number'] > 140)]
# Out:
#         measurement_id  person_id  measurement_concept_id measurement_date  \
# 461404          485028       2161              2129001004       2017-12-04
# 461407          485031       2161              2129001004       2017-12-04
# 461408          485032       2161              2129001004       2017-12-04
# 461409          485033       2161              2129001004       2017-12-04
# 461410          485034       2161              2129001004       2017-12-04
# ...                ...        ...                     ...              ...
# 463302          485969       3223              2129001004       2018-03-16
# 463303          485970       3223              2129001004       2018-03-16
# 463304          485971       3223              2129001004       2018-03-16
# 463306          485973       3223              2129001004       2018-03-16
# 463307          485974       3223              2129001004       2018-03-16
#
#        measurement_datetime measurement_time  measurement_type_concept_id  \
# 461404                 None             None                        32817
# 461407                 None             None                        32817
# 461408                 None             None                        32817
# 461409                 None             None                        32817
# 461410                 None             None                        32817
# ...                     ...              ...                          ...
# 463302                 None             None                        32817
# 463303                 None             None                        32817
# 463304                 None             None                        32817
# 463306                 None             None                        32817
# 463307                 None             None                        32817
#
#        operator_concept_id  value_as_number value_as_concept_id  ...  \
# 461404                None           1294.0                None  ...
# 461407                None            678.0                None  ...
# 461408                None            206.0                None  ...
# 461409                None            867.0                None  ...
# 461410                None            839.0                None  ...
# ...                    ...              ...                 ...  ...
# 463302                None            170.0                None  ...
# 463303                None           1280.0                None  ...
# 463304                None            868.0                None  ...
# 463306                None            992.0                None  ...
# 463307                None            855.0                None  ...
#
#        provider_id visit_occurrence_id visit_detail_id  \
# 461404        None                None            None
# 461407        None                None            None
# 461408        None                None            None
# 461409        None                None            None
# 461410        None                None            None
# ...            ...                 ...             ...
# 463302        None                None            None
# 463303        None                None            None
# 463304        None                None            None
# 463306        None                None            None
# 463307        None                None            None
#
#        measurement_source_value measurement_source_concept_id  \
# 461404                     1294                    2129001004
# 461407                      678                    2129001004
# 461408                      206                    2129001004
# 461409                      867                    2129001004
# 461410                      839                    2129001004
# ...                         ...                           ...
# 463302                      170                    2129001004
# 463303                     1280                    2129001004
# 463304                      868                    2129001004
# 463306                      992                    2129001004
# 463307                      855                    2129001004
#
#        unit_source_value unit_source_concept_id  value_source_value  \
# 461404              None                   None                None
# 461407              None                   None                None
# 461408              None                   None                None
# 461409              None                   None                None
# 461410              None                   None                None
# ...                  ...                    ...                 ...
# 463302              None                   None                None
# 463303              None                   None                None
# 463304              None                   None                None
# 463306              None                   None                None
# 463307              None                   None                None
#
#        measurement_event_id meas_event_field_concept_id
# 461404                 None                        None
# 461407                 None                        None
# 461408                 None                        None
# 461409                 None                        None
# 461410                 None                        None
# ...                     ...                         ...
# 463302                 None                        None
# 463303                 None                        None
# 463304                 None                        None
# 463306                 None                        None
# 463307                 None                        None
#
# [1376 rows x 23 columns]

# %%
sql = '''select * from dbo.image_feature'''
omop_image_feature = pd.read_sql(sql, conn)
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_93686/2487770237.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   omop_image_feature = pd.read_sql(sql, conn)

# %%
omop_image_feature.describe()
# Out:
#        image_feature_id      person_id  image_occurrence_id  \
# count     476127.000000  476127.000000        476127.000000
# mean      243899.229325    2753.697306           473.554951
# std       140024.889471     806.428229           273.607775
# min            1.000000      75.000000             1.000000
# 25%       124355.000000    2161.000000           246.000000
# 50%       243421.000000    3015.000000           470.000000
# 75%       364097.500000    3336.000000           704.000000
# max       485975.000000    3805.000000           948.000000
#
#        image_feature_event_field_concept_id  image_feature_event_id  \
# count                              476127.0           476127.000000
# mean                              1147330.0           243899.229325
# std                                     0.0           140024.889471
# min                               1147330.0                1.000000
# 25%                               1147330.0           124355.000000
# 50%                               1147330.0           243421.000000
# 75%                               1147330.0           364097.500000
# max                               1147330.0           485975.000000
#
#        image_feature_concept_id  image_feature_type_concept_id  \
# count              4.761270e+05                       476127.0
# mean               2.128003e+09                        32817.0
# std                4.459389e+04                            0.0
# min                2.128000e+09                        32817.0
# 25%                2.128000e+09                        32817.0
# 50%                2.128001e+09                        32817.0
# 75%                2.128001e+09                        32817.0
# max                2.129001e+09                        32817.0
#
#        anatomic_site_concept_id
# count                  476127.0
# mean                  4119359.0
# std                         0.0
# min                   4119359.0
# 25%                   4119359.0
# 50%                   4119359.0
# 75%                   4119359.0
# max                   4119359.0

# %%
omop_image_feature['person_id'].nunique()
# Out:
# 37

# %%
cursor.close()
conn.close()

# %%
obs_period = omop_procedure.groupby('person_id')['procedure_date'].agg(['max', 'min']).reset_index() #32817
obs_period['observation_period_id'] = range(1,36,1)
obs_period['period_type_concept_id'] = 32817

# %%
obs_period.to_csv('./files/obs_period.csv')

# %%
import pandas as pd
obs_period = pd.read_csv('./files/obs_period.csv')

# %%
# upload instance level attributes
import psycopg2

#host= ohdsicdmdb.postgres.database.azure.com, user= dbadmin, port=5432, database=adni, password=hopkinsx93ewD

conn = psycopg2.connect(
    database="adni",
    user="dbadmin",
    password="hopkinsx93ewD",
    host="ohdsicdmdb.postgres.database.azure.com",
    port="5432",
    connect_timeout = 6000
)

cursor = conn.cursor()

# %%
cursor.close()
conn.close()

# %%
# Update OBSERVATION_PERIOD
sql = '''
    INSERT INTO dbo.observation_period (observation_period_id, person_id, observation_period_start_date, observation_period_end_date, period_type_concept_id) 
    VALUES (%s,%s,%s,%s,%s)
    '''
for index, row in obs_period.iterrows():
    cursor.execute(sql, (row['observation_period_id'], row['person_id'], row['min'], row['max'], row['period_type_concept_id']))

conn.commit()

# %%
sql = 'select * from dbo.observation_period'
obs_period = pd.read_sql(sql, conn)
obs_period.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_678/3176792398.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   obs_period = pd.read_sql(sql, conn)
#    observation_period_id  person_id observation_period_start_date  \
# 0                      1         75                    2019-01-24
# 1                      2        134                    2017-04-13
# 2                      3       1572                    2017-04-19
# 3                      4       1580                    2018-03-20
# 4                      5       1594                    2017-02-01
#
#   observation_period_end_date  period_type_concept_id
# 0                  2021-01-21                   32817
# 1                  2017-04-13                   32817
# 2                  2020-01-27                   32817
# 3                  2021-10-20                   32817
# 4                  2022-01-27                   32817

# %%
obs_period
# Out:
#     observation_period_id  person_id observation_period_start_date  \
# 0                       1         75                    2019-01-24
# 1                       2        134                    2017-04-13
# 2                       3       1572                    2017-04-19
# 3                       4       1580                    2018-03-20
# 4                       5       1594                    2017-02-01
# 5                       6       1812                    2017-08-11
# 6                       7       1858                    2020-01-13
# 7                       8       1885                    2017-12-18
# 8                       9       1894                    2017-08-31
# 9                      10       2161                    2017-12-04
# 10                     11       2372                    2017-07-28
# 11                     12       2556                    2017-05-03
# 12                     13       2593                    2017-01-31
# 13                     14       2753                    2017-08-02
# 14                     15       2754                    2017-06-29
# 15                     16       2970                    2017-09-12
# 16                     17       2987                    2017-03-09
# 17                     18       3015                    2017-12-14
# 18                     19       3148                    2018-01-30
# 19                     20       3166                    2018-02-13
# 20                     21       3290                    2018-05-04
# 21                     22       3304                    2018-05-10
# 22                     23       3322                    2018-05-29
# 23                     24       3331                    2018-05-18
# 24                     25       3332                    2018-05-29
# 25                     26       3336                    2018-05-25
# 26                     27       3353                    2018-05-30
# 27                     28       3362                    2018-05-30
# 28                     29       3415                    2018-07-02
# 29                     30       3477                    2018-08-02
# 30                     31       3609                    2019-01-07
# 31                     32       3645                    2021-06-21
# 32                     33       3669                    2019-04-19
# 33                     34       3750                    2019-08-06
# 34                     35       3805                    2020-01-13
#
#    observation_period_end_date  period_type_concept_id
# 0                   2021-01-21                   32817
# 1                   2017-04-13                   32817
# 2                   2020-01-27                   32817
# 3                   2021-10-20                   32817
# 4                   2022-01-27                   32817
# 5                   2021-08-11                   32817
# 6                   2022-01-28                   32817
# 7                   2021-12-21                   32817
# 8                   2017-08-31                   32817
# 9                   2022-01-03                   32817
# 10                  2021-05-28                   32817
# 11                  2021-02-17                   32817
# 12                  2022-01-31                   32817
# 13                  2017-08-02                   32817
# 14                  2017-06-29                   32817
# 15                  2019-09-09                   32817
# 16                  2021-07-07                   32817
# 17                  2021-04-16                   32817
# 18                  2020-02-10                   32817
# 19                  2022-03-09                   32817
# 20                  2022-05-19                   32817
# 21                  2022-06-13                   32817
# 22                  2019-06-13                   32817
# 23                  2021-08-03                   32817
# 24                  2020-11-12                   32817
# 25                  2022-06-13                   32817
# 26                  2022-06-15                   32817
# 27                  2018-05-30                   32817
# 28                  2021-06-10                   32817
# 29                  2021-09-14                   32817
# 30                  2021-04-14                   32817
# 31                  2021-06-21                   32817
# 32                  2019-04-19                   32817
# 33                  2019-08-06                   32817
# 34                  2021-05-20                   32817

# %% [markdown]
# ## Debug Atlas

# %%
# upload instance level attributes
import psycopg2

#host= ohdsicdmdb.postgres.database.azure.com, user= dbadmin, port=5432, database=adni, password=hopkinsx93ewD

conn = psycopg2.connect(
    database="adni",
    user="dbadmin",
    password="hopkinsx93ewD",
    host="ohdsicdmdb.postgres.database.azure.com",
    port="5432",
    connect_timeout = 6000
)

cursor = conn.cursor()

# %%
sql = '''
    update dbo.measurement 
    set measurement_concept_id = measurement_source_concept_id
    where measurement_source_concept_id > 2000000000
    '''
cursor.execute(sql)
conn.commit()

# %%
sql = '''select * from dbo.measurement where measurement_concept_id > 2000000000'''
omop_measurement = pd.read_sql(sql, conn)
omop_measurement.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_678/1045349359.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   omop_measurement = pd.read_sql(sql, conn)
#    measurement_id  person_id  measurement_concept_id measurement_date  \
# 0           21658       3805              2128000011       2021-05-20
# 1           22527       3805              2128000011       2021-05-20
# 2           23380       3290              2128000011       2021-05-12
# 3           23633       3290              2128000011       2021-05-12
# 4           24493       3290              2128000011       2021-05-12
#
#   measurement_datetime measurement_time  measurement_type_concept_id  \
# 0                 None             None                        32817
# 1                 None             None                        32817
# 2                 None             None                        32817
# 3                 None             None                        32817
# 4                 None             None                        32817
#
#   operator_concept_id  value_as_number value_as_concept_id  ... provider_id  \
# 0                None              0.0                None  ...        None
# 1                None              0.0                None  ...        None
# 2                None              0.0                None  ...        None
# 3                None              0.0                None  ...        None
# 4                None              0.0                None  ...        None
#
#   visit_occurrence_id visit_detail_id measurement_source_value  \
# 0                None            None               ISO_IR 100
# 1                None            None               ISO_IR 100
# 2                None            None               ISO_IR 100
# 3                None            None               ISO_IR 100
# 4                None            None               ISO_IR 100
#
#   measurement_source_concept_id unit_source_value unit_source_concept_id  \
# 0                    2128000011              None                   None
# 1                    2128000011              None                   None
# 2                    2128000011              None                   None
# 3                    2128000011              None                   None
# 4                    2128000011              None                   None
#
#    value_source_value measurement_event_id meas_event_field_concept_id
# 0                None                 None                        None
# 1                None                 None                        None
# 2                None                 None                        None
# 3                None                 None                        None
# 4                None                 None                        None
#
# [5 rows x 23 columns]

# %%
cursor.close()
conn.close()

# %%
image_series[image_series['concept_name']=="Number of slices - count"]
# Out:
# Empty DataFrame
# Columns: [Study_UID, Series_UID, Attribute Tag, Value, concept_id, concept_name, value_as_number, image_feature_id, measurement_id, measurement_type_concept_id, image_occurrence_date, person_id, image_occurrence_id, image_feature_event_field_concept_id, anatomic_site_concept_id]
# Index: []

# %% [markdown]
# ## Add brain volume to OMOP CDM

# %% [markdown]
# ### Import files

# %%
cd ..
# Out:
# /Users/wooyeonpark/Documents/GitHub/DICOM2OMOP

# %%
import pandas as pd
#first run
df_vol = pd.read_csv("./files/cohort1_testseries_openmapt1_results.csv")
df_vol.head()
# Out:
#                                       study_uid  \
# 0  2.16.124.113543.6006.99.02146034564549802647
# 1  2.16.124.113543.6006.99.02156281418585922950
# 2    2.16.124.113543.6006.99.993407831381508223
# 3   2.16.124.113543.6006.99.7084724843781950414
# 4  2.16.124.113543.6006.99.01664766563067247342
#
#                                      series_uid    SFG_L    SFG_R  SFG_PFC_L  \
# 0  2.16.124.113543.6006.99.02146034564549802647  12542.0  12067.0    10605.0
# 1  2.16.124.113543.6006.99.02156281418585922950  15217.0  14315.0    10326.0
# 2    2.16.124.113543.6006.99.993407831381508223  15451.0  15439.0    10445.0
# 3   2.16.124.113543.6006.99.7084724843781950414  14793.0  12882.0    10043.0
# 4  2.16.124.113543.6006.99.01664766563067247342  14887.0  12869.0     9516.0
#
#    SFG_PFC_R  SFG_pole_L  SFG_pole_R    MFG_L   MFG_R  ...  Fimbria_R  \
# 0     9312.0      2305.0      3552.0   8286.0  9066.0  ...        0.0
# 1    10305.0      1862.0      4190.0   8413.0  7461.0  ...        0.0
# 2    11327.0      2320.0      4734.0  10340.0  9972.0  ...        0.0
# 3    11147.0      2297.0      4078.0   8145.0  8026.0  ...        0.0
# 4    10474.0      2421.0      4279.0   8176.0  7751.0  ...        0.0
#
#    Chroid_LVetc_L  Chroid_LVetc_R  IV_ventricle  ECCL_L  ECCL_R  \
# 0           177.0           168.0        1568.0   421.0   551.0
# 1           356.0           247.0        2621.0   322.0   367.0
# 2           670.0           410.0        2662.0   344.0   494.0
# 3           255.0           240.0        2299.0   406.0   436.0
# 4           260.0           253.0        2207.0   370.0   459.0
#
#    ECSAnterior_L  ECSAnterior_R  ECSPosterior_L  ECSPosterior_R
# 0         3207.0         3514.0          2622.0          2798.0
# 1         4873.0         4113.0          5259.0          5717.0
# 2         3297.0         4894.0          4634.0          3549.0
# 3         6760.0         5479.0          5358.0          4489.0
# 4         7310.0         5978.0          5763.0          4633.0
#
# [5 rows x 282 columns]

# %%
import pandas as pd
# additional volumetrics
df_vol = pd.read_csv("./files/brain_vol_06262024.csv")
df_vol.head()
# Out:
#                                        study_id  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01145873998336190369
# 2  2.16.124.113543.6006.99.01486454390863664241
# 3   2.16.124.113543.6006.99.0171281600952240178
# 4   2.16.124.113543.6006.99.0177008878696943993
#
#                                       series_id    SFG_L    SFG_R  SFG_PFC_L  \
# 0  2.16.124.113543.6006.99.06083117774660962009  13696.0  11047.0     8967.0
# 1   2.16.124.113543.6006.99.1175567928230712121  16732.0  16505.0    11844.0
# 2  2.16.124.113543.6006.99.05538929075952892099  15687.0  15349.0    10539.0
# 3  2.16.124.113543.6006.99.07785233623659097184  15995.0  14917.0    10656.0
# 4   2.16.124.113543.6006.99.0179716961251050726  15596.0  12272.0    10586.0
#
#    SFG_PFC_R  SFG_pole_L  SFG_pole_R    MFG_L    MFG_R  ...  Fimbria_R  \
# 0     9127.0      2699.0      3769.0   8050.0   8104.0  ...        2.0
# 1    12626.0      2855.0      5242.0  11882.0  10237.0  ...        0.0
# 2    11378.0      2587.0      5050.0  10616.0  10159.0  ...        0.0
# 3    10989.0      2689.0      4962.0  10485.0   9950.0  ...        0.0
# 4    10534.0      2251.0      4390.0   8185.0  11233.0  ...        0.0
#
#    Chroid_LVetc_L  Chroid_LVetc_R  IV_ventricle  ECCL_L  ECCL_R  \
# 0           242.0           164.0        2769.0   405.0   445.0
# 1           256.0           255.0        1822.0   539.0   530.0
# 2           665.0           393.0        2690.0   367.0   494.0
# 3           681.0           439.0        2727.0   342.0   455.0
# 4           286.0           267.0        2700.0   356.0   509.0
#
#    ECSAnterior_L  ECSAnterior_R  ECSPosterior_L  ECSPosterior_R
# 0         2728.0         4822.0          2528.0          3880.0
# 1         5429.0         4661.0          3661.0          2730.0
# 2         3325.0         4564.0          3991.0          3939.0
# 3         3682.0         4856.0          4109.0          3629.0
# 4         7705.0         6229.0          5601.0          6773.0
#
# [5 rows x 282 columns]

# %%
df_vol.shape
# Out:
# (88, 282)

# %%
concept_vol = pd.read_csv('./files/concept_vol_brain.csv')
series_to_exclude = pd.read_csv('./files/series_to_exclude.csv')

# %%
series_to_exclude.head()
# Out:
#                                image_series_uid
# 0  2.16.124.113543.6006.99.02146034564549802647
# 1  2.16.124.113543.6006.99.02156281418585922950
# 2    2.16.124.113543.6006.99.993407831381508223
# 3   2.16.124.113543.6006.99.7084724843781950414
# 4  2.16.124.113543.6006.99.01664766563067247342

# %%
#exclude ones we already uploaded
df_vol = df_vol[~df_vol['series_id'].isin(series_to_exclude['image_series_uid'])].copy().reset_index(drop=True)
df_vol.shape
# Out:
# (62, 282)

# %%
import pandas as pd

vol_name = pd.read_csv("./files/openmap_colnames.csv")
vol_name.head()
# Out:
#          name                                         full_name
# 0       SFG_L   Superior Frontal Gyrus (Posterior Segment) Left
# 1       SFG_R  Superior Frontal Gyrus (Posterior Segment) Right
# 2   SFG_PFC_L   Superior Frontal Gyrus (Prefrontal Cortex) Left
# 3   SFG_PFC_R  Superior Frontal Gyrus (Prefrontal Cortex) Right
# 4  SFG_pole_L        Superior Frontal Gyrus (Frontal Pole) Left

# %%
df_vol.head()
# Out:
#                                        study_id  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01145873998336190369
# 2   2.16.124.113543.6006.99.0177008878696943993
# 3  2.16.124.113543.6006.99.01801933550335298251
# 4  2.16.124.113543.6006.99.01802168675798806481
#
#                                       series_id    SFG_L    SFG_R  SFG_PFC_L  \
# 0  2.16.124.113543.6006.99.06083117774660962009  13696.0  11047.0     8967.0
# 1   2.16.124.113543.6006.99.1175567928230712121  16732.0  16505.0    11844.0
# 2   2.16.124.113543.6006.99.0179716961251050726  15596.0  12272.0    10586.0
# 3   2.16.124.113543.6006.99.3841958977277056753  14951.0  12437.0     9670.0
# 4   2.16.124.113543.6006.99.8592343824840798702  16193.0  13756.0    11200.0
#
#    SFG_PFC_R  SFG_pole_L  SFG_pole_R    MFG_L    MFG_R  ...  Fimbria_R  \
# 0     9127.0      2699.0      3769.0   8050.0   8104.0  ...        2.0
# 1    12626.0      2855.0      5242.0  11882.0  10237.0  ...        0.0
# 2    10534.0      2251.0      4390.0   8185.0  11233.0  ...        0.0
# 3     8894.0      2246.0      3523.0  11130.0   9951.0  ...        0.0
# 4    11935.0      2190.0      4205.0   9821.0   9692.0  ...        0.0
#
#    Chroid_LVetc_L  Chroid_LVetc_R  IV_ventricle  ECCL_L  ECCL_R  \
# 0           242.0           164.0        2769.0   405.0   445.0
# 1           256.0           255.0        1822.0   539.0   530.0
# 2           286.0           267.0        2700.0   356.0   509.0
# 3           578.0           492.0        2488.0   373.0   418.0
# 4           231.0           170.0        2578.0   405.0   561.0
#
#    ECSAnterior_L  ECSAnterior_R  ECSPosterior_L  ECSPosterior_R
# 0         2728.0         4822.0          2528.0          3880.0
# 1         5429.0         4661.0          3661.0          2730.0
# 2         7705.0         6229.0          5601.0          6773.0
# 3         1121.0          699.0           545.0           419.0
# 4         1553.0         2707.0          1949.0          1422.0
#
# [5 rows x 282 columns]

# %%
df_long = df_vol.melt(id_vars=['study_id','series_id'], var_name='name', value_name='value')
df_long.head()
# Out:
#                                        study_id  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01145873998336190369
# 2   2.16.124.113543.6006.99.0177008878696943993
# 3  2.16.124.113543.6006.99.01801933550335298251
# 4  2.16.124.113543.6006.99.01802168675798806481
#
#                                       series_id   name    value
# 0  2.16.124.113543.6006.99.06083117774660962009  SFG_L  13696.0
# 1   2.16.124.113543.6006.99.1175567928230712121  SFG_L  16732.0
# 2   2.16.124.113543.6006.99.0179716961251050726  SFG_L  15596.0
# 3   2.16.124.113543.6006.99.3841958977277056753  SFG_L  14951.0
# 4   2.16.124.113543.6006.99.8592343824840798702  SFG_L  16193.0

# %%
df_long = df_long.merge(concept_vol, left_on = 'name', right_on = 'brain_part', how = 'left')
df_long.shape
# Out:
# (17360, 6)

# %%
image_oc = pd.read_pickle('./files/image_occurrence_staging.pkl')
image_oc.head()
# Out:
#                                       study_uid  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01060096421826160662
# 2  2.16.124.113543.6006.99.01060096421826160662
# 3  2.16.124.113543.6006.99.01060096421826160662
# 4  2.16.124.113543.6006.99.01060096421826160662
#
#                                      series_uid  person_id procedure_date  \
# 0  2.16.124.113543.6006.99.06083117774660962009       2161     2017-12-04
# 1  2.16.124.113543.6006.99.06263494736769400825       2161     2017-12-04
# 2  2.16.124.113543.6006.99.06964874624365474765       2161     2017-12-04
# 3  2.16.124.113543.6006.99.07300304364963768908       2161     2017-12-04
# 4  2.16.124.113543.6006.99.08097639857522452001       2161     2017-12-04
#
#    procedure_occurrence_id  image_occurrence_id  \
# 0                        1                    1
# 1                        1                    2
# 2                        1                    3
# 3                        1                    4
# 4                        1                    5
#
#                                           wadors_uri  \
# 0  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 1  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 2  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 3  https://imgextpoc-adnidicom.dicom.azurehealthc...
# 4  https://imgextpoc-adnidicom.dicom.azurehealthc...
#
#    anatomic_site_concept_id  modality_concept_id  visit_occurrence_id  \
# 0                   4119359              4013636                   26
# 1                   4119359              4013636                   26
# 2                   4119359              4013636                   26
# 3                   4119359              4013636                   26
# 4                   4119359              4013636                   26
#
#    visit_concept_id visit_start_date visit_end_date  visit_type_concept_id
# 0              9202       2017-12-04     2017-12-04                  32817
# 1              9202       2017-12-04     2017-12-04                  32817
# 2              9202       2017-12-04     2017-12-04                  32817
# 3              9202       2017-12-04     2017-12-04                  32817
# 4              9202       2017-12-04     2017-12-04                  32817

# %%
df_long = df_long.merge(image_oc[['series_uid', 'person_id', 'procedure_date', 'image_occurrence_id', 'visit_occurrence_id']], 
              left_on = 'series_id', right_on = 'series_uid', how = 'left')

# %%
df_long['measurement_id'] = range(656358, 656358 + len(df_long))
df_long['image_feature_id'] = range(493256, 493256 + len(df_long))
df_long['measurement_type_concept_id'] = 32880 #standard algorithm
df_long['anatomic_site_concept_id'] = df_long['vol_concept_id']-1000

# %%
df_long.to_pickle('./files/add_brain_vol.pkl') #17360 rows

# %%
df_long.head()
# Out:
#                                        study_id  \
# 0  2.16.124.113543.6006.99.01060096421826160662
# 1  2.16.124.113543.6006.99.01145873998336190369
# 2   2.16.124.113543.6006.99.0177008878696943993
# 3  2.16.124.113543.6006.99.01801933550335298251
# 4  2.16.124.113543.6006.99.01802168675798806481
#
#                                       series_id   name    value  \
# 0  2.16.124.113543.6006.99.06083117774660962009  SFG_L  13696.0
# 1   2.16.124.113543.6006.99.1175567928230712121  SFG_L  16732.0
# 2   2.16.124.113543.6006.99.0179716961251050726  SFG_L  15596.0
# 3   2.16.124.113543.6006.99.3841958977277056753  SFG_L  14951.0
# 4   2.16.124.113543.6006.99.8592343824840798702  SFG_L  16193.0
#
#    vol_concept_id brain_part                                    series_uid  \
# 0      2129001000      SFG_L  2.16.124.113543.6006.99.06083117774660962009
# 1      2129001000      SFG_L   2.16.124.113543.6006.99.1175567928230712121
# 2      2129001000      SFG_L   2.16.124.113543.6006.99.0179716961251050726
# 3      2129001000      SFG_L   2.16.124.113543.6006.99.3841958977277056753
# 4      2129001000      SFG_L   2.16.124.113543.6006.99.8592343824840798702
#
#    person_id procedure_date  image_occurrence_id  visit_occurrence_id  \
# 0       2161     2017-12-04                    1                   26
# 1       3332     2018-05-29                   14                   72
# 2       3805     2021-05-20                   42                   93
# 3       3290     2021-05-12                   54                   63
# 4       1858     2021-04-26                   65                   21
#
#    measurement_id  image_feature_id  measurement_concept_id  \
# 0          656358            493256                 3011794
# 1          656359            493257                 3011794
# 2          656360            493258                 3011794
# 3          656361            493259                 3011794
# 4          656362            493260                 3011794
#
#    measurement_type_concept_id  anatomic_site_concept_id
# 0                        32880                2129000000
# 1                        32880                2129000000
# 2                        32880                2129000000
# 3                        32880                2129000000
# 4                        32880                2129000000

# %%
# Update MEASUREMENT
sql = '''
    INSERT INTO dbo.measurement (measurement_id, person_id, measurement_concept_id, measurement_date, measurement_type_concept_id, value_as_number
        , measurement_source_value, measurement_source_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in df_long.iterrows():
    cursor.execute(sql, (row['measurement_id'], row['person_id'], row['vol_concept_id'], row['procedure_date'], row['measurement_type_concept_id'], row['value']
                         , row['value'], row['vol_concept_id']))

conn.commit()

# %%
# Update IMAGE_FEATURE
sql = '''
    INSERT INTO dbo.image_feature (image_feature_id, person_id, image_occurrence_id, image_feature_event_id,
      image_feature_event_field_concept_id, image_feature_concept_id, image_feature_type_concept_id, anatomic_site_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in df_long.iterrows():
    cursor.execute(sql, (row['image_feature_id'], row['person_id'], row['image_occurrence_id'], row['measurement_id'], 
                  1147330, row['vol_concept_id'], row['measurement_type_concept_id'],
                  row['anatomic_site_concept_id']))

conn.commit()

# %% [markdown]
# ### Connect to the database

# %%
import psycopg2

conn = psycopg2.connect(
    database="adni",
    user="dbadmin",
    password="hopkinsx93ewD",
    host="ohdsicdmdb.postgres.database.azure.com",
    port="5432",
    connect_timeout = 6000
)

cursor = conn.cursor()

# %%
sql = """
    select * 
    from dbo.measurement
    order by measurement_id desc
    limit 100
    """
df_measurement = pd.read_sql(sql, conn)
df_measurement.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_88101/2752812816.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_measurement = pd.read_sql(sql, conn)
#    measurement_id  person_id  measurement_concept_id measurement_date  \
# 0          649077       3919              2041571213       2021-07-20
# 1          649076       3011              2041571213       2021-07-20
# 2          649075       3262              2041571213       2020-07-27
# 3          649074       3209              2041571213       2020-08-24
# 4          649073        714              2041571213       2021-07-16
#
#   measurement_datetime measurement_time  measurement_type_concept_id  \
# 0                 None             None                        32817
# 1                 None             None                        32817
# 2                 None             None                        32817
# 3                 None             None                        32817
# 4                 None             None                        32817
#
#   operator_concept_id  value_as_number value_as_concept_id  ... provider_id  \
# 0                None             11.0                None  ...        None
# 1                None              0.0                None  ...        None
# 2                None              0.0                None  ...        None
# 3                None              0.0                None  ...        None
# 4                None              0.0                None  ...        None
#
#   visit_occurrence_id visit_detail_id measurement_source_value  \
# 0                None            None                     None
# 1                None            None                     None
# 2                None            None                     None
# 3                None            None                     None
# 4                None            None                     None
#
#   measurement_source_concept_id unit_source_value unit_source_concept_id  \
# 0                    2041571213              None                   None
# 1                    2041571213              None                   None
# 2                    2041571213              None                   None
# 3                    2041571213              None                   None
# 4                    2041571213              None                   None
#
#    value_source_value measurement_event_id meas_event_field_concept_id
# 0                None                 None                        None
# 1                None                 None                        None
# 2                None                 None                        None
# 3                None                 None                        None
# 4                None                 None                        None
#
# [5 rows x 23 columns]

# %%
df_measurement.measurement_id.max()
# Out:
# 649077

# %%
sql = """
    select * 
    from dbo.image_occurrence
    """
df_staging = pd.read_sql(sql, conn)
df_staging.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_88101/1333957992.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_staging = pd.read_sql(sql, conn)
#    image_occurrence_id  person_id  procedure_occurrence_id  \
# 0                    1       2161                        1
# 1                    2       2161                        1
# 2                    3       2161                        1
# 3                    4       2161                        1
# 4                    5       2161                        1
#
#   visit_occurrence_id  anatomic_site_concept_id  \
# 0                None                   4119359
# 1                None                   4119359
# 2                None                   4119359
# 3                None                   4119359
# 4                None                   4119359
#
#                                           wadors_uri local_path  \
# 0  https://imgextpoc-adnidicom.dicom.azurehealthc...       None
# 1  https://imgextpoc-adnidicom.dicom.azurehealthc...       None
# 2  https://imgextpoc-adnidicom.dicom.azurehealthc...       None
# 3  https://imgextpoc-adnidicom.dicom.azurehealthc...       None
# 4  https://imgextpoc-adnidicom.dicom.azurehealthc...       None
#
#   image_occurrence_date                               image_study_uid  \
# 0            2017-12-04  2.16.124.113543.6006.99.01060096421826160662
# 1            2017-12-04  2.16.124.113543.6006.99.01060096421826160662
# 2            2017-12-04  2.16.124.113543.6006.99.01060096421826160662
# 3            2017-12-04  2.16.124.113543.6006.99.01060096421826160662
# 4            2017-12-04  2.16.124.113543.6006.99.01060096421826160662
#
#                                image_series_uid  modality_concept_id
# 0  2.16.124.113543.6006.99.06083117774660962009              4013636
# 1  2.16.124.113543.6006.99.06263494736769400825              4013636
# 2  2.16.124.113543.6006.99.06964874624365474765              4013636
# 3  2.16.124.113543.6006.99.07300304364963768908              4013636
# 4  2.16.124.113543.6006.99.08097639857522452001              4013636

# %%
import pandas as pd
sql = """
    select * 
    from dbo.concept
    where concept_class_id = 'Body Structure' or concept_id > 2000000000
    """
df_concept = pd.read_sql(sql, conn)
df_concept.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_58685/3943639209.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_concept = pd.read_sql(sql, conn)
#    concept_id                      concept_name           domain_id  \
# 0  2129000165  Lateral Ventricle_Occipital Left  Spec Anatomic Site
# 1  2129000166   Lateral Ventricle_Inferior Left  Spec Anatomic Site
# 2  2129000167   Lateral Ventricle_Frontal Right  Spec Anatomic Site
# 3  2129000168      Lateral Ventricle_Body Right  Spec Anatomic Site
# 4  2129000169    Lateral Ventricle_Atrium Right  Spec Anatomic Site
#
#   vocabulary_id concept_class_id standard_concept    concept_code  \
# 0             0   Body Structure             None  LV_Occipital_L
# 1             0   Body Structure             None   LV_Inferior_L
# 2             0   Body Structure             None    LV_Frontal_R
# 3             0   Body Structure             None       LV_body_R
# 4             0   Body Structure             None     LV_atrium_R
#
#   valid_start_date valid_end_date invalid_reason
# 0       2024-06-01     2099-12-31           None
# 1       2024-06-01     2099-12-31           None
# 2       2024-06-01     2099-12-31           None
# 3       2024-06-01     2099-12-31           None
# 4       2024-06-01     2099-12-31           None

# %%
df_concept.concept_id.max() #2129001004
# Out:
# 2129001004

# %%
df_concept[df_concept['concept_id'] == 2129000000]
# Out:
# Empty DataFrame
# Columns: [concept_id, concept_name, domain_id, vocabulary_id, concept_class_id, standard_concept, concept_code, valid_start_date, valid_end_date, invalid_reason]
# Index: []

# %% [markdown]
# ### Edit measurement concept id to a custom id for brain volume (atlas debug)

# %%
import pandas as pd
sql = 'select max(concept_id) from dbo.concept'
pd.read_sql_query(sql, conn) #2129001004
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_77351/3689220868.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(sql, conn) #2129001004
#           max
# 0  2129001005

# %%
sql = """
    select * 
    from dbo.measurement
    where measurement_concept_id = 2129001005
    """
df_measurement = pd.read_sql(sql, conn)
df_measurement.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_82292/3058257969.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_measurement = pd.read_sql(sql, conn)
#    measurement_id  person_id  measurement_concept_id measurement_date  \
# 0          656046       1594              2129001005       2024-06-13
# 1          656256       1572              2129001005       2024-06-13
# 2          656257       2593              2129001005       2024-06-13
# 3          656258       2593              2129001005       2024-06-13
# 4          656259       1594              2129001005       2024-06-13
#
#   measurement_datetime measurement_time  measurement_type_concept_id  \
# 0                 None             None                        32880
# 1                 None             None                        32880
# 2                 None             None                        32880
# 3                 None             None                        32880
# 4                 None             None                        32880
#
#   operator_concept_id  value_as_number value_as_concept_id  ... provider_id  \
# 0                None              0.0                None  ...        None
# 1                None           3297.0                None  ...        None
# 2                None           6760.0                None  ...        None
# 3                None           7310.0                None  ...        None
# 4                None           3277.0                None  ...        None
#
#   visit_occurrence_id visit_detail_id measurement_source_value  \
# 0                None            None                      0.0
# 1                None            None                   3297.0
# 2                None            None                   6760.0
# 3                None            None                   7310.0
# 4                None            None                   3277.0
#
#   measurement_source_concept_id unit_source_value unit_source_concept_id  \
# 0                    2129001005              None                   None
# 1                    2129001005              None                   None
# 2                    2129001005              None                   None
# 3                    2129001005              None                   None
# 4                    2129001005              None                   None
#
#    value_source_value measurement_event_id meas_event_field_concept_id
# 0                None                 None                        None
# 1                None                 None                        None
# 2                None                 None                        None
# 3                None                 None                        None
# 4                None                 None                        None
#
# [5 rows x 23 columns]

# %%
df_measurement.shape
# Out:
# (7280, 23)

# %%
cursor = conn.cursor()

sql = '''
    INSERT INTO dbo.concept (concept_id,concept_name,domain_id,vocabulary_id,concept_class_id,concept_code,valid_start_date,valid_end_date)
    VALUES (2129001005, 'Brain volume', 'Measurement', 'None', 'Clinical Observation', 0, '2024-06-01', '2099-12-31')
    '''
cursor.execute(sql)
conn.commit()

# %%
sql = '''
    UPDATE dbo.measurement
    SET measurement_concept_id = 2129001005, measurement_source_concept_id = 2129001005
    WHERE measurement_concept_id = 3011794
    '''
cursor.execute(sql)
conn.commit()

# %% [markdown]
# ### EDIT brain volume per brain part as concept id + update measurement date

# %%
import pandas as pd

sql = """
    select measurement_id, m.person_id, measurement_concept_id, measurement_type_concept_id, value_as_number, measurement_source_value
        , measurement_source_concept_id, image_feature_id, f.image_occurrence_id, image_feature_event_id
        , image_feature_event_field_concept_id, image_feature_concept_id, image_feature_type_concept_id, f.anatomic_site_concept_id
        , image_occurrence_date
    from dbo.measurement m
    left join dbo.image_feature f on m.measurement_id = f.image_feature_event_id
    left join dbo.image_occurrence o on f.image_occurrence_id = o.image_occurrence_id
    where measurement_concept_id >= 2129001000
    """
df_measurement = pd.read_sql(sql, conn)
df_measurement.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_89573/1284476894.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_measurement = pd.read_sql(sql, conn)
#    measurement_id  person_id  measurement_concept_id  \
# 0          485028       2161              2129001004
# 1          485028       2161              2129001004
# 2          485029       2161              2129001004
# 3          485029       2161              2129001004
# 4          485030       2161              2129001004
#
#    measurement_type_concept_id  value_as_number measurement_source_value  \
# 0                        32817           1294.0                     1294
# 1                        32817           1294.0                     1294
# 2                        32817             75.0                       75
# 3                        32817             75.0                       75
# 4                        32817             61.0                       61
#
#    measurement_source_concept_id  image_feature_id  image_occurrence_id  \
# 0                     2129001004            485028                    1
# 1                     2129001004            485028                    1
# 2                     2129001004            485029                    2
# 3                     2129001004            485029                    2
# 4                     2129001004            485030                    3
#
#    image_feature_event_id  image_feature_event_field_concept_id  \
# 0                  485028                               1147330
# 1                  485028                               1147330
# 2                  485029                               1147330
# 3                  485029                               1147330
# 4                  485030                               1147330
#
#    image_feature_concept_id  image_feature_type_concept_id  \
# 0                2129001004                          32817
# 1                2129001004                          32817
# 2                2129001004                          32817
# 3                2129001004                          32817
# 4                2129001004                          32817
#
#    anatomic_site_concept_id image_occurrence_date
# 0                   4119359            2017-12-04
# 1                   4119359            2017-12-04
# 2                   4119359            2017-12-04
# 3                   4119359            2017-12-04
# 4                   4119359            2017-12-04

# %%
df_measurement['anatomic_site_concept_id'].min(), df_measurement['anatomic_site_concept_id'].max()
# Out:
# (4119359, 2129000279)

# %%
sql = 'delete from dbo.measurement where measurement_concept_id = 2129001005'
cursor.execute(sql)
conn.commit()

# %%
# Update MEASUREMENT
sql = '''
    INSERT INTO dbo.measurement (measurement_id, person_id, measurement_concept_id, measurement_date, measurement_type_concept_id, value_as_number
        , measurement_source_value, measurement_source_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in df_measurement.iterrows():
    cursor.execute(sql, (row['measurement_id'], row['person_id'], row['brain_volume_concept_id'], row['image_occurrence_date'], row['measurement_type_concept_id'], row['value_as_number']
                         , row['value_as_number'], row['brain_volume_concept_id']))

conn.commit()

# %%
sql = 'select count(*) from dbo.image_feature where anatomic_site_concept_id between 2129000000 and 2129000279'
pd.read_sql_query(sql, conn)
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_89573/4165414948.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query(sql, conn)
#    count
# 0   7280

# %%
sql = 'delete from dbo.image_feature where anatomic_site_concept_id between 2129000000 and 2129000279'
cursor.execute(sql)
conn.commit()

# %%
# Update IMAGE_FEATURE
sql = '''
    INSERT INTO dbo.image_feature (image_feature_id, person_id, image_occurrence_id, image_feature_event_id,
      image_feature_event_field_concept_id, image_feature_concept_id, image_feature_type_concept_id, anatomic_site_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in df_measurement.iterrows():
    cursor.execute(sql, (row['image_feature_id'], row['person_id'], row['image_occurrence_id'], row['measurement_id'], 
                  row['image_feature_event_field_concept_id'], row['measurement_concept_id'], row['measurement_type_concept_id'],
                  row['anatomic_site_concept_id']))

conn.commit()

# %%
cursor.close()
conn.close()

# %% [markdown]
# ### Edit Brain Anatomy Concept Names

# %%
#vol_name

sql = """
    select * 
    from dbo.concept
    where concept_class_id = 'Body Structure' and concept_id > 2000000000
    """
df_concept = pd.read_sql(sql, conn)
df_concept.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_77351/3477584149.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_concept = pd.read_sql(sql, conn)
#    concept_id                      concept_name           domain_id  \
# 0  2129000165  Lateral Ventricle_Occipital Left  Spec Anatomic Site
# 1  2129000166   Lateral Ventricle_Inferior Left  Spec Anatomic Site
# 2  2129000167   Lateral Ventricle_Frontal Right  Spec Anatomic Site
# 3  2129000168      Lateral Ventricle_Body Right  Spec Anatomic Site
# 4  2129000169    Lateral Ventricle_Atrium Right  Spec Anatomic Site
#
#   vocabulary_id concept_class_id standard_concept    concept_code  \
# 0             0   Body Structure             None  LV_Occipital_L
# 1             0   Body Structure             None   LV_Inferior_L
# 2             0   Body Structure             None    LV_Frontal_R
# 3             0   Body Structure             None       LV_body_R
# 4             0   Body Structure             None     LV_atrium_R
#
#   valid_start_date valid_end_date invalid_reason
# 0       2024-06-01     2099-12-31           None
# 1       2024-06-01     2099-12-31           None
# 2       2024-06-01     2099-12-31           None
# 3       2024-06-01     2099-12-31           None
# 4       2024-06-01     2099-12-31           None

# %%
df_concept.shape
# Out:
# (280, 10)

# %%
# df_concept = df_concept.merge(vol_name, left_on = 'concept_code', right_on = 'name', how = 'left')
# df_concept.head()
# Out:
#    concept_id concept_name           domain_id vocabulary_id concept_class_id  \
# 0  2129000000        SFG_L  Spec Anatomic Site             0   Body Structure
# 1  2129000001        SFG_R  Spec Anatomic Site             0   Body Structure
# 2  2129000002    SFG_PFC_L  Spec Anatomic Site             0   Body Structure
# 3  2129000003    SFG_PFC_R  Spec Anatomic Site             0   Body Structure
# 4  2129000004   SFG_pole_L  Spec Anatomic Site             0   Body Structure
#
#   standard_concept concept_code valid_start_date valid_end_date  \
# 0             None        SFG_L       2024-06-01     2099-12-31
# 1             None        SFG_R       2024-06-01     2099-12-31
# 2             None    SFG_PFC_L       2024-06-01     2099-12-31
# 3             None    SFG_PFC_R       2024-06-01     2099-12-31
# 4             None   SFG_pole_L       2024-06-01     2099-12-31
#
#   invalid_reason        name                                         full_name
# 0           None       SFG_L   Superior Frontal Gyrus (Posterior Segment) Left
# 1           None       SFG_R  Superior Frontal Gyrus (Posterior Segment) Right
# 2           None   SFG_PFC_L   Superior Frontal Gyrus (Prefrontal Cortex) Left
# 3           None   SFG_PFC_R  Superior Frontal Gyrus (Prefrontal Cortex) Right
# 4           None  SFG_pole_L        Superior Frontal Gyrus (Frontal Pole) Left

# %%
df_concept['vol_concept_id'] = df_concept['concept_id'] + 1000
df_concept['vol_concept_name'] = df_concept['concept_name'].apply(lambda x: f"Volume Estimation of {x}")
df_concept['vol_domain_id'] = 'Measurement'
df_concept['vol_concept_class_id'] = 'Clinical Observation'
df_concept['vol_concept_code'] = df_concept['concept_code'].apply(lambda x: f"Volume Estimation of {x}")
df_concept.head()
# Out:
#    concept_id                      concept_name           domain_id  \
# 0  2129000165  Lateral Ventricle_Occipital Left  Spec Anatomic Site
# 1  2129000166   Lateral Ventricle_Inferior Left  Spec Anatomic Site
# 2  2129000167   Lateral Ventricle_Frontal Right  Spec Anatomic Site
# 3  2129000168      Lateral Ventricle_Body Right  Spec Anatomic Site
# 4  2129000169    Lateral Ventricle_Atrium Right  Spec Anatomic Site
#
#   vocabulary_id concept_class_id standard_concept    concept_code  \
# 0             0   Body Structure             None  LV_Occipital_L
# 1             0   Body Structure             None   LV_Inferior_L
# 2             0   Body Structure             None    LV_Frontal_R
# 3             0   Body Structure             None       LV_body_R
# 4             0   Body Structure             None     LV_atrium_R
#
#   valid_start_date valid_end_date invalid_reason  vol_concept_id  \
# 0       2024-06-01     2099-12-31           None      2129001165
# 1       2024-06-01     2099-12-31           None      2129001166
# 2       2024-06-01     2099-12-31           None      2129001167
# 3       2024-06-01     2099-12-31           None      2129001168
# 4       2024-06-01     2099-12-31           None      2129001169
#
#                                     vol_concept_name vol_domain_id  \
# 0  Volume Estimation of Lateral Ventricle_Occipit...   Measurement
# 1  Volume Estimation of Lateral Ventricle_Inferio...   Measurement
# 2  Volume Estimation of Lateral Ventricle_Frontal...   Measurement
# 3  Volume Estimation of Lateral Ventricle_Body Right   Measurement
# 4  Volume Estimation of Lateral Ventricle_Atrium ...   Measurement
#
#    vol_concept_class_id                     vol_concept_code
# 0  Clinical Observation  Volume Estimation of LV_Occipital_L
# 1  Clinical Observation   Volume Estimation of LV_Inferior_L
# 2  Clinical Observation    Volume Estimation of LV_Frontal_R
# 3  Clinical Observation       Volume Estimation of LV_body_R
# 4  Clinical Observation     Volume Estimation of LV_atrium_R

# %%
sql = '''delete from dbo.concept where concept_id = 2129001005'''
cursor.execute(sql)
conn.commit()

# %%
# Update CONCEPT
#cursor = conn.cursor()

sql = '''
    INSERT INTO dbo.concept (concept_id,concept_name,domain_id,vocabulary_id,concept_class_id,concept_code,valid_start_date,valid_end_date) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in df_concept.iterrows():
    cursor.execute(sql, (row['concept_id'], row['full_name'], row['domain_id'], row['vocabulary_id'], row['concept_class_id'], row['concept_code'],row['valid_start_date'], row['valid_end_date']))

conn.commit()

# %%
# Update CONCEPT

sql = '''
    INSERT INTO dbo.concept (concept_id,concept_name,domain_id,vocabulary_id,concept_class_id,concept_code,valid_start_date,valid_end_date) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in df_concept.iterrows():
    cursor.execute(sql, (row['vol_concept_id'], row['vol_concept_name'], row['vol_domain_id'], row['vocabulary_id'], row['vol_concept_class_id'], row['vol_concept_code']
                         ,'2000-01-01', '2099-12-31'))

conn.commit()

# %% [markdown]
# ### Edits completed

# %%
# check to see if all the series uids are found
df_vol[df_vol['series_uid'].isin(df_staging['image_series_uid'])]
# Out:
#                                        study_uid  \
# 0   2.16.124.113543.6006.99.02146034564549802647
# 1   2.16.124.113543.6006.99.02156281418585922950
# 2     2.16.124.113543.6006.99.993407831381508223
# 3    2.16.124.113543.6006.99.7084724843781950414
# 4   2.16.124.113543.6006.99.01664766563067247342
# 5   2.16.124.113543.6006.99.06118437509234420494
# 6    2.16.124.113543.6006.99.0926607876713674299
# 7    2.16.124.113543.6006.99.6655130263917453515
# 8   2.16.124.113543.6006.99.06163710924314373088
# 9   2.16.124.113543.6006.99.05538929075952892099
# 10   2.16.124.113543.6006.99.4749695483155790404
# 11  2.16.124.113543.6006.99.06410316007856694424
# 12   2.16.124.113543.6006.99.1418658044239448010
# 13    2.16.124.113543.6006.99.951112993194815290
# 14  2.16.124.113543.6006.99.01918388366793200152
# 15  2.16.124.113543.6006.99.05273733346817463853
# 16  2.16.124.113543.6006.99.01700787502671551684
# 17  2.16.124.113543.6006.99.01292895587978559795
# 18  2.16.124.113543.6006.99.07321282014827401804
# 19  2.16.124.113543.6006.99.07785233623659097184
# 20  2.16.124.113543.6006.99.02574410492359428120
# 21  2.16.124.113543.6006.99.06980800591232908628
# 22  2.16.124.113543.6006.99.08134847940217142646
# 23   2.16.124.113543.6006.99.0655464044882863620
# 24  2.16.124.113543.6006.99.05894487113435554436
# 25   2.16.124.113543.6006.99.6452735615226980766
#
#                                       series_uid    SFG_L    SFG_R  SFG_PFC_L  \
# 0   2.16.124.113543.6006.99.02146034564549802647  12542.0  12067.0    10605.0
# 1   2.16.124.113543.6006.99.02156281418585922950  15217.0  14315.0    10326.0
# 2     2.16.124.113543.6006.99.993407831381508223  15451.0  15439.0    10445.0
# 3    2.16.124.113543.6006.99.7084724843781950414  14793.0  12882.0    10043.0
# 4   2.16.124.113543.6006.99.01664766563067247342  14887.0  12869.0     9516.0
# 5   2.16.124.113543.6006.99.06118437509234420494  12832.0  12010.0    10629.0
# 6    2.16.124.113543.6006.99.0926607876713674299  16489.0  14252.0    10738.0
# 7    2.16.124.113543.6006.99.6655130263917453515  15235.0  13205.0    10797.0
# 8   2.16.124.113543.6006.99.06163710924314373088  15822.0  14206.0    10421.0
# 9   2.16.124.113543.6006.99.05538929075952892099  15687.0  15349.0    10539.0
# 10   2.16.124.113543.6006.99.4749695483155790404  15126.0  13126.0     9883.0
# 11  2.16.124.113543.6006.99.06410316007856694424  12462.0  11565.0     9521.0
# 12   2.16.124.113543.6006.99.1418658044239448010  14730.0  13522.0    10820.0
# 13    2.16.124.113543.6006.99.951112993194815290  15249.0  13094.0     9765.0
# 14  2.16.124.113543.6006.99.01918388366793200152  13790.0  12995.0    10005.0
# 15  2.16.124.113543.6006.99.05273733346817463853  14852.0  14678.0    10413.0
# 16  2.16.124.113543.6006.99.01700787502671551684  13929.0  13101.0    10032.0
# 17  2.16.124.113543.6006.99.01292895587978559795  16240.0  14584.0    11070.0
# 18  2.16.124.113543.6006.99.07321282014827401804  12926.0  11561.0    10298.0
# 19  2.16.124.113543.6006.99.07785233623659097184  15995.0  14917.0    10656.0
# 20  2.16.124.113543.6006.99.02574410492359428120  12771.0  11943.0    10235.0
# 21  2.16.124.113543.6006.99.06980800591232908628  14617.0  12846.0     9232.0
# 22  2.16.124.113543.6006.99.08134847940217142646  16104.0  14599.0    10492.0
# 23   2.16.124.113543.6006.99.0655464044882863620  12809.0  12310.0    10302.0
# 24  2.16.124.113543.6006.99.05894487113435554436  15217.0  13332.0     9502.0
# 25   2.16.124.113543.6006.99.6452735615226980766  17283.0  15957.0    13624.0
#
#     SFG_PFC_R  SFG_pole_L  SFG_pole_R    MFG_L    MFG_R  ...  Fimbria_R  \
# 0      9312.0      2305.0      3552.0   8286.0   9066.0  ...        0.0
# 1     10305.0      1862.0      4190.0   8413.0   7461.0  ...        0.0
# 2     11327.0      2320.0      4734.0  10340.0   9972.0  ...        0.0
# 3     11147.0      2297.0      4078.0   8145.0   8026.0  ...        0.0
# 4     10474.0      2421.0      4279.0   8176.0   7751.0  ...        0.0
# 5      9421.0      2365.0      3604.0   8583.0   9167.0  ...        0.0
# 6     10245.0      2009.0      4087.0   8193.0   7781.0  ...        0.0
# 7     10661.0      2759.0      4468.0   8155.0   7777.0  ...        0.0
# 8      9522.0      2010.0      4036.0   8546.0   7886.0  ...        0.0
# 9     11378.0      2587.0      5050.0  10616.0  10159.0  ...        0.0
# 10    10700.0      2417.0      4188.0   8089.0   7891.0  ...        0.0
# 11     8841.0      2487.0      4184.0   7668.0   8992.0  ...        0.0
# 12    10550.0      2457.0      5025.0   7384.0   6960.0  ...        0.0
# 13    10460.0      2602.0      4366.0   8041.0   7789.0  ...        0.0
# 14     9885.0      2009.0      3328.0   8867.0   8751.0  ...        0.0
# 15    11570.0      2480.0      4893.0  10380.0   9714.0  ...        0.0
# 16    10171.0      2065.0      3511.0   9079.0   8921.0  ...        0.0
# 17    10743.0      2118.0      4693.0   8377.0   7468.0  ...        0.0
# 18     9144.0      2737.0      4004.0   8308.0   8390.0  ...        0.0
# 19    10989.0      2689.0      4962.0  10485.0   9950.0  ...        0.0
# 20     9126.0      2442.0      3727.0   8129.0   8569.0  ...        0.0
# 21    10424.0      2467.0      4107.0   8079.0   7685.0  ...        0.0
# 22    10063.0      2037.0      4017.0   7909.0   7499.0  ...        0.0
# 23     9545.0      2151.0      3494.0   8385.0   9219.0  ...        0.0
# 24    10622.0      2391.0      4173.0   8197.0   7929.0  ...        0.0
# 25    12123.0      3057.0      5267.0  10979.0   9947.0  ...        0.0
#
#     Chroid_LVetc_L  Chroid_LVetc_R  IV_ventricle  ECCL_L  ECCL_R  \
# 0            177.0           168.0        1568.0   421.0   551.0
# 1            356.0           247.0        2621.0   322.0   367.0
# 2            670.0           410.0        2662.0   344.0   494.0
# 3            255.0           240.0        2299.0   406.0   436.0
# 4            260.0           253.0        2207.0   370.0   459.0
# 5            169.0           167.0        1540.0   455.0   585.0
# 6            380.0           265.0        2570.0   323.0   396.0
# 7            353.0           237.0        2906.0   362.0   459.0
# 8            343.0           237.0        2540.0   322.0   386.0
# 9            665.0           393.0        2690.0   367.0   494.0
# 10           274.0           248.0        2217.0   348.0   455.0
# 11           182.0           170.0        1492.0   405.0   487.0
# 12           380.0           302.0        2515.0   373.0   432.0
# 13           260.0           252.0        2211.0   372.0   476.0
# 14           486.0           316.0        3890.0   280.0   391.0
# 15           718.0           400.0        2711.0   327.0   442.0
# 16           466.0           305.0        3805.0   273.0   399.0
# 17           375.0           268.0        2661.0   326.0   410.0
# 18           166.0           150.0        1550.0   451.0   584.0
# 19           681.0           439.0        2727.0   342.0   455.0
# 20           171.0           167.0        1552.0   451.0   655.0
# 21           259.0           277.0        2136.0   366.0   465.0
# 22           415.0           274.0        2614.0   332.0   392.0
# 23           186.0           171.0        1505.0   395.0   539.0
# 24           269.0           241.0        2226.0   368.0   493.0
# 25           204.0           183.0        2449.0   527.0   685.0
#
#     ECSAnterior_L  ECSAnterior_R  ECSPosterior_L  ECSPosterior_R
# 0          3207.0         3514.0          2622.0          2798.0
# 1          4873.0         4113.0          5259.0          5717.0
# 2          3297.0         4894.0          4634.0          3549.0
# 3          6760.0         5479.0          5358.0          4489.0
# 4          7310.0         5978.0          5763.0          4633.0
# 5          3277.0         3735.0          2600.0          2823.0
# 6          5499.0         4542.0          5210.0          5477.0
# 7           799.0         1742.0          1539.0          1108.0
# 8          4950.0         3715.0          5042.0          5236.0
# 9          3325.0         4564.0          3991.0          3939.0
# 10         7267.0         6060.0          5792.0          4932.0
# 11         2545.0         2487.0          2106.0          2383.0
# 12         2511.0         2662.0          1485.0          3011.0
# 13         7368.0         6017.0          5919.0          4895.0
# 14         2448.0         2110.0          1494.0          1599.0
# 15         2421.0         4019.0          3629.0          3118.0
# 16         2624.0         2474.0          1538.0          1790.0
# 17         5288.0         4419.0          5198.0          5051.0
# 18         3284.0         3478.0          2507.0          2778.0
# 19         3682.0         4856.0          4109.0          3629.0
# 20         2674.0         2916.0          1803.0          1952.0
# 21         6773.0         5163.0          5089.0          4480.0
# 22         5704.0         4339.0          5224.0          5428.0
# 23         3262.0         3817.0          2922.0          3151.0
# 24         7615.0         6430.0          5947.0          5010.0
# 25         5930.0         6609.0          6776.0          5630.0
#
# [26 rows x 282 columns]

# %%
# study UID is actually series UID; remove the incorrect col
df_vol = df_vol.drop("study_uid", axis =1)

# %% [markdown]
# ### Initial run on adding the brain anatomy

# %%
neuroanatomics = [col for col in df_vol.columns if col != 'series_uid']
neuroanatomics
# Out:
# ['SFG_L',
#  'SFG_R',
#  'SFG_PFC_L',
#  'SFG_PFC_R',
#  'SFG_pole_L',
#  'SFG_pole_R',
#  'MFG_L',
#  'MFG_R',
#  'MFG_DPFC_L',
#  'MFG_DPFC_R',
#  'IFG_opercularis_L',
#  'IFG_opercularis_R',
#  'IFG_orbitalis_L',
#  'IFG_orbitalis_R',
#  'IFG_triangularis_L',
#  'IFG_triangularis_R',
#  'LFOG_L',
#  'LFOG_R',
#  'MFOG_L',
#  'MFOG_R',
#  'RG_L',
#  'RG_R',
#  'PoCG_L',
#  'PoCG_R',
#  'PrCG_L',
#  'PrCG_R',
#  'SPG_L',
#  'SPG_R',
#  'SMG_L',
#  'SMG_R',
#  'AG_L',
#  'AG_R',
#  'PrCu_L',
#  'PrCu_R',
#  'STG_L',
#  'STG_R',
#  'STG_pole_L',
#  'STG_pole_R',
#  'MTG_L',
#  'MTG_R',
#  'MTG_pole_L',
#  'MTG_pole_R',
#  'ITG_L',
#  'ITG_R',
#  'PHG_L',
#  'PHG_R',
#  'ENT_L',
#  'ENT_R',
#  'FuG_L',
#  'FuG_R',
#  'SOG_L',
#  'SOG_R',
#  'MOG_L',
#  'MOG_R',
#  'IOG_L',
#  'IOG_R',
#  'Cu_L',
#  'Cu_R',
#  'LG_L',
#  'LG_R',
#  'rostral_ACC_L',
#  'rostral_ACC_R',
#  'subcallosal_ACC_L',
#  'subcallosal_ACC_R',
#  'subgenual_ACC_L',
#  'subgenual_ACC_R',
#  'dorsal_ACC_L',
#  'dorsal_ACC_R',
#  'PCC_L',
#  'PCC_R',
#  'Insula_L',
#  'Insula_R',
#  'Amyg_L',
#  'Amyg_R',
#  'Hippo_L',
#  'Hippo_R',
#  'Caud_L',
#  'Caud_R',
#  'Put_L',
#  'Put_R',
#  'GP_L',
#  'GP_R',
#  'Thalamus_L',
#  'Thalamus_R',
#  'HypoThalamus_L',
#  'HypoThalamus_R',
#  'AnteriorBasalForebrain_L',
#  'AnteriorBasalForebrain_R',
#  'NucAccumbens_L',
#  'NucAccumbens_R',
#  'RedNc_L',
#  'RedNc_R',
#  'Snigra_L',
#  'Snigra_R',
#  'CerebellumGM_R',
#  'CerebellumGM_L',
#  'CP_L',
#  'CP_R',
#  'Midbrain_L',
#  'Midbrain_R',
#  'CST_L',
#  'CST_R',
#  'SCP_L',
#  'SCP_R',
#  'MCP_L',
#  'MCP_R',
#  'PCT_L',
#  'PCT_R',
#  'ICP_L',
#  'ICP_R',
#  'ML_L',
#  'ML_R',
#  'Pons_L',
#  'Pons_R',
#  'Medulla_L',
#  'Medulla_R',
#  'ACR_L',
#  'ACR_R',
#  'SCR_L',
#  'SCR_R',
#  'PCR_L',
#  'PCR_R',
#  'GCC_L',
#  'GCC_R',
#  'BCC_L',
#  'BCC_R',
#  'SCC_L',
#  'SCC_R',
#  'PVWl_L',
#  'PVWl_R',
#  'ALIC_L',
#  'ALIC_R',
#  'PLIC_L',
#  'PLIC_R',
#  'RLIC_L',
#  'RLIC_R',
#  'EC_L',
#  'EC_R',
#  'CGC_L',
#  'CGC_R',
#  'CGH_L',
#  'CGH_R',
#  'Fx/ST_L',
#  'Fx/ST_R',
#  'Fx_L',
#  'Fx_R',
#  'IFO_L',
#  'IFO_R',
#  'PTR_L',
#  'PTR_R',
#  'SS_L',
#  'SS_R',
#  'SFO_L',
#  'SFO_R',
#  'SLF_L',
#  'SLF_R',
#  'Cl_L',
#  'Cl_R',
#  'PosteriorBasalForebrain_L',
#  'PosteriorBasalForebrain_R',
#  'Mammillary_R',
#  'Mammillary_L',
#  'LV_Frontal_L',
#  'LV_body_L',
#  'LV_atrium_L',
#  'LV_Occipital_L',
#  'LV_Inferior_L',
#  'LV_Frontal_R',
#  'LV_body_R',
#  'LV_atrium_R',
#  'LV_Occipital_R',
#  'LV_Inferior_R',
#  'III_ventricle',
#  'PVWa_L',
#  'PVWa_R',
#  'PVWp_L',
#  'PVWp_R',
#  'SFWM_L',
#  'SFWM_R',
#  'SFWM_PFC_L',
#  'SFWM_PFC_R',
#  'SFWM_pole_L',
#  'SFWM_pole_R',
#  'MFWM_L',
#  'MFWM_R',
#  'MFWM_DPFC_L',
#  'MFWM_DPFC_R',
#  'IFWM_opercularis_L',
#  'IFWM_opercularis_R',
#  'IFWM_orbitalis_L',
#  'IFWM_orbitalis_R',
#  'IFWM_triangularis_L',
#  'IFWM_triangularis_R',
#  'LFOWM_L',
#  'LFOWM_R',
#  'MFOWM_L',
#  'MFOWM_R',
#  'RGWM_L',
#  'RGWM_R',
#  'PoCWM_L',
#  'PoCWM_R',
#  'PrCWM_L',
#  'PrCWM_R',
#  'SPWM_L',
#  'SPWM_R',
#  'SMWM_L',
#  'SMWM_R',
#  'AGWM_L',
#  'AGWM_R',
#  'PrCuWM_L',
#  'PrCuWM_R',
#  'STWM_L',
#  'STWM_R',
#  'STWM_pole_L',
#  'STWM_pole_R',
#  'MTWM_L',
#  'MTWM_R',
#  'MTWM_pole_L',
#  'MTWM_pole_R',
#  'ITWM_L',
#  'ITWM_R',
#  'FuWM_L',
#  'FuWM_R',
#  'SOWM_L',
#  'SOWM_R',
#  'MOWM_L',
#  'MOWM_R',
#  'IOWM_L',
#  'IOWM_R',
#  'CuWM_L',
#  'CuWM_R',
#  'LGWM_L',
#  'LGWM_R',
#  'rostralWM_ACC_L',
#  'rostralWM_ACC_R',
#  'subcallosalWM_ACC_L',
#  'subcallosalWM_ACC_R',
#  'subgenualWM_ACC_L',
#  'subgenualWM_ACC_R',
#  'dorsalWM_ACC_L',
#  'dorsalWM_ACC_R',
#  'PCCWM_L',
#  'PCCWM_R',
#  'CerebellumWM_R',
#  'CerebellumWM_L',
#  'MCP_cb_L',
#  'MCP_cb_R',
#  'ICP_cb_L',
#  'ICP_cb_R',
#  'FrontSul_L',
#  'FrontSul_R',
#  'CentralSul_L',
#  'CentralSul_R',
#  'SylFrontSul_L',
#  'SylFrontSul_R',
#  'SylTempSul_L',
#  'SylTempSul_R',
#  'SylParieSul_L',
#  'SylParieSul_R',
#  'ParietSul_L',
#  'ParietSul_R',
#  'CinguSul_L',
#  'CinguSul_R',
#  'OcciptSul_L',
#  'OcciptSul_R',
#  'TempSul_L',
#  'TempSul_R',
#  'Caudate_tail_L',
#  'Fimbria_L',
#  'Caudate_tail_R',
#  'Fimbria_R',
#  'Chroid_LVetc_L',
#  'Chroid_LVetc_R',
#  'IV_ventricle',
#  'ECCL_L',
#  'ECCL_R',
#  'ECSAnterior_L',
#  'ECSAnterior_R',
#  'ECSPosterior_L',
#  'ECSPosterior_R']

# %%
df_concept[df_concept['concept_class_id']=="Body Structure"].head()
# Out:
#     concept_id                            concept_name           domain_id  \
# 26    42535764          Bone structure of left patella  Spec Anatomic Site
# 27    42535856             Bone structure of left hand  Spec Anatomic Site
# 28    42535857            Bone structure of right hand  Spec Anatomic Site
# 29    42535858            Bone structure of left pubis  Spec Anatomic Site
# 30    42535860  Structure of left ulnar nerve at wrist  Spec Anatomic Site
#
#    vocabulary_id concept_class_id standard_concept concept_code  \
# 26        SNOMED   Body Structure                S    734208001
# 27        SNOMED   Body Structure                S    734354007
# 28        SNOMED   Body Structure                S    734355008
# 29        SNOMED   Body Structure                S    734356009
# 30        SNOMED   Body Structure                S    734362004
#
#    valid_start_date valid_end_date invalid_reason
# 26       2018-01-31     2099-12-31
# 27       2018-01-31     2099-12-31
# 28       2018-01-31     2099-12-31
# 29       2018-01-31     2099-12-31
# 30       2018-01-31     2099-12-31

# %%
df_concept[df_concept['concept_id']>2000000000].head()
# Out:
#    concept_id                                       concept_name    domain_id  \
# 0  2041571200                         Neuropsychiatric Inventory  Measurement
# 1  2041571201  Neuropsychiatric Inventory Section A. Delusion...  Measurement
# 2  2041571202  Neuropsychiatric Inventory Section B. Hallucin...  Measurement
# 3  2041571203  Neuropsychiatric Inventory Section C. Agitatio...  Measurement
# 4  2041571204  Neuropsychiatric Inventory Section D. Depressi...  Measurement
#
#   vocabulary_id concept_class_id standard_concept concept_code  \
# 0             0                0             None            0
# 1             0                0             None            0
# 2             0                0             None            0
# 3             0                0             None            0
# 4             0                0             None            0
#
#   valid_start_date valid_end_date invalid_reason
# 0       1994-01-01     2099-12-31           None
# 1       1994-01-01     2099-12-31           None
# 2       1994-01-01     2099-12-31           None
# 3       1994-01-01     2099-12-31           None
# 4       1994-01-01     2099-12-31           None

# %%
neuroanatomics_id = [2129000000 + i for i in range(len(neuroanatomics))]

neuro_concept_ids = pd.DataFrame({
    'concept_id': neuroanatomics_id,
    'concept_name': neuroanatomics,
    'domain_id': "Spec Anatomic Site",
    'vocabulary_id': "0",
    'concept_class_id': "Body Structure",
    'concept_code': neuroanatomics,
    'valid_start_date': "2024-06-01",
    'valid_end_date': "2099-12-31"
})

neuro_concept_ids.head()
# Out:
#    concept_id concept_name           domain_id vocabulary_id concept_class_id  \
# 0  2129000000        SFG_L  Spec Anatomic Site             0   Body Structure
# 1  2129000001        SFG_R  Spec Anatomic Site             0   Body Structure
# 2  2129000002    SFG_PFC_L  Spec Anatomic Site             0   Body Structure
# 3  2129000003    SFG_PFC_R  Spec Anatomic Site             0   Body Structure
# 4  2129000004   SFG_pole_L  Spec Anatomic Site             0   Body Structure
#
#   concept_code valid_start_date valid_end_date
# 0        SFG_L       2024-06-01     2099-12-31
# 1        SFG_R       2024-06-01     2099-12-31
# 2    SFG_PFC_L       2024-06-01     2099-12-31
# 3    SFG_PFC_R       2024-06-01     2099-12-31
# 4   SFG_pole_L       2024-06-01     2099-12-31

# %%
neuro_concept_ids.shape
# Out:
# (280, 8)

# %%
# Update CONCEPT
#cursor = conn.cursor()

sql = '''
    INSERT INTO dbo.concept (concept_id,concept_name,domain_id,vocabulary_id,concept_class_id,concept_code,valid_start_date,valid_end_date) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in neuro_concept_ids.iterrows():
    cursor.execute(sql, (row['concept_id'], row['concept_name'], row['domain_id'], row['vocabulary_id'], row['concept_class_id'], row['concept_code'],
     row['valid_start_date'], row['valid_end_date']))

conn.commit()

# %% [markdown]
# ### Oragnize the brain volume outputs for OMOP ingestion

# %%
# Using the melt function to transform the DataFrame
df_long = df_vol.melt(id_vars=['series_uid'], var_name='name', value_name='value')

# Display the transformed DataFrame
df_long.shape
# Out:
# (7280, 3)

# %%
df_long.head()
# Out:
#                                      series_uid   name    value
# 0  2.16.124.113543.6006.99.02146034564549802647  SFG_L  12542.0
# 1  2.16.124.113543.6006.99.02156281418585922950  SFG_L  15217.0
# 2    2.16.124.113543.6006.99.993407831381508223  SFG_L  15451.0
# 3   2.16.124.113543.6006.99.7084724843781950414  SFG_L  14793.0
# 4  2.16.124.113543.6006.99.01664766563067247342  SFG_L  14887.0

# %%
df_long = df_long.merge(neuro_concept_ids[['concept_id', 'concept_code']], how = 'left', left_on = 'name', right_on = 'concept_code')
df_long.head()
# Out:
#                                      series_uid   name    value  concept_id  \
# 0  2.16.124.113543.6006.99.02146034564549802647  SFG_L  12542.0  2129000000
# 1  2.16.124.113543.6006.99.02156281418585922950  SFG_L  15217.0  2129000000
# 2    2.16.124.113543.6006.99.993407831381508223  SFG_L  15451.0  2129000000
# 3   2.16.124.113543.6006.99.7084724843781950414  SFG_L  14793.0  2129000000
# 4  2.16.124.113543.6006.99.01664766563067247342  SFG_L  14887.0  2129000000
#
#   concept_code
# 0        SFG_L
# 1        SFG_L
# 2        SFG_L
# 3        SFG_L
# 4        SFG_L

# %%
df_long = df_long.merge(df_staging[['image_series_uid', 'image_occurrence_id', 'person_id']], how = 'left', left_on = 'series_uid', right_on = 'image_series_uid')
df_long.head()
# Out:
#                                      series_uid   name    value  concept_id  \
# 0  2.16.124.113543.6006.99.02146034564549802647  SFG_L  12542.0  2129000000
# 1  2.16.124.113543.6006.99.02156281418585922950  SFG_L  15217.0  2129000000
# 2    2.16.124.113543.6006.99.993407831381508223  SFG_L  15451.0  2129000000
# 3   2.16.124.113543.6006.99.7084724843781950414  SFG_L  14793.0  2129000000
# 4  2.16.124.113543.6006.99.01664766563067247342  SFG_L  14887.0  2129000000
#
#   concept_code                              image_series_uid  \
# 0        SFG_L  2.16.124.113543.6006.99.02146034564549802647
# 1        SFG_L  2.16.124.113543.6006.99.02156281418585922950
# 2        SFG_L    2.16.124.113543.6006.99.993407831381508223
# 3        SFG_L   2.16.124.113543.6006.99.7084724843781950414
# 4        SFG_L  2.16.124.113543.6006.99.01664766563067247342
#
#    image_occurrence_id  person_id
# 0                   77       1594
# 1                  131       2556
# 2                  145       1572
# 3                  360       2593
# 4                  482       2593

# %%
df_long = df_long.drop(['series_uid', 'name'], axis =1)
df_long.head()
# Out:
#      value  concept_id concept_code  \
# 0  12542.0  2129000000        SFG_L
# 1  15217.0  2129000000        SFG_L
# 2  15451.0  2129000000        SFG_L
# 3  14793.0  2129000000        SFG_L
# 4  14887.0  2129000000        SFG_L
#
#                                image_series_uid  image_occurrence_id  \
# 0  2.16.124.113543.6006.99.02146034564549802647                   77
# 1  2.16.124.113543.6006.99.02156281418585922950                  131
# 2    2.16.124.113543.6006.99.993407831381508223                  145
# 3   2.16.124.113543.6006.99.7084724843781950414                  360
# 4  2.16.124.113543.6006.99.01664766563067247342                  482
#
#    person_id
# 0       1594
# 1       2556
# 2       1572
# 3       2593
# 4       2593

# %%
df_long['measurement_date'] = '2024-06-13'
df_long['measurement_concept_id'] = 3011794 #volume estimated, clinical observation, measurement, loinc
df_long['measurement_type_concept_id'] = 32880 #standard algorithm

# %%
df_long['measurement_id'] = [649078 + i for i in range(len(df_long))]

# %%
df_long['image_feature_id'] = [485976 + i for i in range(len(df_long))]

# %%
sql = 'select * from dbo.measurement order by measurement_id desc limit 1'
ex_measurement = pd.read_sql(sql, conn)
ex_measurement.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_88101/497631013.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ex_measurement = pd.read_sql(sql, conn)
#    measurement_id  person_id  measurement_concept_id measurement_date  \
# 0          649077       3919              2041571213       2021-07-20
#
#   measurement_datetime measurement_time  measurement_type_concept_id  \
# 0                 None             None                        32817
#
#   operator_concept_id  value_as_number value_as_concept_id  ... provider_id  \
# 0                None             11.0                None  ...        None
#
#   visit_occurrence_id visit_detail_id measurement_source_value  \
# 0                None            None                     None
#
#   measurement_source_concept_id unit_source_value unit_source_concept_id  \
# 0                    2041571213              None                   None
#
#    value_source_value measurement_event_id meas_event_field_concept_id
# 0                None                 None                        None
#
# [1 rows x 23 columns]

# %%
sql = 'select * from dbo.image_feature order by image_feature_id desc limit 1'
ex_image_feature = pd.read_sql(sql, conn)
ex_image_feature.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_88101/373536257.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ex_image_feature = pd.read_sql(sql, conn)
#    image_feature_id  person_id  image_occurrence_id  \
# 0            485975       3223                  948
#
#    image_feature_event_field_concept_id  image_feature_event_id  \
# 0                               1147330                  485975
#
#    image_feature_concept_id  image_feature_type_concept_id  \
# 0                2129001004                          32817
#
#   image_finding_concept_id image_finding_id  anatomic_site_concept_id  \
# 0                     None             None                   4119359
#
#   alg_system alg_datetime
# 0       None         None

# %%
df_long.head()
# Out:
#      value  concept_id concept_code  \
# 0  12542.0  2129000000        SFG_L
# 1  15217.0  2129000000        SFG_L
# 2  15451.0  2129000000        SFG_L
# 3  14793.0  2129000000        SFG_L
# 4  14887.0  2129000000        SFG_L
#
#                                image_series_uid  image_occurrence_id  \
# 0  2.16.124.113543.6006.99.02146034564549802647                   77
# 1  2.16.124.113543.6006.99.02156281418585922950                  131
# 2    2.16.124.113543.6006.99.993407831381508223                  145
# 3   2.16.124.113543.6006.99.7084724843781950414                  360
# 4  2.16.124.113543.6006.99.01664766563067247342                  482
#
#    person_id measurement_date  measurement_concept_id  \
# 0       1594       2024-06-13                 3011794
# 1       2556       2024-06-13                 3011794
# 2       1572       2024-06-13                 3011794
# 3       2593       2024-06-13                 3011794
# 4       2593       2024-06-13                 3011794
#
#    measurement_type_concept_id  measurement_id  image_feature_id
# 0                        32880          649078            485976
# 1                        32880          649079            485977
# 2                        32880          649080            485978
# 3                        32880          649081            485979
# 4                        32880          649082            485980

# %%
# Update MEASUREMENT
sql = '''
    INSERT INTO dbo.measurement (measurement_id, person_id, measurement_concept_id, measurement_date, measurement_type_concept_id, value_as_number, measurement_source_value, measurement_source_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in df_long.iterrows():
    cursor.execute(sql, (row['measurement_id'], row['person_id'], row['measurement_concept_id'], row['measurement_date'], row['measurement_type_concept_id'], row['value'], row['value'], row['measurement_concept_id']))

conn.commit()

# %%
df_long['image_feature_event_field_concept_id'] = 1147330 #measurement

# %%
# Update IMAGE_FEATURE
sql = '''
    INSERT INTO dbo.image_feature (image_feature_id, person_id, image_occurrence_id, image_feature_event_id,
      image_feature_event_field_concept_id, image_feature_concept_id, image_feature_type_concept_id, anatomic_site_concept_id) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in df_long.iterrows():
    cursor.execute(sql, (row['image_feature_id'], row['person_id'], row['image_occurrence_id'], row['measurement_id'], 
                  row['image_feature_event_field_concept_id'], row['measurement_concept_id'], row['measurement_type_concept_id'],
                  row['concept_id']))

conn.commit()

# %%
conn.close()
cursor.close()

# %%
df_concept[df_concept['concept_code'].isin(["PHG_L", "PHG_R", "ENT_L", "ENT_R", "Amyg_L", "Amyg_R", "Hippo_L", "Hippo_R", "CGC_L", "CGC_R"])]
# Out:
#      concept_id                      concept_name           domain_id  \
# 624  2129000044        Parahippocampal Gyrus Left  Spec Anatomic Site
# 625  2129000045       Parahippocampal Gyrus Right  Spec Anatomic Site
# 626  2129000046              Entorhinal Area Left  Spec Anatomic Site
# 627  2129000047             Entorhinal Area Right  Spec Anatomic Site
# 652  2129000072                     Amygdala Left  Spec Anatomic Site
# 653  2129000073                    Amygdala Right  Spec Anatomic Site
# 654  2129000074                  Hippocampus Left  Spec Anatomic Site
# 655  2129000075                 Hippocampus Right  Spec Anatomic Site
# 718  2129000138   Cingulum (Cingulate Gyrus) Left  Spec Anatomic Site
# 719  2129000139  Cingulum (Cingulate Gyrus) Right  Spec Anatomic Site
#
#     vocabulary_id concept_class_id standard_concept concept_code  \
# 624             0   Body Structure             None        PHG_L
# 625             0   Body Structure             None        PHG_R
# 626             0   Body Structure             None        ENT_L
# 627             0   Body Structure             None        ENT_R
# 652             0   Body Structure             None       Amyg_L
# 653             0   Body Structure             None       Amyg_R
# 654             0   Body Structure             None      Hippo_L
# 655             0   Body Structure             None      Hippo_R
# 718             0   Body Structure             None        CGC_L
# 719             0   Body Structure             None        CGC_R
#
#     valid_start_date valid_end_date invalid_reason
# 624       2024-06-01     2099-12-31           None
# 625       2024-06-01     2099-12-31           None
# 626       2024-06-01     2099-12-31           None
# 627       2024-06-01     2099-12-31           None
# 652       2024-06-01     2099-12-31           None
# 653       2024-06-01     2099-12-31           None
# 654       2024-06-01     2099-12-31           None
# 655       2024-06-01     2099-12-31           None
# 718       2024-06-01     2099-12-31           None
# 719       2024-06-01     2099-12-31           None

# %% [markdown]
# # DICOM to OMOP: create custom vocabularies
#
# We will be creating custom vocabularies for DICOM Attributes and Value Sets.
# 1. Restructure the data: DICOM harvest to OMOP structure
# 2. DML Scripts using Python & SQL
#    1. Update `VOCABULARY` table
#    2. Update `CONCEPT_CLASS` table
#    3. Update `CONCEPT` table
# 3. Update `CONCEPT_RELATIONSHIP` table from DICOM Standard Part 3
#
# Links to OMOP CDM
# - [Create a custom vocabulary](https://forums.ohdsi.org/t/how-to-add-a-custom-vocabulary-to-the-omop-vocabulary-table/12440/3)
# - [OMOP CDM v.5.4 VOCABULARY](https://ohdsi.github.io/CommonDataModel/cdm54.html#vocabulary)
# - [OMOP CDM v.5.4 CONCEPT_CLASS](https://ohdsi.github.io/CommonDataModel/cdm54.html#concept_class)
# - [OMOP CDM v.5.4 CONCEPT](https://ohdsi.github.io/CommonDataModel/cdm54.html#concept)
#
# Links to DICOM Standards
# - [Value Representation (VR)](https://dicom.nema.org/medical/dicom/current/output/chtml/part05/sect_6.2.html)

# %% [markdown]
# ## 1. Restructure data: DICOM harvest to OMOP Structure
#
# <blockquote>
# <strong>This is for your reference, you can skip this section and use the flat files in the `files` directory in this repository. The instruction to update your OMOP database is at the end of this notebook.</strong>
# </blockquote>

# %%
import pandas as pd

attributes = pd.read_csv("./files/DICOM Standard/part6_attributes.csv")
valuesets = pd.read_csv("./files/DICOM Standard/part16_fhir_valuesets.csv")
part3 = pd.read_pickle('./files/DICOM Standard/part3_mapping.pkl')

# %%
# DICOM attributes
# concept_id: 2128000000 + sequential number in range of 10-5999
# concept_name: 'Name'
# domain_id: Candidates - 'Measurement', 'Meas Value', 'Meas/Procedure', 'Type Concept'
# vocabulary_id: 'DICOM'
# concept_class_id: 'DICOM Attributes'
# standard_concept: NULL
# concept_code: Tag
# valid_start_date: 19930101
# valid_end_date: 20991231
# invalid_reason: NULL

# %%
part3_att = part3[part3['CID']!=''].merge(attributes, left_on = 'Tag', right_on = 'Tag_cleaned', how = 'left')

# %%
attributes_cid = part3_att['Tag_x'].unique()

# %%
included_VR = ['AT', 'CS', 'DA', 'DT', 'DS', 'FL', 'FD', 'IS', 'SL', 'SS', 'SV', 'TM', 'UL', 'US', 'UV']
attributes_included = attributes[(attributes['VR'].isin(included_VR)) | (attributes['Tag_cleaned'].isin(attributes_cid))]
attributes_included #2915 -> 2983
# Out:
#               Tag                                        Name  \
# 0     (0008,0001)                               Length to End
# 1     (0008,0005)                      Specific Character Set
# 3     (0008,0008)                                  Image Type
# 5     (0008,0012)                      Instance Creation Date
# 6     (0008,0013)                      Instance Creation Time
# ...           ...                                         ...
# 5165  (60xx,1301)                                    ROI Area
# 5166  (60xx,1302)                                    ROI Mean
# 5167  (60xx,1303)                      ROI Standard Deviation
# 5173  (7FE0,0003)  Encapsulated Pixel Data Value Total Length
# 5181  (7Fxx,0011)                    Variable Next Data Group
#
#                                          Keyword  VR   VM  Unnamed: 5  \
# 0                                  Length​To​End  UL    1         RET
# 1                         Specific​Character​Set  CS  1-n         NaN
# 3                                     Image​Type  CS  2-n         NaN
# 5                         Instance​Creation​Date  DA    1         NaN
# 6                         Instance​Creation​Time  TM    1         NaN
# ...                                          ...  ..  ...         ...
# 5165                                    ROI​Area  IS    1         NaN
# 5166                                    ROI​Mean  DS    1         NaN
# 5167                      ROI​Standard​Deviation  DS    1         NaN
# 5173  Encapsulated​Pixel​Data​Value​Total​Length  UV    1         NaN
# 5181                    Variable​Next​Data​Group  US    1  RET (2007)
#
#      Tag_cleaned
# 0       00080001
# 1       00080005
# 3       00080008
# 5       00080012
# 6       00080013
# ...          ...
# 5165    60xx1301
# 5166    60xx1302
# 5167    60xx1303
# 5173    7FE00003
# 5181    7Fxx0011
#
# [2983 rows x 7 columns]

# %%
import numpy as np
import pandas as pd

sequential_numbers = range(10, len(attributes_included)+10)
attributes_included.loc[:, 'concept_id'] = [2128000000 + num for num in sequential_numbers]

columns = ['concept_id', 'concept_name', 'domain_id', 'vocabulary_id', 'concept_class_id', 'standard_concept', 'concept_code', 'valid_start_date', 'valid_end_date','invalid_reason']
attribute_table_omop = pd.DataFrame(columns = columns)

attribute_table_omop['concept_id'] = attributes_included['concept_id']
attribute_table_omop['concept_name'] = attributes_included['Name']
attribute_table_omop['domain_id'] = 'Measurement'
attribute_table_omop['vocabulary_id'] = 'DICOM'
attribute_table_omop['concept_class_id'] = 'DICOM Attributes'
attribute_table_omop['concept_code'] = attributes_included['Tag_cleaned']
attribute_table_omop['valid_start_date'] = 19930101
attribute_table_omop['valid_end_date'] = 20991231

attribute_table_omop = attribute_table_omop.reset_index(drop='True')
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_43806/2190954720.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes_included.loc[:, 'concept_id'] = [2128000000 + num for num in sequential_numbers]

# %%
attribute_table_omop
# Out:
#       concept_id                                concept_name    domain_id  \
# 0     2128000010                               Length to End  Measurement
# 1     2128000011                      Specific Character Set  Measurement
# 2     2128000012                                  Image Type  Measurement
# 3     2128000013                      Instance Creation Date  Measurement
# 4     2128000014                      Instance Creation Time  Measurement
# ...          ...                                         ...          ...
# 2978  2128002988                                    ROI Area  Measurement
# 2979  2128002989                                    ROI Mean  Measurement
# 2980  2128002990                      ROI Standard Deviation  Measurement
# 2981  2128002991  Encapsulated Pixel Data Value Total Length  Measurement
# 2982  2128002992                    Variable Next Data Group  Measurement
#
#      vocabulary_id  concept_class_id standard_concept concept_code  \
# 0            DICOM  DICOM Attributes              NaN     00080001
# 1            DICOM  DICOM Attributes              NaN     00080005
# 2            DICOM  DICOM Attributes              NaN     00080008
# 3            DICOM  DICOM Attributes              NaN     00080012
# 4            DICOM  DICOM Attributes              NaN     00080013
# ...            ...               ...              ...          ...
# 2978         DICOM  DICOM Attributes              NaN     60xx1301
# 2979         DICOM  DICOM Attributes              NaN     60xx1302
# 2980         DICOM  DICOM Attributes              NaN     60xx1303
# 2981         DICOM  DICOM Attributes              NaN     7FE00003
# 2982         DICOM  DICOM Attributes              NaN     7Fxx0011
#
#       valid_start_date  valid_end_date invalid_reason
# 0             19930101        20991231            NaN
# 1             19930101        20991231            NaN
# 2             19930101        20991231            NaN
# 3             19930101        20991231            NaN
# 4             19930101        20991231            NaN
# ...                ...             ...            ...
# 2978          19930101        20991231            NaN
# 2979          19930101        20991231            NaN
# 2980          19930101        20991231            NaN
# 2981          19930101        20991231            NaN
# 2982          19930101        20991231            NaN
#
# [2983 rows x 10 columns]

# %%
# DICOM Value Sets
# concept_id: 2128000000 + sequential number in range of 6000-999999
# concept_name: display
# domain_id: Candidates - 'Measurement', 'Meas Value', 'Meas/Procedure', 'Type Concept', 'Condition', 'Observation'
# vocabulary_id: 'DICOM'
# concept_class_id: 'DICOM Value Sets'
# standard_concept: NULL
# concept_code: code
# valid_start_date: 19930101
# valid_end_date: 20991231
# invalid_reason: NULL

# %%
valuesets.shape
# Out:
# (26825, 8)

# %%
valuesets[["code", "display", "system"]].drop_duplicates().shape
# Out:
# (13966, 3)

# %%
valuesets_dicom = valuesets[valuesets['system']=='http://dicom.nema.org/resources/ontology/DCM']
valuesets_dicom #5223
# Out:
#          code                                 display  \
# 31     110504                            Patient died
# 32     110515  Patient condition prevented continuing
# 33     110503      Patient allergic to media/contrast
# 34     110514       Incorrect worklist entry selected
# 35     110502             Incorrect procedure ordered
# ...       ...                                     ...
# 26820  128129          Plane through Posterior Extent
# 26821  128128           Plane through Anterior Extent
# 26822  128130                    Plane through Center
# 26823  128121           Plane through Inferior Extent
# 26824  128120           Plane through Superior Extent
#
#                                              system  \
# 31     http://dicom.nema.org/resources/ontology/DCM
# 32     http://dicom.nema.org/resources/ontology/DCM
# 33     http://dicom.nema.org/resources/ontology/DCM
# 34     http://dicom.nema.org/resources/ontology/DCM
# 35     http://dicom.nema.org/resources/ontology/DCM
# ...                                             ...
# 26820  http://dicom.nema.org/resources/ontology/DCM
# 26821  http://dicom.nema.org/resources/ontology/DCM
# 26822  http://dicom.nema.org/resources/ontology/DCM
# 26823  http://dicom.nema.org/resources/ontology/DCM
# 26824  http://dicom.nema.org/resources/ontology/DCM
#
#                                                     id   version  status  \
# 31     dicom-cid-9301-ModalityPPSDiscontinuationReason  20140419  active
# 32     dicom-cid-9301-ModalityPPSDiscontinuationReason  20140419  active
# 33     dicom-cid-9301-ModalityPPSDiscontinuationReason  20140419  active
# 34     dicom-cid-9301-ModalityPPSDiscontinuationReason  20140419  active
# 35     dicom-cid-9301-ModalityPPSDiscontinuationReason  20140419  active
# ...                                                ...       ...     ...
# 26820            dicom-cid-1010-ReferenceGeometryPlane  20160905  active
# 26821            dicom-cid-1010-ReferenceGeometryPlane  20160905  active
# 26822            dicom-cid-1010-ReferenceGeometryPlane  20160905  active
# 26823            dicom-cid-1010-ReferenceGeometryPlane  20160905  active
# 26824            dicom-cid-1010-ReferenceGeometryPlane  20160905  active
#
#                                              description   cid
# 31     Transitive closure of CID 9301 ModalityPPSDisc...  9301
# 32     Transitive closure of CID 9301 ModalityPPSDisc...  9301
# 33     Transitive closure of CID 9301 ModalityPPSDisc...  9301
# 34     Transitive closure of CID 9301 ModalityPPSDisc...  9301
# 35     Transitive closure of CID 9301 ModalityPPSDisc...  9301
# ...                                                  ...   ...
# 26820  Transitive closure of CID 1010 ReferenceGeomet...  1010
# 26821  Transitive closure of CID 1010 ReferenceGeomet...  1010
# 26822  Transitive closure of CID 1010 ReferenceGeomet...  1010
# 26823  Transitive closure of CID 1010 ReferenceGeomet...  1010
# 26824  Transitive closure of CID 1010 ReferenceGeomet...  1010
#
# [5223 rows x 8 columns]

# %%
valuesets_unique = valuesets_dicom[["code", "display", "system"]].drop_duplicates().reset_index(drop=True)
valuesets_unique.shape #3295
# Out:
# (3295, 3)

# %%
import numpy as np
import pandas as pd

sequential_numbers = range(6000, len(valuesets_unique)+6000)
valuesets_unique.loc[:, 'concept_id'] = [2128000000 + num for num in sequential_numbers]

columns = ['concept_id', 'concept_name', 'domain_id', 'vocabulary_id', 'concept_class_id', 'standard_concept', 'concept_code', 'valid_start_date', 'valid_end_date','invalid_reason']
valuesets_table_omop = pd.DataFrame(columns = columns)

valuesets_table_omop['concept_id'] = valuesets_unique['concept_id']
valuesets_table_omop['concept_name'] = valuesets_unique['display']
valuesets_table_omop['domain_id'] = 'Measurement'
valuesets_table_omop['vocabulary_id'] = 'DICOM'
valuesets_table_omop['concept_class_id'] = 'DICOM Value Sets'
valuesets_table_omop['concept_code'] = valuesets_unique['code']
valuesets_table_omop['valid_start_date'] = 19930101
valuesets_table_omop['valid_end_date'] = 20991231

valuesets_table_omop = valuesets_table_omop.reset_index(drop='True')

# %%
valuesets_table_omop
# Out:
#       concept_id                            concept_name    domain_id  \
# 0     2128006000                            Patient died  Measurement
# 1     2128006001  Patient condition prevented continuing  Measurement
# 2     2128006002      Patient allergic to media/contrast  Measurement
# 3     2128006003       Incorrect worklist entry selected  Measurement
# 4     2128006004             Incorrect procedure ordered  Measurement
# ...          ...                                     ...          ...
# 3290  2128009290          Plane through Posterior Extent  Measurement
# 3291  2128009291           Plane through Anterior Extent  Measurement
# 3292  2128009292                    Plane through Center  Measurement
# 3293  2128009293           Plane through Inferior Extent  Measurement
# 3294  2128009294           Plane through Superior Extent  Measurement
#
#      vocabulary_id  concept_class_id standard_concept concept_code  \
# 0            DICOM  DICOM Value Sets              NaN       110504
# 1            DICOM  DICOM Value Sets              NaN       110515
# 2            DICOM  DICOM Value Sets              NaN       110503
# 3            DICOM  DICOM Value Sets              NaN       110514
# 4            DICOM  DICOM Value Sets              NaN       110502
# ...            ...               ...              ...          ...
# 3290         DICOM  DICOM Value Sets              NaN       128129
# 3291         DICOM  DICOM Value Sets              NaN       128128
# 3292         DICOM  DICOM Value Sets              NaN       128130
# 3293         DICOM  DICOM Value Sets              NaN       128121
# 3294         DICOM  DICOM Value Sets              NaN       128120
#
#       valid_start_date  valid_end_date invalid_reason
# 0             19930101        20991231            NaN
# 1             19930101        20991231            NaN
# 2             19930101        20991231            NaN
# 3             19930101        20991231            NaN
# 4             19930101        20991231            NaN
# ...                ...             ...            ...
# 3290          19930101        20991231            NaN
# 3291          19930101        20991231            NaN
# 3292          19930101        20991231            NaN
# 3293          19930101        20991231            NaN
# 3294          19930101        20991231            NaN
#
# [3295 rows x 10 columns]

# %%
import pandas as pd

modality = pd.read_csv('./files/DICOM Standard/part3_modality.csv')
patient_position = pd.read_csv('./files/DICOM Standard/part3_patient_position.csv')
lossy_image_comp_methods = pd.read_csv('./files/DICOM Standard/part3_lossy_image_comp_methods.csv')
other_values = pd.read_csv('./files/DICOM Standard/part3_other_values.csv')
body_part = pd.read_pickle('./files/DICOM Standard/part16_body_part_examined.pkl')

# %%
other_values['concept_id'] = pd.to_numeric(other_values['concept_id'], errors='coerce').astype('Int64')
modality['concept_id'] = pd.to_numeric(modality['concept_id'], errors='coerce').astype('Int64')

# %%
combined_values = pd.concat([modality, patient_position, lossy_image_comp_methods, other_values[['code', 'description', 'concept_id']]])
combined_values = combined_values.rename(columns={'concept_id': 'syn_concept_id'})
combined_values
# Out:
#        code                                        description  syn_concept_id
# 0       ANN                                         Annotation            <NA>
# 1        AR                                     Autorefraction            <NA>
# 2      ASMT                         Content Assessment Results            <NA>
# 3        AU                                              Audio            <NA>
# 4      BDUS                     Bone Densitometry (ultrasound)            <NA>
# ..      ...                                                ...             ...
# 8   INVERSE                                            Inverse         4114662
# 9         U                                           Unpaired            <NA>
# 10        B                                               Both        45883500
# 11       00  image has not been subjected to lossy compression            <NA>
# 12       01      image has been subjected to lossy compression            <NA>
#
# [116 rows x 3 columns]

# %%
index = valuesets_table_omop['concept_id'].max() + 1
sequential_numbers = range(6000, len(combined_values)+6000)
combined_values.loc[:, 'concept_id'] = [index + num for num in sequential_numbers]

columns = ['concept_id', 'concept_name', 'domain_id', 'vocabulary_id', 'concept_class_id', 'standard_concept', 'concept_code', 'valid_start_date', 'valid_end_date','invalid_reason']
cs_value_table_omop = pd.DataFrame(columns = columns)

cs_value_table_omop['concept_id'] = combined_values['concept_id']
cs_value_table_omop['concept_name'] = combined_values['description']
cs_value_table_omop['domain_id'] = 'Measurement'
cs_value_table_omop['vocabulary_id'] = 'DICOM'
cs_value_table_omop['concept_class_id'] = 'DICOM Value Sets'
cs_value_table_omop['concept_code'] = combined_values['code']
cs_value_table_omop['valid_start_date'] = 19930101
cs_value_table_omop['valid_end_date'] = 20991231

cs_value_table_omop = cs_value_table_omop.reset_index(drop='True')

# %%
cs_value_table_omop
# Out:
#      concept_id                                       concept_name  \
# 0    2128015295                                         Annotation
# 1    2128015296                                     Autorefraction
# 2    2128015297                         Content Assessment Results
# 3    2128015298                                              Audio
# 4    2128015299                     Bone Densitometry (ultrasound)
# ..          ...                                                ...
# 111  2128015406                                            Inverse
# 112  2128015407                                           Unpaired
# 113  2128015408                                               Both
# 114  2128015409  image has not been subjected to lossy compression
# 115  2128015410      image has been subjected to lossy compression
#
#        domain_id vocabulary_id  concept_class_id standard_concept  \
# 0    Measurement         DICOM  DICOM Value Sets              NaN
# 1    Measurement         DICOM  DICOM Value Sets              NaN
# 2    Measurement         DICOM  DICOM Value Sets              NaN
# 3    Measurement         DICOM  DICOM Value Sets              NaN
# 4    Measurement         DICOM  DICOM Value Sets              NaN
# ..           ...           ...               ...              ...
# 111  Measurement         DICOM  DICOM Value Sets              NaN
# 112  Measurement         DICOM  DICOM Value Sets              NaN
# 113  Measurement         DICOM  DICOM Value Sets              NaN
# 114  Measurement         DICOM  DICOM Value Sets              NaN
# 115  Measurement         DICOM  DICOM Value Sets              NaN
#
#     concept_code  valid_start_date  valid_end_date invalid_reason
# 0            ANN          19930101        20991231            NaN
# 1             AR          19930101        20991231            NaN
# 2           ASMT          19930101        20991231            NaN
# 3             AU          19930101        20991231            NaN
# 4           BDUS          19930101        20991231            NaN
# ..           ...               ...             ...            ...
# 111      INVERSE          19930101        20991231            NaN
# 112            U          19930101        20991231            NaN
# 113            B          19930101        20991231            NaN
# 114           00          19930101        20991231            NaN
# 115           01          19930101        20991231            NaN
#
# [116 rows x 10 columns]

# %% [markdown]
# ### For Concept_relationship

# %%
# Pivot (melt) the DataFrame to go from wide to long format
other_values_long = pd.melt(other_values, id_vars=['code', 'description', 'concept_id'], 
                  value_vars=['tag_1', 'tag_2', 'tag_3'], 
                  var_name='tag_type', value_name='tags')

# Drop the 'tag_type' column as it is not needed in the final format
other_values_long = other_values_long.drop('tag_type', axis=1)
other_values_long = other_values_long[~other_values_long['tags'].isna()]
other_values_long['Tag'] = other_values_long['tags'].str.replace(r'[(),]', '', regex = True)
other_values_long = other_values_long.rename(columns={'concept_id': 'syn_concept_id'})
other_values_long.head()
# Out:
#         code description  syn_concept_id         tags       Tag
# 0          R       Right         4080761  (0020,0060)  00200060
# 1          L        Left         4300877  (0020,0060)  00200060
# 2      BIPED       BIPED            <NA>  (0010,2210)  00102210
# 3  QUADRUPED   QUADRUPED            <NA>  (0010,2210)  00102210
# 4        YES         YES         4188539  (0028,0300)  00280300

# %%
other_values_long = other_values_long.merge(cs_value_table_omop[['concept_id', 'concept_code']], how = 'left', right_on = 'concept_code', left_on= 'code')
other_values_long = other_values_long.drop(columns=['tags', 'concept_code'])
other_values_long = other_values_long.rename(columns={'concept_id': 'concept_id_2'}) #value sets' concept ID is concept_id_2 for Concept_relationship table
other_values_long.head()
# Out:
#         code description  syn_concept_id       Tag  concept_id_2
# 0          R       Right         4080761  00200060    2128015398
# 1          L        Left         4300877  00200060    2128015399
# 2      BIPED       BIPED            <NA>  00102210    2128015400
# 3  QUADRUPED   QUADRUPED            <NA>  00102210    2128015401
# 4        YES         YES         4188539  00280300    2128015402

# %%
other_values_long = other_values_long.merge(attribute_table_omop[['concept_id', 'concept_code']], how='left', left_on = 'Tag', right_on = 'concept_code')
other_values_long = other_values_long.drop(columns=['concept_code'])
other_values_long = other_values_long.rename(columns={'concept_id': 'concept_id_1'}) #attributes' concept ID is concept_id_1 for Concept_relationship table
other_values_long
# Out:
#          code                                        description  \
# 0           R                                              Right
# 1           L                                               Left
# 2       BIPED                                              BIPED
# 3   QUADRUPED                                          QUADRUPED
# 4         YES                                                YES
# 5          NO                                                 NO
# 6        BOTH                                               BOTH
# 7    IDENTITY                                           Identity
# 8     INVERSE                                            Inverse
# 9           U                                           Unpaired
# 10          B                                               Both
# 11         00  image has not been subjected to lossy compression
# 12         01      image has been subjected to lossy compression
# 13          R                                              Right
# 14          L                                               Left
# 15        YES                                                YES
# 16         NO                                                 NO
# 17        YES                                                YES
# 18         NO                                                 NO
#
#     syn_concept_id       Tag  concept_id_2  concept_id_1
# 0          4080761  00200060    2128015398    2128001088
# 1          4300877  00200060    2128015399    2128001088
# 2             <NA>  00102210    2128015400    2128000124
# 3             <NA>  00102210    2128015401    2128000124
# 4          4188539  00280300    2128015402    2128001367
# 5          4188540  00280300    2128015403    2128001367
# 6         45883500  00280300    2128015404    2128001367
# 7             <NA>  20500020    2128015405    2128002254
# 8          4114662  20500020    2128015406    2128002254
# 9             <NA>  00200062    2128015407    2128001089
# 10        45883500  00200062    2128015408    2128001089
# 11            <NA>  00282110    2128015409    2128001416
# 12            <NA>  00282110    2128015410    2128001416
# 13         4080761  00200062    2128015398    2128001089
# 14         4300877  00200062    2128015399    2128001089
# 15         4188539  00280301    2128015402    2128001368
# 16         4188540  00280301    2128015403    2128001368
# 17         4188539  00280302    2128015402    2128001369
# 18         4188540  00280302    2128015403    2128001369

# %%
body_part.head()
# Out:
#   Coding Scheme Designator Code Value             Code Meaning  \
# 0                      SCT  818981001                  Abdomen
# 1                      SCT  818982008       Abdomen and Pelvis
# 2                      SCT    7832008          Abdominal aorta
# 3                      SCT   85856004  Acromioclavicular joint
# 4                      SCT   23451007            Adrenal gland
#
#   Body Part Examined SNOMED-RT ID (Retired) FMA Code Value  \
# 0            ABDOMEN
# 1      ABDOMENPELVIS
# 2     ABDOMINALAORTA                T-42500
# 3            ACJOINT                T-15420
# 4            ADRENAL                T-B3000
#
#   UMLS Concept UniqueID
# 0
# 1
# 2
# 3
# 4

# %%
index = cs_value_table_omop['concept_id'].max() + 1
sequential_numbers = range(6000, len(body_part)+6000)
body_part.loc[:, 'concept_id'] = [index + num for num in sequential_numbers]

columns = ['concept_id', 'concept_name', 'domain_id', 'vocabulary_id', 'concept_class_id', 'standard_concept', 'concept_code', 'valid_start_date', 'valid_end_date','invalid_reason']
body_part_table_omop = pd.DataFrame(columns = columns)

body_part_table_omop['concept_id'] = body_part['concept_id']
body_part_table_omop['concept_name'] = body_part['Code Meaning']
body_part_table_omop['domain_id'] = 'Measurement'
body_part_table_omop['vocabulary_id'] = 'DICOM'
body_part_table_omop['concept_class_id'] = 'DICOM Value Sets'
body_part_table_omop['concept_code'] = body_part['Body Part Examined']
body_part_table_omop['valid_start_date'] = 19930101
body_part_table_omop['valid_end_date'] = 20991231

body_part_table_omop = body_part_table_omop.reset_index(drop='True')
body_part_table_omop
# Out:
#      concept_id                  concept_name    domain_id vocabulary_id  \
# 0    2128021411                       Abdomen  Measurement         DICOM
# 1    2128021412            Abdomen and Pelvis  Measurement         DICOM
# 2    2128021413               Abdominal aorta  Measurement         DICOM
# 3    2128021414       Acromioclavicular joint  Measurement         DICOM
# 4    2128021415                 Adrenal gland  Measurement         DICOM
# ..          ...                           ...          ...           ...
# 393  2128021804              Vertebral artery  Measurement         DICOM
# 394  2128021805  Vertebral column and cranium  Measurement         DICOM
# 395  2128021806                         Vulva  Measurement         DICOM
# 396  2128021807                   Wrist joint  Measurement         DICOM
# 397  2128021808                        Zygoma  Measurement         DICOM
#
#      concept_class_id standard_concept    concept_code  valid_start_date  \
# 0    DICOM Value Sets              NaN         ABDOMEN          19930101
# 1    DICOM Value Sets              NaN   ABDOMENPELVIS          19930101
# 2    DICOM Value Sets              NaN  ABDOMINALAORTA          19930101
# 3    DICOM Value Sets              NaN         ACJOINT          19930101
# 4    DICOM Value Sets              NaN         ADRENAL          19930101
# ..                ...              ...             ...               ...
# 393  DICOM Value Sets              NaN      VERTEBRALA          19930101
# 394  DICOM Value Sets              NaN                          19930101
# 395  DICOM Value Sets              NaN           VULVA          19930101
# 396  DICOM Value Sets              NaN           WRIST          19930101
# 397  DICOM Value Sets              NaN          ZYGOMA          19930101
#
#      valid_end_date invalid_reason
# 0          20991231            NaN
# 1          20991231            NaN
# 2          20991231            NaN
# 3          20991231            NaN
# 4          20991231            NaN
# ..              ...            ...
# 393        20991231            NaN
# 394        20991231            NaN
# 395        20991231            NaN
# 396        20991231            NaN
# 397        20991231            NaN
#
# [398 rows x 10 columns]

# %% [markdown]
# ### Combine DICOM concepts

# %%
omop_table_staging = pd.concat([attribute_table_omop, valuesets_table_omop, cs_value_table_omop, body_part_table_omop], ignore_index=True)
omop_table_staging['standard_concept'] = ''
omop_table_staging.to_csv('./files/OMOP CDM Staging/omop_table_staging_new.csv', index=False)
omop_table_staging #6792
# Out:
#       concept_id                  concept_name    domain_id vocabulary_id  \
# 0     2128000010                 Length to End  Measurement         DICOM
# 1     2128000011        Specific Character Set  Measurement         DICOM
# 2     2128000012                    Image Type  Measurement         DICOM
# 3     2128000013        Instance Creation Date  Measurement         DICOM
# 4     2128000014        Instance Creation Time  Measurement         DICOM
# ...          ...                           ...          ...           ...
# 6787  2128021804              Vertebral artery  Measurement         DICOM
# 6788  2128021805  Vertebral column and cranium  Measurement         DICOM
# 6789  2128021806                         Vulva  Measurement         DICOM
# 6790  2128021807                   Wrist joint  Measurement         DICOM
# 6791  2128021808                        Zygoma  Measurement         DICOM
#
#       concept_class_id standard_concept concept_code  valid_start_date  \
# 0     DICOM Attributes                      00080001          19930101
# 1     DICOM Attributes                      00080005          19930101
# 2     DICOM Attributes                      00080008          19930101
# 3     DICOM Attributes                      00080012          19930101
# 4     DICOM Attributes                      00080013          19930101
# ...                ...              ...          ...               ...
# 6787  DICOM Value Sets                    VERTEBRALA          19930101
# 6788  DICOM Value Sets                                        19930101
# 6789  DICOM Value Sets                         VULVA          19930101
# 6790  DICOM Value Sets                         WRIST          19930101
# 6791  DICOM Value Sets                        ZYGOMA          19930101
#
#       valid_end_date invalid_reason
# 0           20991231            NaN
# 1           20991231            NaN
# 2           20991231            NaN
# 3           20991231            NaN
# 4           20991231            NaN
# ...              ...            ...
# 6787        20991231            NaN
# 6788        20991231            NaN
# 6789        20991231            NaN
# 6790        20991231            NaN
# 6791        20991231            NaN
#
# [6792 rows x 10 columns]

# %% [markdown]
# ## 2. DML Scripts using Python & SQL

# %%
import psycopg2
 
conn = psycopg2.connect(
    database="adni",
    user="dbadmin",
    password="hopkinsx93ewD",
    host="ohdsicdmdb.postgres.database.azure.com",
    port="5432",
    connect_timeout = 6000
)
 
cursor = conn.cursor()

# %%
import pyodbc

# Connect to your database
server = 'server_name'
database = 'database_name'
# here, we use a trusted connection (i.e., using Windows account), you can also use user_name and password by replacing it with ';UID=<user_name>;PWD=<password>;Encrypt=no'
conn = pyodbc.connect('Driver={SQL Server};Server=' + server + ';Database=' + database + ';Trusted_Connection=yes;')
cursor = conn.cursor()

# Update VOCABULARY
sql = '''
    INSERT INTO dbo.VOCABULARY (vocabulary_id, vocabulary_name, vocabulary_reference, vocabulary_version, vocabulary_concept_id)
    VALUES ('DICOM', 'Digital Imaging and Communications in Medicine (National Electrical Manufacturers Association)',  'https://www.dicomstandard.org/current', 'NEMA Standard PS3', 2128000000)
    '''
cursor.execute(sql)
conn.commit()

# %%
# Update CONCEPT_CLASS
sql = '''
    INSERT INTO CONCEPT_CLASS (concept_class_id, concept_class_name, concept_class_concept_id)
    VALUES ('DICOM Attributes', 'DICOM Attributes', 2128000001),
           ('DICOM Value Sets', 'DICOM Value Sets', 2128000002)
    '''
cursor.execute(sql)
conn.commit()

# %%
# Load the file for DICOM attributes and value sets
omop_table_staging = pd.read_csv('./files/OMOP CDM Staging/omop_table_staging_new.csv')

from datetime import datetime

sql = '''
    INSERT INTO dbo.concept (concept_id, concept_name, domain_id, vocabulary_id, concept_class_id, concept_code, valid_start_date, valid_end_date) 
    VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
    '''
for index, row in omop_table_staging.iterrows():
    # Convert the valid_start_date and valid_end_date from integer (YYYYMMDD) to date
    valid_start_date = datetime.strptime(str(row['valid_start_date']), '%Y%m%d').date() if pd.notnull(row['valid_start_date']) else None
    valid_end_date = datetime.strptime(str(row['valid_end_date']), '%Y%m%d').date() if pd.notnull(row['valid_end_date']) else None

    cursor.execute(sql, (
        row['concept_id'], 
        row['concept_name'], 
        row['domain_id'], 
        row['vocabulary_id'], 
        row['concept_class_id'], 
        row['concept_code'], 
        valid_start_date, 
        valid_end_date
    ))

conn.commit()

# %%
# check the upload
sql = "select * from dbo.concept where vocabulary_id = 'DICOM'"
omop_dicom_test = pd.read_sql_query(sql, conn)
omop_dicom_test.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_43806/3889848845.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   omop_dicom_test = pd.read_sql_query(sql, conn)
#    concept_id       concept_name    domain_id vocabulary_id  concept_class_id  \
# 0  2128006112  TG18-GA10 Pattern  Measurement         DICOM  DICOM Value Sets
# 1  2128006113  TG18-GA25 Pattern  Measurement         DICOM  DICOM Value Sets
# 2  2128006114  TG18-GA20 Pattern  Measurement         DICOM  DICOM Value Sets
# 3  2128006115  TG18-GA03 Pattern  Measurement         DICOM  DICOM Value Sets
# 4  2128006116  TG18-GA08 Pattern  Measurement         DICOM  DICOM Value Sets
#
#   standard_concept concept_code valid_start_date valid_end_date invalid_reason
# 0             None       109873       1993-01-01     2099-12-31           None
# 1             None       109876       1993-01-01     2099-12-31           None
# 2             None       109875       1993-01-01     2099-12-31           None
# 3             None       109870       1993-01-01     2099-12-31           None
# 4             None       109872       1993-01-01     2099-12-31           None

# %%
omop_dicom_test.groupby('concept_class_id')['concept_id'].agg(['count', 'min', 'max']) #2128000010-2128002992, 2128006000-2128021808
# Out:
#                   count         min         max
# concept_class_id
# DICOM Attributes   2983  2128000010  2128002992
# DICOM Value Sets   3809  2128006000  2128021808

# %%
sql_query = "SELECT * FROM dbo.concept"
concept_df = pd.read_sql_query(sql_query, conn)
concept_df.head()
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_43806/959860308.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   concept_df = pd.read_sql_query(sql_query, conn)
#    concept_id   concept_name  domain_id vocabulary_id concept_class_id  \
# 0    41886036         Kyogle  Geography           OSM       10th level
# 1    41886037       Kyvalley  Geography           OSM       10th level
# 2    41886038          Laang  Geography           OSM       10th level
# 3    41886039     Lake Bolac  Geography           OSM       10th level
# 4    41886040  Lake Brewster  Geography           OSM       10th level
#
#   standard_concept concept_code valid_start_date valid_end_date invalid_reason
# 0                S      6069960       1970-01-01     2099-12-31
# 1                S      2504902       1970-01-01     2099-12-31
# 2                S      3155973       1970-01-01     2099-12-31
# 3                S      3153764       1970-01-01     2099-12-31
# 4                S      5816798       1970-01-01     2099-12-31

# %%
# close the cursor and connection
cursor.close()
conn.close()

# %% [markdown]
# ## 3. Set Concept_relationship from Part 3

# %% [markdown]
# ### Attribute & Value Sets with CIDs: Attributes = concept_id_1, Value Sets = concept_id_2
# This relationship includes mapping to standard coding systems, such as SNOMED and LOINC.

# %%
part3_cid = part3[part3['CID']!=''].merge(attributes_included[['Tag_cleaned', 'concept_id']], how = 'inner', left_on = 'Tag', right_on = 'Tag_cleaned')
part3_cid['cid'] = pd.to_numeric(part3_cid['CID'], errors='coerce').astype('Int64')
part3_cid = part3_cid.rename(columns={'concept_id':'concept_id_1'})
part3_cid.head()
# Out:
#         xml_id                                     iod       IE  \
# 0  table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 1  table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 2  table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 3  table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 4  table_A.2-1  Computed Radiography Image IOD Modules    Study
#
#           Module     Reference Usage Usage_code Reference_adjusted  \
# 0        Patient  sect_C.7.1.1     M          M       sect_C.7.1.1
# 1        Patient  sect_C.7.1.1     M          M       sect_C.7.1.1
# 2        Patient  sect_C.7.1.1     M          M       sect_C.7.1.1
# 3        Patient  sect_C.7.1.1     M          M       sect_C.7.1.1
# 4  General Study  sect_C.7.2.1     M          M       sect_C.7.2.1
#
#                            Attribute Name       Tag Type  \
# 0              Ethnic Group Code Sequence  00102161    3
# 1           Patient Species Code Sequence  00102202   1C
# 2             Patient Breed Code Sequence  00102293   2C
# 3  De-identification Method Code Sequence  00120064   1C
# 4        Requesting Service Code Sequence  00321034    3
#
#   Attribute Description   CID              SOP Class UID Tag_cleaned  \
# 0                    {}  6099  1.2.840.10008.5.1.4.1.1.1    00102161
# 1                    {}  7454  1.2.840.10008.5.1.4.1.1.1    00102202
# 2                    {}  7480  1.2.840.10008.5.1.4.1.1.1    00102293
# 3                    {}  7050  1.2.840.10008.5.1.4.1.1.1    00120064
# 4                    {}  7030  1.2.840.10008.5.1.4.1.1.1    00321034
#
#    concept_id_1   cid
# 0    2128000118  6099
# 1    2128000122  7454
# 2    2128000125  7480
# 3    2128000132  7050
# 4    2128001481  7030

# %%
part3_cid_val = part3_cid[['iod', 'Module', 'Attribute Name', 'Tag', 'cid', 'concept_id_1']].merge(valuesets[['code', 'cid', 'system']], how = 'left', on = 'cid')
part3_cid_val = part3_cid_val.rename(columns={'code': 'concept_code'})
part3_cid_val.head()
# Out:
#                                       iod   Module  \
# 0  Computed Radiography Image IOD Modules  Patient
# 1  Computed Radiography Image IOD Modules  Patient
# 2  Computed Radiography Image IOD Modules  Patient
# 3  Computed Radiography Image IOD Modules  Patient
# 4  Computed Radiography Image IOD Modules  Patient
#
#                Attribute Name       Tag   cid  concept_id_1 concept_code  \
# 0  Ethnic Group Code Sequence  00102161  6099    2128000118       C41219
# 1  Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# 2  Ethnic Group Code Sequence  00102161  6099    2128000118    413581001
# 3  Ethnic Group Code Sequence  00102161  6099    2128000118    413773004
# 4  Ethnic Group Code Sequence  00102161  6099    2128000118    413600007
#
#                     system
# 0  http://ncit.nci.nih.gov
# 1   http://snomed.info/sct
# 2   http://snomed.info/sct
# 3   http://snomed.info/sct
# 4   http://snomed.info/sct

# %%
part3_cid_val.shape
# Out:
# (609019, 8)

# %%
part3_cid_val['system'].value_counts()
# Out:
# system
# http://snomed.info/sct                                                 590255
# http://dicom.nema.org/resources/ontology/DCM                            12195
# http://sig.biostr.washington.edu/projects/fm/AboutFM.html                2928
# http://www.nlm.nih.gov/research/umls                                     1170
# http://braininfo.rprc.washington.edu/aboutBrainInfo.aspx#NeuroNames       748
# doi:10.1016/S0735-1097(99)00126-6                                         544
# http://www.itis.gov                                                       513
# http://ncit.nci.nih.gov                                                   303
# http://www.radlex.org                                                      80
# http://unitsofmeasure.org                                                  61
# http://www.nlm.nih.gov/research/umls/rxnorm                                40
# http://loinc.org                                                           10
# Name: count, dtype: int64

# %%
mapping = {
    'http://snomed.info/sct': 'SNOMED',
    'http://dicom.nema.org/resources/ontology/DCM': 'DICOM',
    'http://unitsofmeasure.org': 'UCUM',
    'http://loinc.org': 'LOINC',
}

part3_cid_val['vocabulary_id'] = part3_cid_val['system'].map(mapping)
part3_cid_val.head()
# Out:
#                                       iod   Module  \
# 0  Computed Radiography Image IOD Modules  Patient
# 1  Computed Radiography Image IOD Modules  Patient
# 2  Computed Radiography Image IOD Modules  Patient
# 3  Computed Radiography Image IOD Modules  Patient
# 4  Computed Radiography Image IOD Modules  Patient
#
#                Attribute Name       Tag   cid  concept_id_1 concept_code  \
# 0  Ethnic Group Code Sequence  00102161  6099    2128000118       C41219
# 1  Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# 2  Ethnic Group Code Sequence  00102161  6099    2128000118    413581001
# 3  Ethnic Group Code Sequence  00102161  6099    2128000118    413773004
# 4  Ethnic Group Code Sequence  00102161  6099    2128000118    413600007
#
#                     system vocabulary_id
# 0  http://ncit.nci.nih.gov           NaN
# 1   http://snomed.info/sct        SNOMED
# 2   http://snomed.info/sct        SNOMED
# 3   http://snomed.info/sct        SNOMED
# 4   http://snomed.info/sct        SNOMED

# %%
part3_cid_val_concept = part3_cid_val.merge(concept_df[['concept_id', 'concept_name', 'concept_code', 'vocabulary_id']], how = 'left', on = ['concept_code', 'vocabulary_id'])
part3_cid_val_concept = part3_cid_val_concept.rename(columns={'concept_id': 'concept_id_2'})

# %%
part3_cid_val_concept.shape
# Out:
# (609019, 11)

# %%
part3_cid_val_concept.head()
# Out:
#                                       iod   Module  \
# 0  Computed Radiography Image IOD Modules  Patient
# 1  Computed Radiography Image IOD Modules  Patient
# 2  Computed Radiography Image IOD Modules  Patient
# 3  Computed Radiography Image IOD Modules  Patient
# 4  Computed Radiography Image IOD Modules  Patient
#
#                Attribute Name       Tag   cid  concept_id_1 concept_code  \
# 0  Ethnic Group Code Sequence  00102161  6099    2128000118       C41219
# 1  Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# 2  Ethnic Group Code Sequence  00102161  6099    2128000118    413581001
# 3  Ethnic Group Code Sequence  00102161  6099    2128000118    413773004
# 4  Ethnic Group Code Sequence  00102161  6099    2128000118    413600007
#
#                     system vocabulary_id  concept_id_2 concept_name
# 0  http://ncit.nci.nih.gov           NaN           NaN          NaN
# 1   http://snomed.info/sct        SNOMED           NaN          NaN
# 2   http://snomed.info/sct        SNOMED           NaN          NaN
# 3   http://snomed.info/sct        SNOMED           NaN          NaN
# 4   http://snomed.info/sct        SNOMED           NaN          NaN

# %%
part3_val_agg = part3_cid_val_concept.groupby(['concept_id_1', 'concept_code'])['concept_id_2'].nunique().reset_index()
print('No concept_id:', part3_val_agg[part3_val_agg['concept_id_2']==0].shape)
print('Exactly one concept_id:', part3_val_agg[part3_val_agg['concept_id_2']==1].shape)
print('Multiple concept_ids:', part3_val_agg[part3_val_agg['concept_id_2']>1].shape)
# Out:
# No concept_id: (737, 3)
# Exactly one concept_id: (6583, 3)
# Multiple concept_ids: (0, 3)

# %%
no_concept_ids = part3_val_agg[part3_val_agg['concept_id_2']==0]['concept_code'].unique()
part3_cid_val_concept[part3_cid_val_concept['concept_code'].isin(no_concept_ids)]
# Out:
#                                                       iod    Module  \
# 0                  Computed Radiography Image IOD Modules   Patient
# 1                  Computed Radiography Image IOD Modules   Patient
# 2                  Computed Radiography Image IOD Modules   Patient
# 3                  Computed Radiography Image IOD Modules   Patient
# 4                  Computed Radiography Image IOD Modules   Patient
# ...                                                   ...       ...
# 608913  Confocal Microscopy Tiled Pyramidal Image IOD ...  Specimen
# 608940  Confocal Microscopy Tiled Pyramidal Image IOD ...  Specimen
# 609004  Confocal Microscopy Tiled Pyramidal Image IOD ...  Specimen
# 609017  Confocal Microscopy Tiled Pyramidal Image IOD ...  Specimen
# 609018  Confocal Microscopy Tiled Pyramidal Image IOD ...  Specimen
#
#                        Attribute Name       Tag   cid  concept_id_1  \
# 0          Ethnic Group Code Sequence  00102161  6099    2128000118
# 1          Ethnic Group Code Sequence  00102161  6099    2128000118
# 2          Ethnic Group Code Sequence  00102161  6099    2128000118
# 3          Ethnic Group Code Sequence  00102161  6099    2128000118
# 4          Ethnic Group Code Sequence  00102161  6099    2128000118
# ...                               ...       ...   ...           ...
# 608913  Specimen Description Sequence  00400560  8134    2128001563
# 608940  Specimen Description Sequence  00400560  8134    2128001563
# 609004  Specimen Description Sequence  00400560  8134    2128001563
# 609017  Specimen Description Sequence  00400560  8134    2128001563
# 609018  Specimen Description Sequence  00400560  8134    2128001563
#
#        concept_code                                system vocabulary_id  \
# 0            C41219               http://ncit.nci.nih.gov           NaN
# 1         413490006                http://snomed.info/sct        SNOMED
# 2         413581001                http://snomed.info/sct        SNOMED
# 3         413773004                http://snomed.info/sct        SNOMED
# 4         413600007                http://snomed.info/sct        SNOMED
# ...             ...                                   ...           ...
# 608913    116010006                http://snomed.info/sct        SNOMED
# 608940   1231522001                http://snomed.info/sct        SNOMED
# 609004    244251006                http://snomed.info/sct        SNOMED
# 609017     C0221297  http://www.nlm.nih.gov/research/umls           NaN
# 609018     C3669027  http://www.nlm.nih.gov/research/umls           NaN
#
#         concept_id_2 concept_name
# 0                NaN          NaN
# 1                NaN          NaN
# 2                NaN          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# ...              ...          ...
# 608913           NaN          NaN
# 608940           NaN          NaN
# 609004           NaN          NaN
# 609017           NaN          NaN
# 609018           NaN          NaN
#
# [22471 rows x 11 columns]

# %%
part3_cid_val_concept[part3_cid_val_concept['concept_code']=="413490006"]
# Out:
#                                                       iod   Module  \
# 1                  Computed Radiography Image IOD Modules  Patient
# 4447                                 CT Image IOD Modules  Patient
# 8910                                 MR Image IOD Modules  Patient
# 13356                  Nuclear Medicine Image IOD Modules  Patient
# 17757                        Ultrasound Image IOD Modules  Patient
# ...                                                   ...      ...
# 588520  RT Patient Position Acquisition Instruction IO...  Patient
# 591498     Microscopy Bulk Simple Annotations IOD Modules  Patient
# 595892                    Photoacoustic Image IOD Modules  Patient
# 600336              Confocal Microscopy Image IOD Modules  Patient
# 604678  Confocal Microscopy Tiled Pyramidal Image IOD ...  Patient
#
#                     Attribute Name       Tag   cid  concept_id_1 concept_code  \
# 1       Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# 4447    Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# 8910    Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# 13356   Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# 17757   Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# ...                            ...       ...   ...           ...          ...
# 588520  Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# 591498  Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# 595892  Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# 600336  Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
# 604678  Ethnic Group Code Sequence  00102161  6099    2128000118    413490006
#
#                         system vocabulary_id  concept_id_2 concept_name
# 1       http://snomed.info/sct        SNOMED           NaN          NaN
# 4447    http://snomed.info/sct        SNOMED           NaN          NaN
# 8910    http://snomed.info/sct        SNOMED           NaN          NaN
# 13356   http://snomed.info/sct        SNOMED           NaN          NaN
# 17757   http://snomed.info/sct        SNOMED           NaN          NaN
# ...                        ...           ...           ...          ...
# 588520  http://snomed.info/sct        SNOMED           NaN          NaN
# 591498  http://snomed.info/sct        SNOMED           NaN          NaN
# 595892  http://snomed.info/sct        SNOMED           NaN          NaN
# 600336  http://snomed.info/sct        SNOMED           NaN          NaN
# 604678  http://snomed.info/sct        SNOMED           NaN          NaN
#
# [171 rows x 11 columns]

# %%
concept_df[concept_df['concept_code']=="413490006"]
# Out:
# Empty DataFrame
# Columns: [concept_id, concept_name, domain_id, vocabulary_id, concept_class_id, standard_concept, concept_code, valid_start_date, valid_end_date, invalid_reason]
# Index: []

# %%
omop_table_staging[omop_table_staging['concept_code']=="00180082"]
# Out:
#      concept_id    concept_name    domain_id vocabulary_id  concept_class_id  \
# 437  2128000447  Inversion Time  Measurement         DICOM  DICOM Attributes
#
#     standard_concept concept_code  valid_start_date  valid_end_date  \
# 437                      00180082          19930101        20991231
#
#     invalid_reason
# 437            NaN

# %%
concept_df[concept_df['concept_name']=="Inversion Time"]
# Out:
# Empty DataFrame
# Columns: [concept_id, concept_name, domain_id, vocabulary_id, concept_class_id, standard_concept, concept_code, valid_start_date, valid_end_date, invalid_reason]
# Index: []

# %%
concept_df[concept_df['concept_id']==2128000447]
# Out:
# Empty DataFrame
# Columns: [concept_id, concept_name, domain_id, vocabulary_id, concept_class_id, standard_concept, concept_code, valid_start_date, valid_end_date, invalid_reason]
# Index: []

# %% [markdown]
# # DICOM to OMOP: create custom vocabularies
#
# We will be creating custom vocabularies for DICOM attributes and Value Sets (DICOM terminology, Enumerated Values, Defined Terms).
# 1. Restructure the data: DICOM harvest to OMOP structure
# 2. DML Scripts using Python & SQL
#    1. Update `VOCABULARY` table
#    2. Update `CONCEPT_CLASS` table
#    3. Update `CONCEPT` table
#
# Links to OMOP CDM
# - [Create a custom vocabulary](https://forums.ohdsi.org/t/how-to-add-a-custom-vocabulary-to-the-omop-vocabulary-table/12440/3)
# - [OMOP CDM v.5.4 VOCABULARY](https://ohdsi.github.io/CommonDataModel/cdm54.html#vocabulary)
# - [OMOP CDM v.5.4 CONCEPT_CLASS](https://ohdsi.github.io/CommonDataModel/cdm54.html#concept_class)
# - [OMOP CDM v.5.4 CONCEPT](https://ohdsi.github.io/CommonDataModel/cdm54.html#concept)
#
# Links to DICOM Standards
# - [Value Representation (VR)](https://dicom.nema.org/medical/dicom/current/output/chtml/part05/sect_6.2.html)

# %% [markdown]
# ## 1. Restructure data: DICOM harvest to OMOP Structure
#
# <blockquote>
# <strong>This is for your reference, you can skip this section and use the flat files in the `files` directory in this repository. The instruction to update your OMOP database is at the end of this notebook.</strong>
# </blockquote>

# %%
import pandas as pd

attributes = pd.read_csv("./files/part6_attributes.csv")
valuesets = pd.read_csv("./files/part16_fhir_valuesets.csv")

# %%
# DICOM attributes
# concept_id: 2128000000 + sequential number in range of 10-5999
# concept_name: 'Name'
# domain_id: Candidates - 'Measurement', 'Meas Value', 'Meas/Procedure', 'Type Concept'
# vocabulary_id: 'DICOM'
# concept_class_id: 'DICOM Attributes'
# standard_concept: NULL
# concept_code: Tag
# valid_start_date: 19930101
# valid_end_date: 20991231
# invalid_reason: NULL

# %%
included_VR = ['AT', 'CS', 'DA', 'DT', 'DS', 'FL', 'FD', 'IS', 'SL', 'SS', 'SV', 'TM', 'UL', 'US', 'UV']
attributes_included = attributes[attributes['VR'].isin(included_VR)]
attributes_included #2824
# Out:
#               Tag                                        Name  \
# 0     (0008,0001)                               Length to End
# 1     (0008,0005)                      Specific Character Set
# 3     (0008,0008)                                  Image Type
# 5     (0008,0012)                      Instance Creation Date
# 6     (0008,0013)                      Instance Creation Time
# ...           ...                                         ...
# 5051  (60xx,1301)                                    ROI Area
# 5052  (60xx,1302)                                    ROI Mean
# 5053  (60xx,1303)                      ROI Standard Deviation
# 5059  (7FE0,0003)  Encapsulated Pixel Data Value Total Length
# 5067  (7Fxx,0011)                    Variable Next Data Group
#
#                                          Keyword  VR   VM
# 0                                  Length​To​End  UL    1
# 1                         Specific​Character​Set  CS  1-n
# 3                                     Image​Type  CS  2-n
# 5                         Instance​Creation​Date  DA    1
# 6                         Instance​Creation​Time  TM    1
# ...                                          ...  ..  ...
# 5051                                    ROI​Area  IS    1
# 5052                                    ROI​Mean  DS    1
# 5053                      ROI​Standard​Deviation  DS    1
# 5059  Encapsulated​Pixel​Data​Value​Total​Length  UV    1
# 5067                    Variable​Next​Data​Group  US    1
#
# [2824 rows x 5 columns]

# %%
import numpy as np
import pandas as pd

sequential_numbers = range(10, len(attributes_included)+10)
attributes_included.loc[:, 'concept_id'] = [2128000000 + num for num in sequential_numbers]

columns = ['concept_id', 'concept_name', 'domain_id', 'vocabulary_id', 'concept_class_id', 'standard_concept', 'concept_code', 'valid_start_date', 'valid_end_date','invalid_reason']
attribute_table_omop = pd.DataFrame(columns = columns)

attribute_table_omop['concept_id'] = attributes_included['concept_id']
attribute_table_omop['concept_name'] = attributes_included['Name']
attribute_table_omop['domain_id'] = 'Measurement'
attribute_table_omop['vocabulary_id'] = 'DICOM'
attribute_table_omop['concept_class_id'] = 'DICOM Attributes'
attribute_table_omop['concept_code'] = attributes_included['Tag']
attribute_table_omop['valid_start_date'] = 19930101
attribute_table_omop['valid_end_date'] = 20991231

attribute_table_omop = attribute_table_omop.reset_index(drop='True')
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_3493/2650751791.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attributes_included.loc[:, 'concept_id'] = [2128000000 + num for num in sequential_numbers]

# %%
attribute_table_omop
# Out:
#       concept_id                                concept_name    domain_id  \
# 0     2128000010                               Length to End  Measurement
# 1     2128000011                      Specific Character Set  Measurement
# 2     2128000012                                  Image Type  Measurement
# 3     2128000013                      Instance Creation Date  Measurement
# 4     2128000014                      Instance Creation Time  Measurement
# ...          ...                                         ...          ...
# 2819  2128002829                                    ROI Area  Measurement
# 2820  2128002830                                    ROI Mean  Measurement
# 2821  2128002831                      ROI Standard Deviation  Measurement
# 2822  2128002832  Encapsulated Pixel Data Value Total Length  Measurement
# 2823  2128002833                    Variable Next Data Group  Measurement
#
#      vocabulary_id  concept_class_id standard_concept concept_code  \
# 0            DICOM  DICOM Attributes              NaN  (0008,0001)
# 1            DICOM  DICOM Attributes              NaN  (0008,0005)
# 2            DICOM  DICOM Attributes              NaN  (0008,0008)
# 3            DICOM  DICOM Attributes              NaN  (0008,0012)
# 4            DICOM  DICOM Attributes              NaN  (0008,0013)
# ...            ...               ...              ...          ...
# 2819         DICOM  DICOM Attributes              NaN  (60xx,1301)
# 2820         DICOM  DICOM Attributes              NaN  (60xx,1302)
# 2821         DICOM  DICOM Attributes              NaN  (60xx,1303)
# 2822         DICOM  DICOM Attributes              NaN  (7FE0,0003)
# 2823         DICOM  DICOM Attributes              NaN  (7Fxx,0011)
#
#       valid_start_date  valid_end_date invalid_reason
# 0             19930101        20991231            NaN
# 1             19930101        20991231            NaN
# 2             19930101        20991231            NaN
# 3             19930101        20991231            NaN
# 4             19930101        20991231            NaN
# ...                ...             ...            ...
# 2819          19930101        20991231            NaN
# 2820          19930101        20991231            NaN
# 2821          19930101        20991231            NaN
# 2822          19930101        20991231            NaN
# 2823          19930101        20991231            NaN
#
# [2824 rows x 10 columns]

# %%
# DICOM Value Sets
# concept_id: 2128000000 + sequential number in range of 6000-999999
# concept_name: display
# domain_id: Candidates - 'Measurement', 'Meas Value', 'Meas/Procedure', 'Type Concept', 'Condition', 'Observation'
# vocabulary_id: 'DICOM'
# concept_class_id: 'DICOM Value Sets'
# standard_concept: NULL
# concept_code: code
# valid_start_date: 19930101
# valid_end_date: 20991231
# invalid_reason: NULL

# %%
valuesets_dicom = valuesets[valuesets['system']=='http://dicom.nema.org/resources/ontology/DCM']
valuesets_dicom #5223
# Out:
#          code                                 display  \
# 31     110504                            Patient died
# 32     110515  Patient condition prevented continuing
# 33     110503      Patient allergic to media/contrast
# 34     110514       Incorrect worklist entry selected
# 35     110502             Incorrect procedure ordered
# ...       ...                                     ...
# 26820  128129          Plane through Posterior Extent
# 26821  128128           Plane through Anterior Extent
# 26822  128130                    Plane through Center
# 26823  128121           Plane through Inferior Extent
# 26824  128120           Plane through Superior Extent
#
#                                              system  \
# 31     http://dicom.nema.org/resources/ontology/DCM
# 32     http://dicom.nema.org/resources/ontology/DCM
# 33     http://dicom.nema.org/resources/ontology/DCM
# 34     http://dicom.nema.org/resources/ontology/DCM
# 35     http://dicom.nema.org/resources/ontology/DCM
# ...                                             ...
# 26820  http://dicom.nema.org/resources/ontology/DCM
# 26821  http://dicom.nema.org/resources/ontology/DCM
# 26822  http://dicom.nema.org/resources/ontology/DCM
# 26823  http://dicom.nema.org/resources/ontology/DCM
# 26824  http://dicom.nema.org/resources/ontology/DCM
#
#                                                     id   version  status  \
# 31     dicom-cid-9301-ModalityPPSDiscontinuationReason  20140419  active
# 32     dicom-cid-9301-ModalityPPSDiscontinuationReason  20140419  active
# 33     dicom-cid-9301-ModalityPPSDiscontinuationReason  20140419  active
# 34     dicom-cid-9301-ModalityPPSDiscontinuationReason  20140419  active
# 35     dicom-cid-9301-ModalityPPSDiscontinuationReason  20140419  active
# ...                                                ...       ...     ...
# 26820            dicom-cid-1010-ReferenceGeometryPlane  20160905  active
# 26821            dicom-cid-1010-ReferenceGeometryPlane  20160905  active
# 26822            dicom-cid-1010-ReferenceGeometryPlane  20160905  active
# 26823            dicom-cid-1010-ReferenceGeometryPlane  20160905  active
# 26824            dicom-cid-1010-ReferenceGeometryPlane  20160905  active
#
#                                              description
# 31     Transitive closure of CID 9301 ModalityPPSDisc...
# 32     Transitive closure of CID 9301 ModalityPPSDisc...
# 33     Transitive closure of CID 9301 ModalityPPSDisc...
# 34     Transitive closure of CID 9301 ModalityPPSDisc...
# 35     Transitive closure of CID 9301 ModalityPPSDisc...
# ...                                                  ...
# 26820  Transitive closure of CID 1010 ReferenceGeomet...
# 26821  Transitive closure of CID 1010 ReferenceGeomet...
# 26822  Transitive closure of CID 1010 ReferenceGeomet...
# 26823  Transitive closure of CID 1010 ReferenceGeomet...
# 26824  Transitive closure of CID 1010 ReferenceGeomet...
#
# [5223 rows x 7 columns]

# %%
import numpy as np
import pandas as pd

sequential_numbers = range(6000, len(valuesets_dicom)+6000)
valuesets_dicom.loc[:, 'concept_id'] = [2128000000 + num for num in sequential_numbers]

columns = ['concept_id', 'concept_name', 'domain_id', 'vocabulary_id', 'concept_class_id', 'standard_concept', 'concept_code', 'valid_start_date', 'valid_end_date','invalid_reason']
valuesets_table_omop = pd.DataFrame(columns = columns)

valuesets_table_omop['concept_id'] = valuesets_dicom['concept_id']
valuesets_table_omop['concept_name'] = valuesets_dicom['display']
valuesets_table_omop['domain_id'] = 'Measurement'
valuesets_table_omop['vocabulary_id'] = 'DICOM'
valuesets_table_omop['concept_class_id'] = 'DICOM Value Sets'
valuesets_table_omop['concept_code'] = valuesets_dicom['code']
valuesets_table_omop['valid_start_date'] = 19930101
valuesets_table_omop['valid_end_date'] = 20991231

valuesets_table_omop = valuesets_table_omop.reset_index(drop='True')
# Out:
# /var/folders/wh/p78ddrtn39j879rx8h8fs8fr0000gn/T/ipykernel_3493/1665095070.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valuesets_dicom.loc[:, 'concept_id'] = [2128000000 + num for num in sequential_numbers]

# %%
valuesets_table_omop
# Out:
#       concept_id                            concept_name    domain_id  \
# 0     2128006000                            Patient died  Measurement
# 1     2128006001  Patient condition prevented continuing  Measurement
# 2     2128006002      Patient allergic to media/contrast  Measurement
# 3     2128006003       Incorrect worklist entry selected  Measurement
# 4     2128006004             Incorrect procedure ordered  Measurement
# ...          ...                                     ...          ...
# 5218  2128011218          Plane through Posterior Extent  Measurement
# 5219  2128011219           Plane through Anterior Extent  Measurement
# 5220  2128011220                    Plane through Center  Measurement
# 5221  2128011221           Plane through Inferior Extent  Measurement
# 5222  2128011222           Plane through Superior Extent  Measurement
#
#      vocabulary_id  concept_class_id standard_concept concept_code  \
# 0            DICOM  DICOM Value Sets              NaN       110504
# 1            DICOM  DICOM Value Sets              NaN       110515
# 2            DICOM  DICOM Value Sets              NaN       110503
# 3            DICOM  DICOM Value Sets              NaN       110514
# 4            DICOM  DICOM Value Sets              NaN       110502
# ...            ...               ...              ...          ...
# 5218         DICOM  DICOM Value Sets              NaN       128129
# 5219         DICOM  DICOM Value Sets              NaN       128128
# 5220         DICOM  DICOM Value Sets              NaN       128130
# 5221         DICOM  DICOM Value Sets              NaN       128121
# 5222         DICOM  DICOM Value Sets              NaN       128120
#
#       valid_start_date  valid_end_date invalid_reason
# 0             19930101        20991231            NaN
# 1             19930101        20991231            NaN
# 2             19930101        20991231            NaN
# 3             19930101        20991231            NaN
# 4             19930101        20991231            NaN
# ...                ...             ...            ...
# 5218          19930101        20991231            NaN
# 5219          19930101        20991231            NaN
# 5220          19930101        20991231            NaN
# 5221          19930101        20991231            NaN
# 5222          19930101        20991231            NaN
#
# [5223 rows x 10 columns]

# %%
omop_table_staging = pd.concat([attribute_table_omop, valuesets_table_omop], ignore_index=True)
omop_table_staging.to_csv('./files/omop_table_staging.csv', index=False)
omop_table_staging
# Out:
#       concept_id                    concept_name    domain_id vocabulary_id  \
# 0     2128000010                   Length to End  Measurement         DICOM
# 1     2128000011          Specific Character Set  Measurement         DICOM
# 2     2128000012                      Image Type  Measurement         DICOM
# 3     2128000013          Instance Creation Date  Measurement         DICOM
# 4     2128000014          Instance Creation Time  Measurement         DICOM
# ...          ...                             ...          ...           ...
# 8042  2128011218  Plane through Posterior Extent  Measurement         DICOM
# 8043  2128011219   Plane through Anterior Extent  Measurement         DICOM
# 8044  2128011220            Plane through Center  Measurement         DICOM
# 8045  2128011221   Plane through Inferior Extent  Measurement         DICOM
# 8046  2128011222   Plane through Superior Extent  Measurement         DICOM
#
#       concept_class_id standard_concept concept_code  valid_start_date  \
# 0     DICOM Attributes              NaN  (0008,0001)          19930101
# 1     DICOM Attributes              NaN  (0008,0005)          19930101
# 2     DICOM Attributes              NaN  (0008,0008)          19930101
# 3     DICOM Attributes              NaN  (0008,0012)          19930101
# 4     DICOM Attributes              NaN  (0008,0013)          19930101
# ...                ...              ...          ...               ...
# 8042  DICOM Value Sets              NaN       128129          19930101
# 8043  DICOM Value Sets              NaN       128128          19930101
# 8044  DICOM Value Sets              NaN       128130          19930101
# 8045  DICOM Value Sets              NaN       128121          19930101
# 8046  DICOM Value Sets              NaN       128120          19930101
#
#       valid_end_date invalid_reason
# 0           20991231            NaN
# 1           20991231            NaN
# 2           20991231            NaN
# 3           20991231            NaN
# 4           20991231            NaN
# ...              ...            ...
# 8042        20991231            NaN
# 8043        20991231            NaN
# 8044        20991231            NaN
# 8045        20991231            NaN
# 8046        20991231            NaN
#
# [8047 rows x 10 columns]

# %% [markdown]
# ## 2. DML Scripts using Python & SQL

# %%
import pyodbc

# Connect to your database
server = 'server_name'
database = 'database_name'
# here, we use a trusted connection (i.e., using Windows account), you can also use user_name and password by replacing it with ';UID=<user_name>;PWD=<password>;Encrypt=no'
conn = pyodbc.connect('Driver={SQL Server};Server=' + server + ';Database=' + database + ';Trusted_Connection=yes;')
cursor = conn.cursor()

# Update VOCABULARY
sql = '''
    INSERT INTO dbo.VOCABULARY (vocabulary_id, vocabulary_name, vocabulary_reference, vocabulary_version, vocabulary_concept_id)
    VALUES ('DICOM', 'Digital Imaging and Communications in Medicine (National Electrical Manufacturers Association)',  'https://www.dicomstandard.org/current', 'NEMA Standard PS3', 2128000000)
    '''
cursor.execute(sql)
conn.commit()

# %%
# Update CONCEPT_CLASS
sql = '''
    INSERT INTO CONCEPT_CLASS (concept_class_id, concept_class_name, concept_class_concept_id)
    VALUES ('DICOM Attributes', 'DICOM Attributes', 2128000001),
           ('DICOM Value Sets', 'DICOM Value Sets', 2128000002)
    '''
cursor.execute(sql)
conn.commit()

# %%
# Load the file for DICOM attributes and value sets
omop_table_staging = pd.read_csv('./files/omop_table_staging.csv')

# Update CONCEPT
sql = '''
    INSERT INTO dbo.concept (concept_id,concept_name,domain_id,vocabulary_id,concept_class_id,standard_concept,concept_code,valid_start_date,valid_end_date,invalid_reason) 
    VALUES (?,?,?,?,?,?,?,?,?,?)
    '''
for index, row in omop_table_staging.iterrows():
    cursor.execute(sql, row['concept_id'], row['concept_name'], row['domain_id'], row['vocabulary_id'], 
                   row['concept_class_id'], row['standard_concept'], row['concept_code'], row['valid_start_date'], row['valid_end_date'],row['invalid_reason'])

conn.commit()

# %%
# close the cursor and connection
cursor.close()
conn.close()

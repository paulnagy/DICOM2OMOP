# %% [markdown]
# We can use the provided stylesheets under ./support/stylesheets as interpreters to extract the source data xml files.

# %%
import pandas as pd
from lxml import etree
import os

def xslt_transform_to_csv(xslt_path, xml_path, csv_path):
  # Load the XSLT stylesheet
  with open(xslt_path, 'r') as f:
      xsl = etree.parse(f)

  # Load the XML document
  with open(xml_path, 'r') as f:
      xml = etree.parse(f)

  # Create an XSLT transformer
  transform = etree.XSLT(xsl)

  # Apply the transformation
  result = transform(xml)

  # Write the result to a file
  with open('temp.xml', 'wb') as f:
      f.write(etree.tostring(result))

  # Read the XML data into a DataFrame
  df = pd.read_xml('temp.xml')

  # Write the DataFrame to a CSV file
  df.to_csv(csv_path, index=False)

  # Delete the temporary XML file
  if os.path.exists('temp.xml'):
      os.remove('temp.xml')
  else:
      print("The file does not exist")

path_to_xslt_stylesheet = './sourceandrenderingpipeline/support/stylesheets/extractcontextgroupsforpixelmed.xsl'
path_to_xml_document = './sourceandrenderingpipeline/source/docbook/part16/part16.xml'
path_to_output_csv = './data/P16_extract_context_groups.csv'

xslt_transform_to_csv(path_to_xslt_stylesheet, path_to_xml_document, path_to_output_csv)

# %%
# Load the CSV data into a DataFrame
df = pd.read_csv('./data/P16_extract_context_groups.csv')

# Display the first few rows of the DataFrame
df
# Out:
#         cid                            name extensible   version  \
# 0         2                AnatomicModifier          T  20190118
# 1         4                  AnatomicRegion          T  20220922
# 2         5              TransducerApproach          T  20220628
# 3         6           TransducerOrientation          T  20190817
# 4         7              UltrasoundBeamPath          T  20191108
# ...     ...                             ...        ...       ...
# 1336  12307        CardiacPhaseandTimePoint          T  20211112
# 1337  12308  UltrasoundShearWaveMeasurement          T  20190817
# 1338  12309       CoreEchoStrainMeasurement          F  20211112
# 1339  12310          MyocardialStrainMethod          T  20211112
# 1340  12311      EchoMeasuredStrainProperty          F  20211112
#
#                          uid                         keyword  \
# 0        1.2.840.10008.6.1.1                AnatomicModifier
# 1        1.2.840.10008.6.1.2                  AnatomicRegion
# 2        1.2.840.10008.6.1.3              TransducerApproach
# 3        1.2.840.10008.6.1.4           TransducerOrientation
# 4        1.2.840.10008.6.1.5              UltrasoundBeamPath
# ...                      ...                             ...
# 1336  1.2.840.10008.6.1.1148        CardiacPhaseAndTimePoint
# 1337  1.2.840.10008.6.1.1411  UltrasoundShearWaveMeasurement
# 1338  1.2.840.10008.6.1.1426       CoreEchoStrainMeasurement
# 1339  1.2.840.10008.6.1.1427          MyocardialStrainMethod
# 1340  1.2.840.10008.6.1.1428      EchoMeasuredStrainProperty
#
#                                          fhirkeyword  contextgroupcode  \
# 0                       dicom-cid-2-AnatomicModifier               NaN
# 1                         dicom-cid-4-AnatomicRegion               NaN
# 2                     dicom-cid-5-TransducerApproach               NaN
# 3                  dicom-cid-6-TransducerOrientation               NaN
# 4                     dicom-cid-7-UltrasoundBeamPath               NaN
# ...                                              ...               ...
# 1336        dicom-cid-12307-CardiacPhaseAndTimePoint               NaN
# 1337  dicom-cid-12308-UltrasoundShearWaveMeasurement               NaN
# 1338       dicom-cid-12309-CoreEchoStrainMeasurement               NaN
# 1339          dicom-cid-12310-MyocardialStrainMethod               NaN
# 1340      dicom-cid-12311-EchoMeasuredStrainProperty               NaN
#
#       include
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 1336      NaN
# 1337      NaN
# 1338      NaN
# 1339      NaN
# 1340      NaN
#
# [1341 rows x 9 columns]

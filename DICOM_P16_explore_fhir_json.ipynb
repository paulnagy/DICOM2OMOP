# %%
import pandas as pd

parquet_file_path = './fhir_valuesets.parquet'

df = pd.read_parquet(parquet_file_path)

df
# Out:
#             code          display  \
# 0        11962-8  Clavicle length
# 1        11963-6     Femur Length
# 2        11964-4    Fibula length
# 3        11966-9   Humerus length
# 4        11967-7    Radius length
# ...          ...              ...
# 26807     112149           Fluffy
# 26808     112300            AP+45
# 26809     112301            AP-45
# 26810     130123   Aperture Block
# 26811  228739009  Shielding Block
#
#                                              system  \
# 0                                  http://loinc.org
# 1                                  http://loinc.org
# 2                                  http://loinc.org
# 3                                  http://loinc.org
# 4                                  http://loinc.org
# ...                                             ...
# 26807  http://dicom.nema.org/resources/ontology/DCM
# 26808  http://dicom.nema.org/resources/ontology/DCM
# 26809  http://dicom.nema.org/resources/ontology/DCM
# ...

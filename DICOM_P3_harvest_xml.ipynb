# %% [markdown]
# ## DICOM Standard harvesting of Part 3
# ### Extract relationships between tags and CIDs
#
# [Useful Online XML Viewer](https://jsonformatter.org/xml-viewer)
#
# Links to the XML Objects
# - [DICOM Part 3](https://dicom.nema.org/medical/dicom/current/source/docbook/part03/part03.xml)
# - [DICOM Part 6](https://dicom.nema.org/medical/dicom/current/source/docbook/part06/part06.xml)
# - [DICOM Part 16](https://dicom.nema.org/medical/dicom/current/source/docbook/part16/part16.xml)

# %% [markdown]
# ### Extract one IOD Module Table: A.36 Enhanced MR

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# Fetch XML content from the URL
url = 'https://dicom.nema.org/medical/dicom/current/source/docbook/part03/part03.xml'
response = requests.get(url)
xml_content = response.content

# Parse the XML content
soup = BeautifulSoup(xml_content, 'xml')

# Find the table with label 'A.36-1'
table = soup.find('table', {'label': 'A.36-1'})

# Find the section containing the table and extract its title
section_title = soup.find('section', {'xml:id': table.parent['xml:id']}).find('title').text.strip()

# Extract the part of the title before "IOD"
iod_index = section_title.find(" IOD")
iod = section_title[:iod_index]

# Extract table headers
headers = [th.text.strip() for th in table.find_all('th')]

# Extract table rows
rows = []
current_ie = None
for tr in table.find_all('tr')[1:]:  # Skip the header row
    cells = tr.find_all(['td', 'th'])

    # Extract cell values
    cell_values = [cell.text.strip() for cell in cells]

    # Check if the cell values are complete (some cells may be missing due to rowspan)
    if len(cell_values) < len(headers):
        # Fill in the missing values based on the previous row
        for i in range(len(headers) - len(cell_values)):
            cell_values.insert(0, current_ie)

    # Store the IE value for the next iteration
    current_ie = cell_values[0]

    # Extract the reference value if available
    reference = None
    for cell in cells:
        xref = cell.find('xref', {'xrefstyle': 'select: labelnumber'})
        if xref:
            reference = xref['linkend']
            break

    # Insert the reference value into the correct position
    if reference:
        # Find the index of the cell containing the reference
        reference_index = next((idx for idx, val in enumerate(cell_values) if val == ''), None)
        if reference_index is not None:
            cell_values[reference_index] = reference

    # Insert the title of the table as the first element
    cell_values.insert(0, iod)

    rows.append(cell_values)

# Create a DataFrame
df = pd.DataFrame(rows, columns=['IOD'] + headers)

# %%
df
# Out:
#                   IOD                  IE  \
# 0   Enhanced MR Image             Patient
# 1   Enhanced MR Image             Patient
# 2   Enhanced MR Image               Study
# 3   Enhanced MR Image               Study
# 4   Enhanced MR Image               Study
# 5   Enhanced MR Image              Series
# 6   Enhanced MR Image              Series
# 7   Enhanced MR Image              Series
# 8   Enhanced MR Image  Frame of Reference
# 9   Enhanced MR Image  Frame of Reference
# 10  Enhanced MR Image           Equipment
# 11  Enhanced MR Image           Equipment
# 12  Enhanced MR Image               Image
# 13  Enhanced MR Image               Image
# 14  Enhanced MR Image               Image
# 15  Enhanced MR Image               Image
# 16  Enhanced MR Image               Image
# 17  Enhanced MR Image               Image
# 18  Enhanced MR Image               Image
# 19  Enhanced MR Image               Image
# 20  Enhanced MR Image               Image
# 21  Enhanced MR Image               Image
# 22  Enhanced MR Image               Image
# 23  Enhanced MR Image               Image
# 24  Enhanced MR Image               Image
# 25  Enhanced MR Image               Image
# 26  Enhanced MR Image               Image
# 27  Enhanced MR Image               Image
# 28  Enhanced MR Image               Image
#
#                                      Module        Reference  \
# 0                                   Patient     sect_C.7.1.1
# 1                    Clinical Trial Subject     sect_C.7.1.3
# 2                             General Study     sect_C.7.2.1
# 3                             Patient Study     sect_C.7.2.2
# 4                      Clinical Trial Study     sect_C.7.2.3
# 5                            General Series     sect_C.7.3.1
# 6                     Clinical Trial Series     sect_C.7.3.2
# 7                                 MR Series    sect_C.8.13.6
# 8                        Frame of Reference     sect_C.7.4.1
# 9                           Synchronization     sect_C.7.4.2
# 10                        General Equipment     sect_C.7.5.1
# 11               Enhanced General Equipment     sect_C.7.5.2
# 12                              Image Pixel     sect_C.7.6.3
# 13                  Enhanced Contrast/Bolus    sect_C.7.6.4b
# 14            Multi-frame Functional Groups    sect_C.7.6.16
# 15                    Multi-frame Dimension    sect_C.7.6.17
# 16                  Cardiac Synchronization  sect_C.7.6.18.1
# 17              Respiratory Synchronization  sect_C.7.6.18.2
# 18              Bulk Motion Synchronization  sect_C.7.6.18.3
# 19  Supplemental Palette Color Lookup Table    sect_C.7.6.19
# 20                      Acquisition Context    sect_C.7.6.14
# 21                                   Device    sect_C.7.6.12
# 22                                 Specimen    sect_C.7.6.22
# 23                        Enhanced MR Image    sect_C.8.13.1
# 24                        MR Pulse Sequence    sect_C.8.13.4
# 25                              ICC Profile     sect_C.11.15
# 26                               SOP Common      sect_C.12.1
# 27                Common Instance Reference      sect_C.12.2
# 28                         Frame Extraction      sect_C.12.3
#
#                                                 Usage
# 0                                                   M
# 1                                                   U
# 2                                                   M
# 3                                                   U
# 4                                                   U
# 5                                                   M
# 6                                                   U
# 7                                                   M
# 8                                                   M
# 9   C - Required if time synchronization was applied.
# 10                                                  M
# 11                                                  M
# 12                                                  M
# 13       C - Required if contrast media were applied.
# 14                                                  M
# 15                                                  M
# 16  C - Required if cardiac synchronization was ap...
# 17  C - Required if respiratory synchronization wa...
# 18  C - Required if bulk motion synchronization wa...
# 19  C - Required if Pixel Presentation (0008,9205)...
# 20                                                  M
# 21                                                  U
# 22                                                  U
# 23                                                  M
# 24  C - Required if Image Type (0008,0008) Value 1...
# 25                                                  U
# 26                                                  M
# 27                                                  U
# 28  C - Required if the SOP Instance was created i...

# %% [markdown]
# ### Extract Module Tables from all IODs

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re

def extract_module_table_data(section):
    # Search for the "Module Table" within subsections
    for sub_section in section.find_all('section', recursive=True):
        module_table = sub_section.find('table', {'caption': re.compile('IOD Modules')})
        if module_table:
            # Extract data from the "Module Table"
            table_data = []
            current_ie = None
            for tr in module_table.find_all('tr')[1:]:  # Skip the header row
                cells = tr.find_all(['td', 'th'])

                # Extract cell values
                cell_values = [cell.text.strip() for cell in cells]

                # Check if the cell values are complete (some cells may be missing due to rowspan)
                if len(cell_values) < 4:
                    # Fill in the missing values based on the previous row
                    for i in range(4 - len(cell_values)):
                        cell_values.insert(0, current_ie)

                # Store the IE value for the next iteration
                current_ie = cell_values[0]

                # Extract the reference value if available
                reference = None
                for cell in cells:
                    xref = cell.find('xref', {'xrefstyle': 'select: labelnumber'})
                    if xref:
                        reference = xref['linkend']
                        break

                # Insert the reference value into the correct position
                if reference:
                    # Find the index of the cell containing the reference
                    reference_index = next((idx for idx, val in enumerate(cell_values) if val == ''), None)
                    if reference_index is not None:
                        cell_values[reference_index] = reference

                table_data.append(cell_values)

            return table_data

    return None

# %%
# Fetch XML content from the URL
url = 'https://dicom.nema.org/medical/dicom/current/source/docbook/part03/part03.xml'
response = requests.get(url)
xml_content = response.content

# Parse the XML content
soup = BeautifulSoup(xml_content, 'xml')

# List to store rows of data
rows = []

# Iterate over sections in the range A.2 to A.90
for section_label in range(2, 91):
    section_id = f"sect_A.{section_label}"
    section = soup.find('section', {'xml:id': section_id})
    if section:
        # Extract data from the "Module Table" section
        module_table_data = extract_module_table_data(section)
        if module_table_data:
            # Append the extracted data to the rows list
            rows.extend([[section.find('title').text.strip()] + row for row in module_table_data])

# %%
# Create a DataFrame from the list of rows
df = pd.DataFrame(rows, columns=['IOD', 'IE', 'Module', 'Reference', 'Usage'])

# Print the DataFrame
print(df)
# Out:
# []

# %% [markdown]
# ### Extract Section C

# %%
# Fetch XML content from the URL
url = 'https://dicom.nema.org/medical/dicom/current/source/docbook/part03/part03.xml'
response = requests.get(url)
xml_content = response.content

# Parse the XML content
soup = BeautifulSoup(xml_content, 'xml')

# %%
import pandas as pd
from bs4 import BeautifulSoup
import re

# Find the table
table = soup.find('table', {'xml:id': 'table_C.7-1'})

# Initialize lists to store extracted data
attribute_names = []
tags = []
types = []
attribute_descriptions = []

# Extract data from the table rows
for row in table.find_all('tr'):
    columns = row.find_all('td')
    if len(columns) == 4:
        # Extract attribute name, tag, type, and description
        attribute_name = columns[0].text.strip()
        
        # Skip rows with "attribute name" starting with ">"
        if attribute_name.startswith('>'):
            continue
        # Extract attribute name, tag, type, and description
        tag = columns[1].text.strip()
        type_ = columns[2].text.strip()
        description = columns[3].text.strip()
        
        # Find the <variablelist> elements with titles "Defined Terms" or "Enumerated Values"
        variablelists = re.findall(r'<variablelist[^>]*?title=["\'](Defined Terms|Enumerated Values)["\'][^>]*?>(.*?)<\/variablelist>', str(description), flags=re.DOTALL)

        # Extract defined terms from each variablelist
        defined_terms_dict = {}
        if variablelists:
            for variablelist in variablelists:
                title = variablelist.title.text.strip()
                defined_terms = [entry.term.text.strip() for entry in variablelist.find_all('varlistentry')]
                defined_terms_dict[title] = defined_terms
            
        # Append the extracted data to the lists
        attribute_names.append(attribute_name)
        tags.append(tag)
        types.append(type_)
        attribute_descriptions.append(description)

    # elif len(columns) == 2:
    #     # Insert the value in the second column into the previous row's Attribute Description
    #     attribute_descriptions[-1] += ' ' + columns[1].text.strip()

# Create a DataFrame from the extracted data
data = {
    'Attribute Name': attribute_names,
    'Tag': tags,
    'Type': types,
    'Attribute Description': attribute_descriptions
}
df_test = pd.DataFrame(data)

# %%
df_test
# Out:
#                                   Attribute Name          Tag Type  \
# 0                                 Patient's Name  (0010,0010)    2
# 1                                     Patient ID  (0010,0020)    2
# 2                             Type of Patient ID  (0010,0022)    3
# 3                           Patient's Birth Date  (0010,0030)    2
# 4   Patient's Birth Date in Alternative Calendar  (0010,0033)    3
# 5   Patient's Death Date in Alternative Calendar  (0010,0034)    3
# 6                 Patient's Alternative Calendar  (0010,0035)   1C
# 7                                  Patient's Sex  (0010,0040)    2
# 8              Referenced Patient Photo Sequence  (0010,1100)    3
# 9                        Quality Control Subject  (0010,0200)    3
# 10                   Referenced Patient Sequence  (0008,1120)    3
# 11                          Patient's Birth Time  (0010,0032)    3
# 12                    Other Patient IDs Sequence  (0010,1002)    3
# 13                           Other Patient Names  (0010,1001)    3
# 14                                  Ethnic Group  (0010,2160)    3
# 15                              Patient Comments  (0010,4000)    3
# 16                   Patient Species Description  (0010,2201)   1C
# 17                 Patient Species Code Sequence  (0010,2202)   1C
# 18                     Patient Breed Description  (0010,2292)   2C
# 19                   Patient Breed Code Sequence  (0010,2293)   2C
# 20                   Breed Registration Sequence  (0010,2294)   2C
# 21                            Strain Description  (0010,0212)    3
# 22                           Strain Nomenclature  (0010,0213)    3
# 23                          Strain Code Sequence  (0010,0219)    3
# 24                 Strain Additional Information  (0010,0218)    3
# 25                         Strain Stock Sequence  (0010,0216)    3
# 26                Genetic Modifications Sequence  (0010,0221)    3
# 27                            Responsible Person  (0010,2297)   2C
# 28                       Responsible Person Role  (0010,2298)   1C
# 29                      Responsible Organization  (0010,2299)   2C
# 30                      Patient Identity Removed  (0012,0062)    3
# 31                      De-identification Method  (0012,0063)   1C
# 32        De-identification Method Code Sequence  (0012,0064)   1C
#
#                                 Attribute Description
# 0                                Patient's full name.
# 1   Primary identifier for the Patient.\n\nIn the ...
# 2   The type of identifier in the Patient ID (0010...
# 3                          Birth date of the Patient.
# 4   Date of birth of the named Patient in the Alte...
# 5   Date of death of the named Patient in the Alte...
# 6   The Alternative Calendar used for Patient's Bi...
# 7   Sex of the named Patient.\n\nEnumerated Values...
# 8   A photo to confirm the identity of a Patient.\...
# 9   Indicates whether or not the subject is a qual...
# 10  A Sequence that provides reference to a Patien...
# 11                         Birth time of the Patient.
# 12  A Sequence of identification numbers or codes ...
# 13          Other names used to identify the Patient.
# 14               Ethnic group or race of the Patient.
# 15  User-defined additional information about the ...
# 16  The taxonomic rank value (e.g., genus, subgenu...
# 17  The taxonomic rank value (e.g., genus, subgenu...
# 18  The breed of the Patient. See .\nRequired if t...
# 19  The breed of the Patient. See .\nZero or more ...
# 20  Information identifying a non-human organism w...
# 21                   The strain of the Patient. See .
# 22  The nomenclature used for Strain Description (...
# 23  A coded identification of the strain of the Pa...
# 24  Additional information about the strain of the...
# 25  Information identifying a non-human organism w...
# 26  The genetic modifications of the Patient.\nOne...
# 27  Name of person with medical or welfare decisio...
# 28  Relationship of Responsible Person to the Pati...
# 29  Name of organization with medical or welfare d...
# 30  The true identity of the Patient has been remo...
# 31  A description or label of the mechanism or met...
# 32  A code describing the mechanism or method use ...

# %%
df_test["Attribute Description"][17]
# Out:
# 'The taxonomic rank value (e.g., genus, subgenus, species or subspecies) of the Patient. See .\nOnly a single Item shall be included in this Sequence.\nRequired if the Patient is a non-human organism and if Patient Species Description (0010,2201) is not present. May be present otherwise. D.'

# %%
import requests
import xml.etree.ElementTree as ET

# URI for DICOM Standard Part 3
xml_uri = 'https://dicom.nema.org/medical/dicom/current/source/docbook/part03/part03.xml'

# Parse the XML content
response = requests.get(xml_uri)
root = ET.fromstring(response.content)

# %%
# Find the child node with label="6"
for child in root:
    if child.attrib.get('label') == 'C':
        selected_node = child
        break

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import re

# Find the table with the specified xml:id
table = root.find(".//*[@xml:id='table_C.7-1']")

# Initialize lists to store extracted data
attribute_names = []
tags = []
types = []
attribute_descriptions = []

# Extract data from the table rows
for row in table.findall(".//tr"):
    columns = row.findall("./td")
    if len(columns) == 4:
        # Extract attribute name, tag, type, and description
        attribute_name = columns[0].text.strip()
        
        # Skip rows with "attribute name" starting with ">"
        if attribute_name.startswith('>'):
            continue
        
        # Extract attribute name, tag, type, and description
        tag = columns[1].text.strip()
        type_ = columns[2].text.strip()
        description = columns[3].text.strip()
        
        # Search for variablelist elements within the description
        variablelists = re.findall(r'<variablelist[^>]*?title=["\'](Defined Terms|Enumerated Values)["\'][^>]*?>(.*?)<\/variablelist>', description, flags=re.DOTALL)

        # Extract defined terms from each variablelist
        defined_terms_dict = {}
        if variablelists:
            for title, content in variablelists:
                defined_terms = [entry.strip() for entry in re.findall(r'<term>(.*?)<\/term>', content)]
                defined_terms_dict[title] = defined_terms
            
        # Append the extracted data to the lists
        attribute_names.append(attribute_name)
        tags.append(tag)
        types.append(type_)
        attribute_descriptions.append(defined_terms_dict)

# Create a DataFrame from the extracted data
data = {
    'Attribute Name': attribute_names,
    'Tag': tags,
    'Type': types,
    'Attribute Description': attribute_descriptions
}
df_test = pd.DataFrame(data)
# Out:
# Traceback (most recent call last):
#
#   File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3505 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[210], line 6
#     table = root.find(".//*[@xml:id='table_C.7-1']")
#
#   File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/xml/etree/ElementPath.py:389 in find
#     return next(iterfind(elem, path, namespaces), None)
#
#   File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/xml/etree/ElementPath.py:368 in iterfind
#     selector.append(ops[token[0]](next, token))
#
#   File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/xml/etree/ElementPath.py:234 in prepare_predicate
#     token = next()
#
#   File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/xml/etree/ElementPath.py:86 in xpath_tokenizer
#     raise SyntaxError("prefix %r not found in prefix map" % prefix) from None
#
#   File <string>
# SyntaxError: prefix 'xml' not found in prefix map

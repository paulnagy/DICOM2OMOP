# %% [markdown]
# # Enumerated Values and Defined Terms
# DICOM Standard Part 3 describes the relationship between Attributes and Value Sets per Information Object Definition (IOD). The Value Sets can be in form of Context Identifier (CIDs), Enumerated Values, and Defined Terms. The CID elements are stored in Part 16, and other two are described in Part 3. This script extracts them from Part 3 file from this repo, which had been extracted from DICOM Standard XML files.

# %%
cd ..
# Out:
# /Users/wooyeonpark/Documents/GitHub/DICOM2OMOP

# %%
import pandas as pd
part3 = pd.read_pickle('./files/DICOM Standard/part3_mapping.pkl')

# %%
part3['attribute_description_str'] = part3['Attribute Description'].astype(str)

# %%
part3[part3['attribute_description_str']!='{}'].head(5)
# Out:
#          xml_id                                     iod       IE  \
# 2   table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 7   table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 9   table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 31  table_A.2-1  Computed Radiography Image IOD Modules  Patient
# 79  table_A.2-1  Computed Radiography Image IOD Modules    Study
#
#            Module     Reference Usage Usage_code Reference_adjusted  \
# 2         Patient  sect_C.7.1.1     M          M       sect_C.7.1.1
# 7         Patient  sect_C.7.1.1     M          M       sect_C.7.1.1
# 9         Patient  sect_C.7.1.1     M          M       sect_C.7.1.1
# 31        Patient  sect_C.7.1.1     M          M       sect_C.7.1.1
# 79  Patient Study  sect_C.7.2.2     U          U       sect_C.7.2.2
#
#               Attribute Name       Tag Type  \
# 2         Type of Patient ID  00100022    3
# 7              Patient's Sex  00100040    2
# 9    Quality Control Subject  00100200    3
# 31  Patient Identity Removed  00120062    3
# 79            Smoking Status  001021A0    3
#
#                               Attribute Description CID  \
# 2    {'Defined Terms': ['TEXT', 'RFID', 'BARCODE']}
# 7            {'Enumerated Values': ['M', 'F', 'O']}
# 9              {'Enumerated Values': ['YES', 'NO']}
# 31             {'Enumerated Values': ['YES', 'NO']}
# 79  {'Enumerated Values': ['YES', 'NO', 'UNKNOWN']}
#
#                 SOP Class UID                        attribute_description_str
# 2   1.2.840.10008.5.1.4.1.1.1   {'Defined Terms': ['TEXT', 'RFID', 'BARCODE']}
# 7   1.2.840.10008.5.1.4.1.1.1           {'Enumerated Values': ['M', 'F', 'O']}
# 9   1.2.840.10008.5.1.4.1.1.1             {'Enumerated Values': ['YES', 'NO']}
# 31  1.2.840.10008.5.1.4.1.1.1             {'Enumerated Values': ['YES', 'NO']}
# 79  1.2.840.10008.5.1.4.1.1.1  {'Enumerated Values': ['YES', 'NO', 'UNKNOWN']}

# %%
defined_term = part3[part3['attribute_description_str'].str.contains('Defined')]['Attribute Description'].reset_index(drop=True)
enumerated_values = part3[part3['attribute_description_str'].str.contains('Enumerated')]['Attribute Description'].reset_index(drop=True)

# %%
enumerated_values.shape
# Out:
# (3931,)

# %%
defined_term.shape
# Out:
# (773,)

# %%
combined_defined_terms = []

for terms in defined_term:
    for key in terms:
        value = terms[key]
        combined_defined_terms.extend(value)

combined_defined_terms = list(set(combined_defined_terms))

# %%
len(combined_defined_terms) #773 to 345
# Out:
# 345

# %%
combined_defined_terms
# Out:
# ['SINGLE CRYSTAL',
#  'US',
#  'LORENTZIAN',
#  'PFP',
#  '4',
#  'SP',
#  'STORAGE',
#  'ENDOCAV_LINEAR',
#  'LDR',
#  'STEAM',
#  'SD',
#  'BASELINE',
#  'MONOPLANE',
#  'WOBBLE',
#  'TRACKING',
#  'TIME_DOMAIN_FIT',
#  'REPLICATE',
#  'ENDOCAV_MECH',
#  'OVFL',
#  'VECTOR_PHASED',
#  'ENDOCAV_AA',
#  'SECTOR_PHASED',
#  '19',
#  'RDD',
#  'MDR',
#  '255',
#  '11',
#  'TEXT',
#  'FILM',
#  'BLANK',
#  'PDDL',
#  'MLEV',
#  'CIRCLE',
#  'PPG',
#  'FAT_AND_WATER',
#  'SPECTRAL',
#  'SINGLE_VOXEL',
#  'RESEARCH',
#  'RG',
#  'STRIP',
#  'FLAT',
#  'GATING',
#  'CONST POTENTIAL',
#  'BREAST',
#  'RECTILINEAR',
#  'START',
#  'ENDOCAV_CLA',
#  'CYLINDRICAL RING',
#  'DRR',
#  'UNIF',
#  '2D',
#  'WATER',
#  'ULTRASOUND',
#  'CMOS',
#  'CYLINDRICAL',
#  'VCG',
#  'THM',
#  'RETROSPECTIVE',
#  'HAMMING',
#  '22',
#  'LONGITUDINAL',
#  'SS',
#  'CHASE',
#  '24CMX30CM',
#  'EKG',
#  'RWAVE',
#  'CENTRIC',
#  'WALTZ',
#  '7LI',
#  'PVC',
#  'REFLECTION',
#  'PRIME',
#  'BRACHY',
#  'TRIGGER',
#  'MR_PHASE',
#  'COSINE_SQUARED',
#  '19F',
#  'STATIONARY',
#  'STEP',
#  'PORTAL',
#  'SLIT_BASED',
#  'ILOPS',
#  'MANUAL_PULLBACK',
#  'CYLINDRICAL_RING',
#  'NORMAL',
#  'DIRECT',
#  'PLANE',
#  'LLO',
#  '16',
#  'BUTTERFLY',
#  '5',
#  'MP',
#  'DECY',
#  'CONTROL_POINT',
#  'SECTOR_MECH',
#  'SUB',
#  'SK',
#  '24',
#  'CYL_RING_PARTIAL',
#  'EFFECTIVE',
#  'CO2_SENSOR',
#  'CLN',
#  'MUL_PLAN_PARTIAL',
#  'PALLIATIVE',
#  'MOLYBDENUM',
#  'SI',
#  'NARROWBAND',
#  '15',
#  'PFF',
#  'BRACHY_SESSION',
#  'RL',
#  'FRACTION',
#  '3HE',
#  'ISIS',
#  '3D',
#  'ENDSYSTOLE',
#  'CONTINUOUS',
#  '10',
#  '35CMX43CM',
#  'TOMOSYNTHESIS',
#  'REALTIME',
#  'SLIM',
#  'SILICON_GEL',
#  'MOTN',
#  'FRACTION_SESSION',
#  'SIMULATOR',
#  'RECTANGLE',
#  'SPIRAL',
#  'MULTIPLE PLANAR',
#  '7',
#  'SCAT',
#  '30CMX35CM',
#  '14INX17IN',
#  '0',
#  'PLANE B',
#  'CCD',
#  'HANNING',
#  'DV',
#  'TOMO',
#  'FS',
#  '13',
#  'CURVED LINEAR',
#  'ELLIPSOIDAL',
#  'SUM',
#  'FC',
#  'PRESS',
#  'VERIFICATION',
#  'NAT',
#  'R98',
#  'PHOTO',
#  'BILINEAR',
#  'APEX',
#  'CARM',
#  'NAVIGATOR',
#  'TILED_FULL',
#  'COLUMN',
#  'PP',
#  'IV_ROT XTAL',
#  'SLOT',
#  'TUNGSTEN',
#  'RADIOGRAPH',
#  'LOCAL_LINEAR_FIT',
#  'INT',
#  'NON_RIGID',
#  'NCO',
#  'NRGY',
#  'FREE_PRECESSION',
#  'NONE',
#  '3D_TEMPORAL',
#  'ISOCENTER',
#  'PHYSICAL',
#  'CNTS',
#  'DRW',
#  'MOTION',
#  '8',
#  'STATIC',
#  'TREATMENT_DEVICE',
#  '20',
#  'MAX PIXEL',
#  'RIGID',
#  'JOINT',
#  'CG',
#  'DCAL',
#  'BREATH_HOLD',
#  '30CMX40CM',
#  'CARBON DIOXIDE',
#  'ECG',
#  'MTC',
#  'INTERFEROMETRY',
#  'CEPHALOSTAT',
#  'SINC_DECONVOLUTN',
#  'HEXAGONAL',
#  'PULSED',
#  'ERROR',
#  'DENS',
#  'RLD',
#  '9',
#  'ATTN',
#  'AMPLITUDE',
#  '12',
#  'PLANE A',
#  'PDR',
#  'AUTOMATIC',
#  '35CMX35CM',
#  'PLAN',
#  'BOTH',
#  'SECTOR_ANNULAR',
#  '6',
#  'ROW',
#  'RING',
#  'PATIENT',
#  'SERVICE',
#  'LL',
#  'MULTIPLE_PLANAR',
#  'RLO',
#  'IV_ROT MIRROR',
#  'DYNAMIC',
#  'GADOLINIUM',
#  'EXPONENTIAL',
#  'TILED_SPARSE',
#  'SPLIT XTAL CWD',
#  'GONADS',
#  '18',
#  'FIXED',
#  'ELLIPSE',
#  'SLO_TOMO',
#  'COR',
#  'SYN',
#  'GATED_PULLBACK',
#  '14',
#  '14INX14IN',
#  'PHASE_ORDERING',
#  'BARCODE',
#  'SELECTIVE',
#  '8INX10IN',
#  'IN',
#  'POLYNOMIAL_FIT',
#  'WSD',
#  'BARIUM',
#  'ADMIN',
#  '31P',
#  'NASAL_PROBE',
#  'REVERSE_LINEAR',
#  'MANUAL',
#  'BEAM',
#  'PROPHYLACTIC',
#  'FETUS',
#  'TRANSVERSE',
#  'CORRECTION',
#  'RHODIUM',
#  '3',
#  'HDR',
#  'RADIAL',
#  'FREQUENCY',
#  '23NA',
#  'RADL',
#  'DLYD',
#  'MAMMOGRAPHIC',
#  'CUBIC',
#  'WEIGHTED',
#  'COSINE',
#  '18CMX24CM',
#  'HIGHMI',
#  'ENDOCAV_PA',
#  'ROUND',
#  'SLOOP',
#  'SCINTILLATOR',
#  'MULTIPLE',
#  '13C',
#  'AREA',
#  'CURATIVE',
#  'AUTO',
#  '1H',
#  'STEP AND SHOOT',
#  '17',
#  '10INX12IN',
#  'POLYCYCLOIDAL',
#  'MR',
#  'FAT',
#  'DTIM',
#  'SINGLE PHASE',
#  'ENROLLMENT',
#  'QRS_LOOP',
#  'BELT',
#  'CLAMSHELL',
#  '1',
#  'IV_PHASED',
#  '1D',
#  'IODINE',
#  'PHASE_RESCANNING',
#  'RAN',
#  'PA',
#  'NORM',
#  'POLARIMETRY',
#  'MANU',
#  '21',
#  'RFID',
#  'LENS',
#  'FLUENCE',
#  'SEGMENTED',
#  'LINEAR_EXACT',
#  'RECORD',
#  'TILTING',
#  'PER',
#  'OCT',
#  'VOLUME',
#  'PMOT',
#  '23',
#  'LIN',
#  'ABORTED',
#  'MOTOR_PULLBACK',
#  'REVERSE_CENTRIC',
#  'OSP',
#  'MACHINE_QA',
#  'R03',
#  'SIGMOID',
#  'LINEAR',
#  'LLD',
#  'TRIG',
#  'PLAN_OVERVIEW',
#  'AP',
#  'SING',
#  'WEDGE',
#  'FULL',
#  '11INX14IN',
#  'SPLINE',
#  'RR_INTERVAL',
#  'LRNTZ_GSS_TRNSFM',
#  'DI',
#  'ROTA',
#  'GAUSSIAN',
#  '2',
#  'BEAM_SESSION',
#  'TIME_REVERSED',
#  'OPTICAL',
#  'BONE MARROW',
#  'LINEAR_TILT',
#  'MULTI_PLAN',
#  'DF',
#  '129XE',
#  'CIRCULAR',
#  'TRSS',
#  'TIME',
#  'THREE PHASE',
#  'PANORAMIC']

# %%
combined_enumerated_values = []

for terms in enumerated_values:
    for key in terms:
        value = terms[key]
        combined_enumerated_values.extend(value)

combined_enumerated_values = list(set(combined_enumerated_values))

# %%
combined_enumerated_values
# Out:
# ['01',
#  'IMG_INTENSIFIER',
#  'NS',
#  'G',
#  '0002',
#  'MARGINAL',
#  'SM',
#  'EMISSION',
#  'BSA',
#  'EP',
#  '2',
#  'TABLE',
#  'REALTIME',
#  'ORIGINAL',
#  'LEN',
#  'RESEARCH',
#  'PERSPECTIVE',
#  'E',
#  'CONTACT',
#  'OPV',
#  '2D_3D',
#  'EXVIVO',
#  'TRUE_COLOR',
#  'FOR PROCESSING',
#  'PLASTIC_CAP',
#  'IRIG',
#  'NTP',
#  'XAPROTOCOL',
#  'SCOORD',
#  'NOT_STARTED',
#  'ABNORMAL',
#  'MU',
#  'ROI_OVERRIDE',
#  'SMR',
#  'SE',
#  'PLAN',
#  'LANDSCAPE',
#  'AUTO',
#  'ALCOHOL',
#  'INTRAVASCULAR',
#  '12',
#  'CIRCULAR',
#  'OPERATOR',
#  'UIDREF',
#  'SUSPENDED',
#  'ACQ DURING STEP',
#  'RTRECORD',
#  'PNAME',
#  '3D_TEMPORAL',
#  'O',
#  'COMPLETE',
#  'BITMAP',
#  'CW',
#  'INTRACAVITARY',
#  'FEET_TO_HEAD',
#  'DX',
#  'SLAB',
#  '9',
#  'P',
#  'HEAD_TO_FEET',
#  'INVERSE',
#  '14',
#  'CODE',
#  'UNKNOWN',
#  'NP',
#  '15',
#  'FLUORESCENCE',
#  'PASSTHRU',
#  'MODIFIED',
#  'US',
#  'MAXIMUM_IP',
#  'FREEHAND',
#  'REGISTRATION',
#  'U',
#  'W',
#  'V',
#  'REMOVED',
#  'PRELIMINARY',
#  'PROSPECTIVE',
#  'PCN',
#  'INTRALUMENARY',
#  'MEASURED',
#  'MANUAL',
#  'IMAGINARY',
#  'PSEUDOCONTINUOUS',
#  'KER',
#  'GRADIENT',
#  'PACED',
#  'IBW',
#  'EXTERNAL',
#  'PRODUCT',
#  'EYE',
#  'PARTIAL',
#  '3D',
#  'ADAPT_LAYOUT',
#  'NO',
#  'TRANSMISSION',
#  'INVIVO',
#  'SELECTIVE',
#  '2D',
#  'REFERENCED',
#  'SINGLE',
#  'WATER',
#  'RWV',
#  'MINIMUM_IP',
#  'IMAGE',
#  '11',
#  'NOT_ACCEPTABLE',
#  'FLYTHROUGH',
#  'COMPOSITE',
#  'FINAL',
#  'NUM',
#  '64',
#  '+1',
#  'CROSSCURVE',
#  'ULTRASOUND_GEL',
#  'DIGITAL',
#  'ESDBS',
#  'IDENTITY',
#  'LBMJANMA',
#  'M',
#  'PULSED',
#  'CTPROTOCOL',
#  'COMPLETED',
#  'FIXED',
#  'FRACTIONAL',
#  'SPIN',
#  'STUDY',
#  'MINUTE',
#  '13',
#  'SNTP',
#  'OR',
#  'ANALOG',
#  'YES',
#  'DATE',
#  'RTDOSE',
#  'LOCAL',
#  'OPTBSV',
#  'BREAST',
#  'RELATIVE',
#  '00',
#  'MAMMOGRAPHIC',
#  'NON_STAGED',
#  '00181063H',
#  'IR',
#  'VERIFIED',
#  'BOTH',
#  'FOR PRESENTATION',
#  'RTSTRUCT',
#  'S',
#  '-1',
#  'ORTHOGRAPHIC',
#  'WAVEFORM',
#  'HEXAGONAL',
#  'MR',
#  'LBM',
#  'LIN',
#  '3',
#  'GR',
#  'APPROVED',
#  'PLANAR',
#  '10',
#  'ALTERED',
#  'DYNAMIC',
#  'AC',
#  'Y',
#  'RETROSPECTIVE',
#  'MONOCHROME',
#  'ON_TREATMENT',
#  'FAILED',
#  'UNAPPROVED',
#  'SUB',
#  'NONE',
#  'OPTENF',
#  'INCONCLUSIVE',
#  'CONTAINER',
#  'ACTUAL',
#  'PX',
#  'DEVICE',
#  'PRIMARY',
#  'MINERAL_OIL',
#  'FID',
#  'PT',
#  'STATIC',
#  'TRACKED',
#  'COL',
#  'UNALTERED',
#  'TCOORD',
#  '1',
#  'MOTORIZED',
#  'NON_NORMAL',
#  'FULL',
#  'UNVERIFIED',
#  'A',
#  'L',
#  'IVOCT',
#  'BASE_TO_APEX',
#  'ANN',
#  'PORTRAIT',
#  'COLUMN',
#  'SINGLE_USER',
#  '0001',
#  'UNMODIFIED',
#  'MONOCHROME2',
#  'ENHANCED',
#  'COLOR_RANGE',
#  'KO',
#  'ROW',
#  'USER_GROUP',
#  'BW',
#  'N',
#  'SITE',
#  'PASSED',
#  'LOG',
#  'USER',
#  'ESTIMATED',
#  'REPROJECTION',
#  'MG',
#  'CT',
#  'REG',
#  '32',
#  'F',
#  '0',
#  '00181065H',
#  '0004',
#  'OPM',
#  'THIN',
#  'MONOCHROME1',
#  'OP',
#  'PERMANENT',
#  '6',
#  'TRUE',
#  'OPT',
#  'PTP',
#  'SR',
#  'SEPARATE',
#  'COLOR_REF',
#  'BIPED',
#  'COMPLEX',
#  'UNDEFINED',
#  'VA',
#  'DATETIME',
#  'NORMAL',
#  'DERIVED',
#  '180',
#  'COLOR',
#  'IMPORTED',
#  'GPS',
#  'NO TRIGGER',
#  '16',
#  'QUADRUPED',
#  'MSP',
#  'RECTANGLE',
#  'BINARY',
#  'REAL',
#  'REFLECTANCE',
#  'POPULATION',
#  'ESAK',
#  'MAINTAIN_LAYOUT',
#  '2PS',
#  'MANUFACTURER',
#  'TIME',
#  'NON_CONTACT',
#  'RM',
#  'SWIVEL',
#  'ORIENTATION_VAR',
#  'WHOLE BODY',
#  'CONTINUOUS',
#  'STEP AND SHOOT',
#  'STOPPED',
#  'NON_POLARIZED',
#  'GY',
#  'SERIES',
#  'PALETTE COLOR',
#  'SEG',
#  'FRAME',
#  'AR',
#  'RF',
#  'RECTANGULAR',
#  'SRF',
#  '7',
#  'PRESENTATION_SEQ',
#  'T',
#  'POSITION_VAR',
#  'IAK',
#  'ON_BREAK',
#  'XA',
#  'INSTANCE',
#  '90',
#  'VARIABLE',
#  'ROUND',
#  'IOL',
#  'RTIMAGE',
#  'FREQUENCY',
#  'POLARIZED',
#  'REJECTED',
#  'IO',
#  '0000H',
#  'SERVICE',
#  'DIGITAL_DETECTOR',
#  'PR',
#  'INPUT_SEQ',
#  'IVUS',
#  'AO',
#  'SOURCE',
#  'MAGNITUDE',
#  'OAM',
#  'VOLUME_RENDERED',
#  '0003',
#  'B',
#  'ESDNOBS',
#  'OSS',
#  'SCOORD3D',
#  'K',
#  'ACCEPTABLE',
#  'GATED',
#  'LBMJAMES128',
#  'POLYGONAL',
#  'APEX_TO_BASE',
#  'R',
#  'SC',
#  '270',
#  'FALSE',
#  'CEPHALOSTAT',
#  'CLASSIC',
#  'STAGED',
#  'USED_DISCARDED',
#  '8',
#  'RTPLAN',
#  'INTERSTITIAL',
#  'TEXT',
#  '1PS',
#  'RIGID',
#  'application/pdf',
#  'WATER_REFERENCE',
#  'CC',
#  'VOLUME']

# %%
len(combined_enumerated_values) #3931 to 337
# Out:
# 337

# %%
combined_defined_terms = set(combined_defined_terms)
combined_enumerated_values = set(combined_enumerated_values)

# %%
overlap = combined_defined_terms.intersection(combined_enumerated_values)

# %%
len(overlap)
# Out:
# 55

# %%
overlap
# Out:
# {'0',
#  '1',
#  '10',
#  '11',
#  '12',
#  '13',
#  '14',
#  '15',
#  '16',
#  '2',
#  '2D',
#  '3',
#  '3D',
#  '3D_TEMPORAL',
#  '6',
#  '7',
#  '8',
#  '9',
#  'AUTO',
#  'BOTH',
#  'BREAST',
#  'CEPHALOSTAT',
#  'CIRCULAR',
#  'COLUMN',
#  'CONTINUOUS',
#  'DYNAMIC',
#  'FIXED',
#  'FREQUENCY',
#  'FULL',
#  'HEXAGONAL',
#  'LIN',
#  'MAMMOGRAPHIC',
#  'MANUAL',
#  'MR',
#  'NONE',
#  'NORMAL',
#  'PLAN',
#  'PULSED',
#  'REALTIME',
#  'RECTANGLE',
#  'RESEARCH',
#  'RETROSPECTIVE',
#  'RIGID',
#  'ROUND',
#  'ROW',
#  'SELECTIVE',
#  'SERVICE',
#  'STATIC',
#  'STEP AND SHOOT',
#  'SUB',
#  'TEXT',
#  'TIME',
#  'US',
#  'VOLUME',
#  'WATER'}

# %% [markdown]
# ## Are all Defined Terms and Enumerated Values valuable to add in the OMOP CDM?

# %%
attributes = pd.read_csv("./files/DICOM Standard/part6_attributes.csv")
part3_att = part3.merge(attributes[['Tag_cleaned', 'VR']], how = 'inner', left_on = 'Tag', right_on = 'Tag_cleaned')

# %%
# Looking through General Series Attributes (5)
part3_att[(part3_att['VR']=="CS") & (part3_att['Tag'].isin(['00200060','00185100', '00102210']))]
# Modality: C.7.3.1.1.1 for Defined Terms (https://dicom.nema.org/medical/dicom/current/output/chtml/part03/sect_C.7.3.html#sect_C.7.3.1.1.1)
# Body Part Examined: Annex L Correspondence of Anatomic Region Codes and Body Part Examined Defined Terms (https://dicom.nema.org/medical/dicom/current/output/chtml/part16/chapter_l.html)
# Laterality: R = Right, L = Left
# Patient Position: Section C.7.3.1.1.2 (https://dicom.nema.org/medical/dicom/current/output/chtml/part03/sect_C.7.3.html#sect_C.7.3.1.1.2)
# Anatomic Orientation Type: BIPED, QUADRUPED
# Out:
#                  xml_id                                                iod  \
# 103         table_A.2-1             Computed Radiography Image IOD Modules
# 116         table_A.2-1             Computed Radiography Image IOD Modules
# 120         table_A.2-1             Computed Radiography Image IOD Modules
# 391         table_A.3-1                               CT Image IOD Modules
# 404         table_A.3-1                               CT Image IOD Modules
# ...                 ...                                                ...
# 40885  table_A.90.1.3-1              Confocal Microscopy Image IOD Modules
# 40889  table_A.90.1.3-1              Confocal Microscopy Image IOD Modules
# 41143  table_A.90.2.3-1  Confocal Microscopy Tiled Pyramidal Image IOD ...
# 41156  table_A.90.2.3-1  Confocal Microscopy Tiled Pyramidal Image IOD ...
# 41160  table_A.90.2.3-1  Confocal Microscopy Tiled Pyramidal Image IOD ...
#
#            IE          Module     Reference Usage Usage_code  \
# 103    Series  General Series  sect_C.7.3.1     M          M
# 116    Series  General Series  sect_C.7.3.1     M          M
# 120    Series  General Series  sect_C.7.3.1     M          M
# 391    Series  General Series  sect_C.7.3.1     M          M
# 404    Series  General Series  sect_C.7.3.1     M          M
# ...       ...             ...           ...   ...        ...
# 40885  Series  General Series  sect_C.7.3.1     M          M
# 40889  Series  General Series  sect_C.7.3.1     M          M
# 41143  Series  General Series  sect_C.7.3.1     M          M
# 41156  Series  General Series  sect_C.7.3.1     M          M
# 41160  Series  General Series  sect_C.7.3.1     M          M
#
#       Reference_adjusted               Attribute Name       Tag Type  \
# 103         sect_C.7.3.1                   Laterality  00200060   2C
# 116         sect_C.7.3.1             Patient Position  00185100   2C
# 120         sect_C.7.3.1  Anatomical Orientation Type  00102210   1C
# 391         sect_C.7.3.1                   Laterality  00200060   2C
# 404         sect_C.7.3.1             Patient Position  00185100   2C
# ...                  ...                          ...       ...  ...
# 40885       sect_C.7.3.1             Patient Position  00185100   2C
# 40889       sect_C.7.3.1  Anatomical Orientation Type  00102210   1C
# 41143       sect_C.7.3.1                   Laterality  00200060   2C
# 41156       sect_C.7.3.1             Patient Position  00185100   2C
# 41160       sect_C.7.3.1  Anatomical Orientation Type  00102210   1C
#
#                                Attribute Description CID  \
# 103                {'Enumerated Values': ['R', 'L']}
# 116                                               {}
# 120    {'Enumerated Values': ['BIPED', 'QUADRUPED']}
# 391                {'Enumerated Values': ['R', 'L']}
# 404                                               {}
# ...                                              ...  ..
# 40885                                             {}
# 40889  {'Enumerated Values': ['BIPED', 'QUADRUPED']}
# 41143              {'Enumerated Values': ['R', 'L']}
# 41156                                             {}
# 41160  {'Enumerated Values': ['BIPED', 'QUADRUPED']}
#
#                         SOP Class UID  \
# 103         1.2.840.10008.5.1.4.1.1.1
# 116         1.2.840.10008.5.1.4.1.1.1
# 120         1.2.840.10008.5.1.4.1.1.1
# 391         1.2.840.10008.5.1.4.1.1.2
# 404         1.2.840.10008.5.1.4.1.1.2
# ...                               ...
# 40885  1.2.840.10008.5.1.4.1.1.77.1.8
# 40889  1.2.840.10008.5.1.4.1.1.77.1.8
# 41143  1.2.840.10008.5.1.4.1.1.77.1.9
# 41156  1.2.840.10008.5.1.4.1.1.77.1.9
# 41160  1.2.840.10008.5.1.4.1.1.77.1.9
#
#                            attribute_description_str Tag_cleaned  VR
# 103                {'Enumerated Values': ['R', 'L']}    00200060  CS
# 116                                               {}    00185100  CS
# 120    {'Enumerated Values': ['BIPED', 'QUADRUPED']}    00102210  CS
# 391                {'Enumerated Values': ['R', 'L']}    00200060  CS
# 404                                               {}    00185100  CS
# ...                                              ...         ...  ..
# 40885                                             {}    00185100  CS
# 40889  {'Enumerated Values': ['BIPED', 'QUADRUPED']}    00102210  CS
# 41143              {'Enumerated Values': ['R', 'L']}    00200060  CS
# 41156                                             {}    00185100  CS
# 41160  {'Enumerated Values': ['BIPED', 'QUADRUPED']}    00102210  CS
#
# [400 rows x 17 columns]

# %%
# Looking through General Image Attributes (9)
part3_att[(part3_att['VR']=="CS") & (part3_att['Tag'].isin(['00282110','20500020', '00200062']))]
# Patient Orientation: C.7.6.1.1.1 (https://dicom.nema.org/medical/dicom/current/output/chtml/part03/sect_C.7.6.html#sect_C.7.6.1.1.1)
    # different values are allowed based on Anatomic Orientation Type (0010,2210) BIPED > A (anterior), P (posterior), etc.; QUADRUPED > LE (Left), RT (Right), D (Dorsal), etc.
# Image Type: C.7.6.1.1.2 (multi values: value 1= ORIGINAL, DERIVED; value 2 = PRIMARY, SECONDARY)
# Quality Control Image: YES, NO, BOTH
# Burned In Annotation: YES, NO
# Recognizable Visual Features: YES, NO
# Lossy Image Compression: 00 (image has not been subjected to lossy compression ~ NO), 01 (image has been subjected to lossy compression ~ YES)
# Lossy Image Compression Method: C.7.6.1.1.5.1 (https://dicom.nema.org/medical/dicom/current/output/chtml/part03/sect_C.7.6.html#sect_C.7.6.1.1.5.1)
# Presentation LUT Shape: 'IDENTITY', 'INVERSE'
# Image Laterality: 'R' Right, 'L' Left, 'U' Unparied, 'B' Both left and right
# Out:
#                  xml_id                                                iod  \
# 169         table_A.2-1             Computed Radiography Image IOD Modules
# 173         table_A.2-1             Computed Radiography Image IOD Modules
# 175         table_A.2-1             Computed Radiography Image IOD Modules
# 460         table_A.3-1                               CT Image IOD Modules
# 464         table_A.3-1                               CT Image IOD Modules
# ...                 ...                                                ...
# 40997  table_A.90.1.3-1              Confocal Microscopy Image IOD Modules
# 41219  table_A.90.2.3-1  Confocal Microscopy Tiled Pyramidal Image IOD ...
# 41223  table_A.90.2.3-1  Confocal Microscopy Tiled Pyramidal Image IOD ...
# 41225  table_A.90.2.3-1  Confocal Microscopy Tiled Pyramidal Image IOD ...
# 41276  table_A.90.2.3-1  Confocal Microscopy Tiled Pyramidal Image IOD ...
#
#           IE                     Module      Reference Usage Usage_code  \
# 169    Image              General Image   sect_C.7.6.1     M          M
# 173    Image              General Image   sect_C.7.6.1     M          M
# 175    Image              General Image   sect_C.7.6.1     M          M
# 460    Image              General Image   sect_C.7.6.1     M          M
# 464    Image              General Image   sect_C.7.6.1     M          M
# ...      ...                        ...            ...   ...        ...
# 40997  Image  Confocal Microscopy Image  sect_C.8.35.1     M          M
# 41219  Image              General Image   sect_C.7.6.1     M          M
# 41223  Image              General Image   sect_C.7.6.1     M          M
# 41225  Image              General Image   sect_C.7.6.1     M          M
# 41276  Image  Confocal Microscopy Image  sect_C.8.35.1     M          M
#
#       Reference_adjusted           Attribute Name       Tag Type  \
# 169         sect_C.7.6.1  Lossy Image Compression  00282110    3
# 173         sect_C.7.6.1   Presentation LUT Shape  20500020    3
# 175         sect_C.7.6.1         Image Laterality  00200062    3
# 460         sect_C.7.6.1  Lossy Image Compression  00282110    3
# 464         sect_C.7.6.1   Presentation LUT Shape  20500020    3
# ...                  ...                      ...       ...  ...
# 40997      sect_C.8.35.1  Lossy Image Compression  00282110    1
# 41219       sect_C.7.6.1  Lossy Image Compression  00282110    3
# 41223       sect_C.7.6.1   Presentation LUT Shape  20500020    3
# 41225       sect_C.7.6.1         Image Laterality  00200062    3
# 41276      sect_C.8.35.1  Lossy Image Compression  00282110    1
#
#                                 Attribute Description CID  \
# 169               {'Enumerated Values': ['00', '01']}
# 173    {'Enumerated Values': ['IDENTITY', 'INVERSE']}
# 175       {'Enumerated Values': ['R', 'L', 'U', 'B']}
# 460               {'Enumerated Values': ['00', '01']}
# 464    {'Enumerated Values': ['IDENTITY', 'INVERSE']}
# ...                                               ...  ..
# 40997             {'Enumerated Values': ['00', '01']}
# 41219             {'Enumerated Values': ['00', '01']}
# 41223  {'Enumerated Values': ['IDENTITY', 'INVERSE']}
# 41225     {'Enumerated Values': ['R', 'L', 'U', 'B']}
# 41276             {'Enumerated Values': ['00', '01']}
#
#                         SOP Class UID  \
# 169         1.2.840.10008.5.1.4.1.1.1
# 173         1.2.840.10008.5.1.4.1.1.1
# 175         1.2.840.10008.5.1.4.1.1.1
# 460         1.2.840.10008.5.1.4.1.1.2
# 464         1.2.840.10008.5.1.4.1.1.2
# ...                               ...
# 40997  1.2.840.10008.5.1.4.1.1.77.1.8
# 41219  1.2.840.10008.5.1.4.1.1.77.1.9
# 41223  1.2.840.10008.5.1.4.1.1.77.1.9
# 41225  1.2.840.10008.5.1.4.1.1.77.1.9
# 41276  1.2.840.10008.5.1.4.1.1.77.1.9
#
#                             attribute_description_str Tag_cleaned  VR
# 169               {'Enumerated Values': ['00', '01']}    00282110  CS
# 173    {'Enumerated Values': ['IDENTITY', 'INVERSE']}    20500020  CS
# 175       {'Enumerated Values': ['R', 'L', 'U', 'B']}    00200062  CS
# 460               {'Enumerated Values': ['00', '01']}    00282110  CS
# 464    {'Enumerated Values': ['IDENTITY', 'INVERSE']}    20500020  CS
# ...                                               ...         ...  ..
# 40997             {'Enumerated Values': ['00', '01']}    00282110  CS
# 41219             {'Enumerated Values': ['00', '01']}    00282110  CS
# 41223  {'Enumerated Values': ['IDENTITY', 'INVERSE']}    20500020  CS
# 41225     {'Enumerated Values': ['R', 'L', 'U', 'B']}    00200062  CS
# 41276             {'Enumerated Values': ['00', '01']}    00282110  CS
#
# [269 rows x 17 columns]

# %% [markdown]
# # Harvest select Defined Terms
# ## Modality

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the DICOM section
url = 'https://dicom.nema.org/medical/dicom/current/output/chtml/part03/sect_C.7.3.html#sect_C.7.3.1.1.1'

# Fetch the page content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
soup

# Find the section that contains the list of codes and descriptions
# The structure is a <dl> element containing <dt> (codes) and <dd> (descriptions)
dl_section = soup.find('dl', class_='variablelist compact')

# Locate the section by finding the <a> tag with the correct id (sect_C.7.3.1.1.1)
section_anchor = soup.find('a', {'id': 'sect_C.7.3.1.1.1'})

if section_anchor:
    # Find the next <dl> (description list) tag that contains the codes and descriptions
    dl_section = section_anchor.find_next('dl', class_='variablelist compact')

    if dl_section:
        # Create lists to store codes and their descriptions
        codes = []
        descriptions = []

        # Loop through each <dt> (codes) and <dd> (descriptions)
        for dt in dl_section.find_all('dt'):
            # Extract the code text from the <span class="term"> within the <dt> tag
            code = dt.find('span', class_='term').get_text(strip=True)

            # Extract the description text from the <p> tag within the corresponding <dd> tag
            dd = dt.find_next_sibling('dd')
            description = dd.find('p').get_text(strip=True)

            # Append the code and description to the lists
            codes.append(code)
            descriptions.append(description)

        # Create a DataFrame with the extracted codes and descriptions
        modality_defined_terms = pd.DataFrame({
            'code': codes,
            'description': descriptions
        })
    else:
        print("Description list (dl) not found after the section anchor.")
else:
    print("Section anchor with id 'sect_C.7.3.1.1.1' not found.")

# %%
modality_defined_terms
# Out:
#           code                     description
# 0          ANN                      Annotation
# 1           AR                  Autorefraction
# 2         ASMT      Content Assessment Results
# 3           AU                           Audio
# 4         BDUS  Bone Densitometry (ultrasound)
# ..         ...                             ...
# 74          US                      Ultrasound
# 75          VA                   Visual Acuity
# 76          XA               X-Ray Angiography
# 77  XAPROTOCOL         XA Protocol (Performed)
# 78          XC     External-camera Photography
#
# [79 rows x 2 columns]

# %%
modality_defined_terms.to_csv('./files/DICOM Standard/part3_modality.csv', index=False)

# %% [markdown]
# ## Annex L Body Part Examined

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the DICOM section
url = 'https://dicom.nema.org/medical/dicom/current/output/chtml/part16/chapter_l.html'

# Fetch the page content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
soup

# Locate the specific table by finding the <a> tag with the id="table_L-1"
table_anchor = soup.find('a', {'id': 'table_L-1'})

if table_anchor:
    # Find the table contents after the anchor
    table = table_anchor.find_next('table')

    # Extract table headers
    headers = []
    for th in table.find_all('th'):
        header_text = th.get_text(strip=True)
        headers.append(header_text)

    # Extract table rows
    rows = []
    for tr in table.find_all('tr')[1:]:  # Skip the header row
        row = []
        for td in tr.find_all('td'):
            cell_text = td.get_text(strip=True)
            row.append(cell_text)
        rows.append(row)

    # Create a DataFrame with the extracted headers and rows
    body_part_examined_defined_terms = pd.DataFrame(rows, columns=headers)

else:
    print("Table L-1 not found")

# %%
body_part_examined_defined_terms
# Out:
#     Coding Scheme Designator Code Value                  Code Meaning  \
# 0                        SCT  818981001                       Abdomen
# 1                        SCT  818982008            Abdomen and Pelvis
# 2                        SCT    7832008               Abdominal aorta
# 3                        SCT   85856004       Acromioclavicular joint
# 4                        SCT   23451007                 Adrenal gland
# ..                       ...        ...                           ...
# 393                      SCT   85234005              Vertebral artery
# 394                      SCT  110517009  Vertebral column and cranium
# 395                      SCT   45292006                         Vulva
# 396                      SCT   74670003                   Wrist joint
# 397                      SCT   13881006                        Zygoma
#
#     Body Part Examined SNOMED-RT ID (Retired) FMA Code Value  \
# 0              ABDOMEN
# 1        ABDOMENPELVIS
# 2       ABDOMINALAORTA                T-42500
# 3              ACJOINT                T-15420
# 4              ADRENAL                T-B3000
# ..                 ...                    ...            ...
# 393         VERTEBRALA                T-45700
# 394                                   T-11011
# 395              VULVA                T-81000
# 396              WRIST                T-15460
# 397             ZYGOMA                T-11166
#
#     UMLS Concept UniqueID
# 0
# 1
# 2
# 3
# 4
# ..                    ...
# 393
# 394
# 395
# 396
# 397
#
# [398 rows x 7 columns]

# %%
body_part_examined_defined_terms.to_pickle('./files/DICOM Standard/part16_body_part_examined.pkl')

# %% [markdown]
# ## Patient Position

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the DICOM section
url = 'https://dicom.nema.org/medical/dicom/current/output/chtml/part03/sect_C.7.3.html#sect_C.7.3.1.1.2'

# Fetch the page content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Locate the section by finding the <a> tag with the correct id (sect_C.7.3.1.1.2)
section_anchor = soup.find('a', {'id': 'sect_C.7.3.1.1.2'})

if section_anchor:
    # Find the next <dl> (description list) tag that contains the codes and descriptions
    dl_section = section_anchor.find_next('dl', class_='variablelist compact')

    if dl_section:
        # Create lists to store codes and their descriptions
        codes = []
        descriptions = []

        # Loop through each <dt> (codes) and <dd> (descriptions)
        for dt in dl_section.find_all('dt'):
            # Extract the code text from the <span class="term"> within the <dt> tag
            code = dt.find('span', class_='term').get_text(strip=True)

            # Extract the description text from the <p> tag within the corresponding <dd> tag
            dd = dt.find_next_sibling('dd')
            description = dd.find('p').get_text(strip=True)

            # Append the code and description to the lists
            codes.append(code)
            descriptions.append(description)

        # Create a DataFrame with the extracted codes and descriptions
        patient_position_defined_terms = pd.DataFrame({
            'code': codes,
            'description': descriptions
        })

    else:
        print("Description list (dl) not found after the section anchor.")
else:
    print("Section anchor with id 'sect_C.7.3.1.1.2' not found.")

# %%
patient_position_defined_terms
# Out:
#     code                      description
# 0    HFP                 Head First-Prone
# 1    HFS                Head First-Supine
# 2   HFDR       Head First-Decubitus Right
# 3   HFDL        Head First-Decubitus Left
# 4   FFDR       Feet First-Decubitus Right
# 5   FFDL        Feet First-Decubitus Left
# 6    FFP                 Feet First-Prone
# 7    FFS                Feet First-Supine
# 8    LFP                 Left First-Prone
# 9    LFS                Left First-Supine
# 10   RFP                Right First-Prone
# 11   RFS               Right First-Supine
# 12  AFDR   Anterior First-Decubitus Right
# 13  AFDL    Anterior First-Decubitus Left
# 14  PFDR  Posterior First-Decubitus Right
# 15  PFDL   Posterior First-Decubitus Left

# %%
patient_position_defined_terms.to_csv('./files/DICOM Standard/part3_patient_position.csv', index=False)

# %% [markdown]
# ## Lossy Image Compression Method

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the DICOM section
url = 'https://dicom.nema.org/medical/dicom/current/output/chtml/part03/sect_C.7.6.html#sect_C.7.6.1.1.5.1'

# Fetch the page content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Locate the section by finding the <a> tag with the correct id (sect_C.7.6.1.1.5.1)
section_anchor = soup.find('a', {'id': 'sect_C.7.6.1.1.5.1'})

if section_anchor:
    # Find the next <dl> (description list) tag that contains the codes and descriptions
    dl_section = section_anchor.find_next('dl', class_='variablelist compact')

    if dl_section:
        # Create lists to store codes and their descriptions
        codes = []
        descriptions = []

        # Loop through each <dt> (codes) and <dd> (descriptions)
        for dt in dl_section.find_all('dt'):
            # Extract the code text from the <span class="term"> within the <dt> tag
            code = dt.find('span', class_='term').get_text(strip=True)

            # Extract the description text from the <p> tag within the corresponding <dd> tag
            dd = dt.find_next_sibling('dd')
            description = dd.find('p').get_text(strip=True)

            # Append the code and description to the lists
            codes.append(code)
            descriptions.append(description)

        # Create a DataFrame with the extracted codes and descriptions
        lossy_image_comp_method_defined_terms = pd.DataFrame({
            'code': codes,
            'description': descriptions
        })

    else:
        print("Description list (dl) not found after the section anchor.")
else:
    print("Section anchor with id 'sect_C.7.6.1.1.5.1' not found.")

# %%
lossy_image_comp_method_defined_terms
# Out:
#            code                                        description
# 0   ISO_10918_1            JPEG Lossy Compression[ISO/IEC 10918-1]
# 1   ISO_14495_1  JPEG-LS Near-lossless Compression[ISO/IEC 1449...
# 2   ISO_15444_1  JPEG 2000 Irreversible Compression[ISO/IEC 154...
# 3  ISO_15444_15  High-Throughput JPEG 2000 Irreversible Compres...
# 4   ISO_18181_1  JPEG XL Image Coding System - Part 1 Core Codi...
# 5   ISO_13818_2                 MPEG2 Compression[ISO/IEC 13818-2]
# 6  ISO_14496_10     MPEG-4 AVC/H.264 Compression[ISO/IEC 14496-10]
# 7   ISO_23008_2      HEVC/H.265 Lossy Compression[ISO/IEC 23008-2]

# %%
lossy_image_comp_method_defined_terms.to_csv('./files/DICOM Standard/part3_lossy_image_comp_methods.csv', index=False)
